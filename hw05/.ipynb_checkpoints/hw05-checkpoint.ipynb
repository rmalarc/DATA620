# %%
import os
import re
import math
import nltk
import random
import itertools
import numpy as np
import pandas as pd
import seaborn as sns
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import accuracy_score, confusion_matrix, cohen_kappa_score, roc_curve, jaccard_similarity_score, precision_score
# %matplotlib inline

# %% [markdown]
# Dataset obtained from: https://www.cs.cmu.edu/afs/cs.cmu.edu/project/theo-20/www/data/news20.html <br>
# This data set is a collection of 20,000 messages, collected from 20 different netnews newsgroups. One thousand messages from each of the twenty newsgroups were chosen at random and partitioned by newsgroup name.

# %%
rootdir = '/Users/aadi/Documents/DATA620/hw05/data/'

# %%
df_ = pd.DataFrame(index=range(0), columns=['class', 'document'])
df_ = df_.fillna(0) # with 0s rather than NaNs

# %%
df_
# Out:
# Empty DataFrame
# Columns: [class, document]
# Index: []

# %%
counter = 0
for subdir, dirs, files in os.walk(rootdir):
    folder_name = os.path.basename(subdir)
    for file in files:
        if not file.startswith('.'):
            f = open(subdir+'/'+file, 'r')
            txt = f.read()
            header_end = re.search(r'\n\n', txt)
            pos = header_end.start()
            strlen = len(txt)
            txt = txt[pos:strlen]
            df_ = df_.append({'class':folder_name, 'document':txt}, ignore_index=True)
            counter = counter + 1
            if counter % 500 == 0:
                print counter
# Out:
# 500
# 1000
# 1500
# 2000
# 2500
# 3000
# 3500
# 4000
# 4500
# 5000
# 5500
# 6000
# 6500
# 7000
# 7500
# 8000
# 8500
# 9000
# 9500
# 10000
# 10500
# 11000
# 11500
# 12000
# 12500
# 13000
# 13500
# 14000
# 14500
# 15000
# 15500
# 16000
# 16500
# 17000
# 17500
# 18000
# 18500
# 19000
# 19500

# %%
df_['document'] = df_['document'].str.replace('\n', '')

# %%
df_
# Out:
#                     class                                           document
# 0             alt.atheism  Archive-name: atheism/resourcesAlt-atheism-arc...
# 1             alt.atheism  Archive-name: atheism/introductionAlt-atheism-...
# 2             alt.atheism  In article <65974@mimsy.umd.edu>mangoe@cs.umd....
# 3             alt.atheism  dmn@kepler.unh.edu (...until kings become phil...
# 4             alt.atheism  In article <N4HY.93Apr5120934@harder.ccr-p.ida...
# 5             alt.atheism  In article <1993Apr5.091139.823@batman.bmd.trw...
# 6             alt.atheism  arromdee@jyusenkyou.cs.jhu.edu (Ken Arromdee) ...
# 7             alt.atheism  In article <114127@bu.edu>jaeger@buphy.bu.edu ...
# 8             alt.atheism  (reference line trimmed)livesey@solntze.wpd.sg...
# 9             alt.atheism  kmr4@po.CWRU.edu (Keith M. Ryan) writes:>>Then...
# 10            alt.atheism  livesey@solntze.wpd.sgi.com (Jon Livesey) writ...
# 11            alt.atheism  sandvik@newton.apple.com (Kent Sandvik) writes...
# 12            alt.atheism  wpr@atlanta.dg.com (Bill Rawlins) writes:>>[.....
# 13            alt.atheism  arromdee@jyusenkyou.cs.jhu.edu (Ken Arromdee) ...
# 14            alt.atheism  bobbe@vice.ICO.TEK.COM (Robert Beauchaine) wri...
# 15            alt.atheism  bobbe@vice.ICO.TEK.COM (Robert Beauchaine) wri...
# 16            alt.atheism  bobbe@vice.ICO.TEK.COM (Robert Beauchaine) wri...
# 17            alt.atheism  In article <2942881697.0.p00168@psilink.com> p...
# 18            alt.atheism  In article <1993Apr3.081052.11292@monu6.cc.mon...
# 19            alt.atheism  In article <1993Apr3.212139.14076@blaze.cs.jhu...
# 20            alt.atheism  In article <1phnkoINNbk@ctron-news.ctron.com> ...
# 21            alt.atheism  Someone writes:>I found a list of Biblical con...
# 22            alt.atheism  In article <16BA1E927.DRPORTER@SUVM.SYR.EDU>, ...
# 23            alt.atheism  In article <j0=5l3=@rpi.edu>, johnsd2@jec322.i...
# 24            alt.atheism  In article <930405.172903.4w6.rusnews.w165w@ma...
# 25            alt.atheism  livesey@solntze.wpd.sgi.com (Jon Livesey) writ...
# 26            alt.atheism  livesey@solntze.wpd.sgi.com (Jon Livesey) writ...
# 27            alt.atheism  In article <199304041750.AA17104@kepler.unh.ed...
# 28            alt.atheism  In article <C4rzz2.47J@unix.portal.com> danb@s...
# 29            alt.atheism  In article <1993Apr3.214741.14026@ultb.isc.rit...
# ...                   ...                                                ...
# 19967  talk.religion.misc  In article <1993Apr26.150845.28537@advtech.usw...
# 19968  talk.religion.misc       The following partial summary of a Theory...
# 19969  talk.religion.misc  In article <1993Apr23.163823.24226@ads.com> wm...
# 19970  talk.religion.misc  Jeremiah:25:27 Therefore thou shalt say unto t...
# 19971  talk.religion.misc  In article <1f2P02UA40zB01@JUTS.ccc.amdahl.com...
# 19972  talk.religion.misc  In article <lefty-260493134641@lefty.apple.com...
# 19973  talk.religion.misc  netd@susie.sbc.com () writes:> In article <20A...
# 19974  talk.religion.misc  In article <1993Apr26.215627.24917@organpipe.u...
# 19975  talk.religion.misc       I wasn't sure if this was the right newsg...
# 19976  talk.religion.misc  >I'm curious to know if Christians ever read b...
# 19977  talk.religion.misc  In article <26APR199315363120@rigel.tamu.edu> ...
# 19978  talk.religion.misc  king@ctron.com (John E. King) writes:>scharle@...
# 19979  talk.religion.misc  I am pleased to announce that a *revised versi...
# 19980  talk.religion.misc  In article <C5vGyD.H7s@acsu.buffalo.edu> psyro...
# 19981  talk.religion.misc  Mark McCullough (mccullou@snake2.cs.wisc.edu) ...
# 19982  talk.religion.misc  In article <1r7os6$hil@agate.berkeley.edu> isa...
# 19983  talk.religion.misc  In article <1rc9vg$9be@squick.eitech.com> ekr@...
# 19984  talk.religion.misc  In article <1993Apr26.163627.11364@csrd.uiuc.e...
# 19985  talk.religion.misc  In article <1993Apr15.012537.26867@nntpd2.cxo....
# 19986  talk.religion.misc  On 26-Apr-93 in Re: What part of "No" don't..u...
# 19987  talk.religion.misc      In the King James Version of the Bible the...
# 19988  talk.religion.misc  muttiah@thistle.ecn.purdue.edu (Ranjan S Mutti...
# 19989  talk.religion.misc  joakimr@ifi.uio.no (Joakim Ruud) writes:>Recen...
# 19990  talk.religion.misc  pboxrud@magnus.acs.ohio-state.edu (Paul D Boxr...
# 19991  talk.religion.misc  In article <1993Apr23.111105.7703@ifi.uio.no>,...
# 19992  talk.religion.misc  In article <930426.140835.4f1.rusnews.w165w@ma...
# 19993  talk.religion.misc  In article <1993Apr27.073723.18577@csis.dit.cs...
# 19994  talk.religion.misc  In article <1rc1f3INN7rl@emx.cc.utexas.edu> bi...
# 19995  talk.religion.misc  In article <1993Apr26.231845.13843@digi.lonest...
# 19996  talk.religion.misc  In article <C64H4w.BFH@darkside.osrhe.uoknor.e...
#
# [19997 rows x 2 columns]

# %%
data1 = df_
shuffled_indices = np.random.permutation(np.arange(len(data1)))
data1 = data1.reset_index(drop=True)
train_proportion = 0.8

shuffled_df = data1.reindex(np.random.permutation(data1.index))
shuffled_df = shuffled_df.reset_index(drop=True)
df_train = shuffled_df[0:int(math.floor(train_proportion*len(shuffled_df)))]
df_test = shuffled_df[int(math.floor(train_proportion*len(shuffled_df))+1):len(shuffled_df)]
df_train = df_train.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

def review_to_words(raw_review):
    review_text = BeautifulSoup(raw_review).get_text()    
    letters_only = re.sub("[^a-zA-Z]", " ", review_text) 
    words = letters_only.lower().split()                             
    stops = set(nltk.corpus.stopwords.words('english'))
    meaningful_words = [w for w in words if not w in stops] 
    return( " ".join( meaningful_words ))

# %%
def perf_measure(y_actual, y_hat, metric=[]):
    TN, TP, FN, TP = confusion_matrix(y_actual, y_hat).ravel()

    if metric == 'sensitivity':
        return TP/(TP+FP)
    elif metric == 'specificity':
        return TN/(TN+FN)
    else:
        return(TP, FP, TN, FN)

# %%
stopwords = nltk.corpus.stopwords.words('english')
stopwords
# Out:
# [u'i',
#  u'me',
#  u'my',
#  u'myself',
#  u'we',
#  u'our',
#  u'ours',
#  u'ourselves',
#  u'you',
#  u'your',
#  u'yours',
#  u'yourself',
#  u'yourselves',
#  u'he',
#  u'him',
#  u'his',
#  u'himself',
#  u'she',
#  u'her',
#  u'hers',
#  u'herself',
#  u'it',
#  u'its',
#  u'itself',
#  u'they',
#  u'them',
#  u'their',
#  u'theirs',
#  u'themselves',
#  u'what',
#  u'which',
#  u'who',
#  u'whom',
#  u'this',
#  u'that',
#  u'these',
#  u'those',
#  u'am',
#  u'is',
#  u'are',
#  u'was',
#  u'were',
#  u'be',
#  u'been',
#  u'being',
#  u'have',
#  u'has',
#  u'had',
#  u'having',
#  u'do',
#  u'does',
#  u'did',
#  u'doing',
#  u'a',
#  u'an',
#  u'the',
#  u'and',
#  u'but',
#  u'if',
#  u'or',
#  u'because',
#  u'as',
#  u'until',
#  u'while',
#  u'of',
#  u'at',
#  u'by',
#  u'for',
#  u'with',
#  u'about',
#  u'against',
#  u'between',
#  u'into',
#  u'through',
#  u'during',
#  u'before',
#  u'after',
#  u'above',
#  u'below',
#  u'to',
#  u'from',
#  u'up',
#  u'down',
#  u'in',
#  u'out',
#  u'on',
#  u'off',
#  u'over',
#  u'under',
#  u'again',
#  u'further',
#  u'then',
#  u'once',
#  u'here',
#  u'there',
#  u'when',
#  u'where',
#  u'why',
#  u'how',
#  u'all',
#  u'any',
#  u'both',
#  u'each',
#  u'few',
#  u'more',
#  u'most',
#  u'other',
#  u'some',
#  u'such',
#  u'no',
#  u'nor',
#  u'not',
#  u'only',
#  u'own',
#  u'same',
#  u'so',
#  u'than',
#  u'too',
#  u'very',
#  u's',
#  u't',
#  u'can',
#  u'will',
#  u'just',
#  u'don',
#  u'should',
#  u'now',
#  u'd',
#  u'll',
#  u'm',
#  u'o',
#  u're',
#  u've',
#  u'y',
#  u'ain',
#  u'aren',
#  u'couldn',
#  u'didn',
#  u'doesn',
#  u'hadn',
#  u'hasn',
#  u'haven',
#  u'isn',
#  u'ma',
#  u'mightn',
#  u'mustn',
#  u'needn',
#  u'shan',
#  u'shouldn',
#  u'wasn',
#  u'weren',
#  u'won',
#  u'wouldn']

# %%
num_paths_train = df_train["document"].size
num_paths_test = df_test["document"].size
#print num_paths_test
clean_paths_train = []
clean_paths_test = []

for i in xrange(0, num_paths_train):
    clean_paths_train.append(review_to_words(df_train["document"][i]))

for i in xrange(0, num_paths_test):
    clean_paths_test.append(review_to_words(df_test["document"][i]))

# %%
collapsed_train = ' '.join(clean_paths_train)
print 'vectorizing'
vectorizer = CountVectorizer(analyzer = "word",ngram_range=(1,6),tokenizer = None,preprocessor = None,stop_words = None, max_features=10000) 
print 'transforming'
train_data_features = vectorizer.fit_transform(clean_paths_train)
print 'transforming complete'
train_data_features = train_data_features.toarray()
vocab = vectorizer.get_feature_names()
dist = np.sum(train_data_features, axis=0)
for tag, count in zip(vocab, dist):
    print count, tag
# Out:
# vectorizing
# transforming
# transforming complete
# 123 aa
# 60 aaa
# 107 aaron
# 199 ab
# 41 abandoned
# 125 abc
# 73 abiding
# 336 ability
# 1322 able
# 44 able find
# 89 able get
# 41 able use
# 343 abortion
# 71 abortions
# 58 aboutthe
# 48 abraham
# 61 abs
# 68 absence
# 298 absolute
# 44 absolute truth
# 320 absolutely
# 67 absolutes
# 71 abstract
# 112 absurd
# 44 abu
# 200 abuse
# 39 abused
# 41 abuses
# 890 ac
# 42 ac il
# 50 ac nz
# 403 ac uk
# 47 ac za
# 69 acad
# 44 acad alaska
# 43 acad alaska edu
# 39 acad alaska edu high
# 83 academic
# 45 acc
# 56 accelerated
# 60 acceleration
# 92 accelerator
# 43 accelerators
# 592 accept
# 184 acceptable
# 71 acceptance
# 255 accepted
# 62 accepting
# 46 accepts
# 951 access
# 128 access digex
# 104 access digex com
# 45 access digex com pat
# 41 access digex com pat writes
# 151 accident
# 60 accidental
# 79 accidents
# 64 accomplish
# 58 accomplished
# 59 accord
# 641 according
# 352 account
# 135 accounts
# 148 accuracy
# 40 accuracy information
# 39 accuracy information errors
# 39 accuracy information errors omissions
# 39 accuracy information errors omissions excepted
# 246 accurate
# 47 accurately
# 44 accuse
# 79 accused
# 43 ace
# 100 achieve
# 69 achieved
# 130 acid
# 54 acknowledge
# 53 aclu
# 66 acm
# 51 acns
# 52 acquire
# 58 acquired
# 365 across
# 227 acs
# 106 acs ohio
# 106 acs ohio state
# 104 acs ohio state edu
# 45 acsu
# 45 acsu buffalo
# 43 acsu buffalo edu
# 534 act
# 47 acted
# 81 acting
# 564 action
# 417 actions
# 229 active
# 46 actively
# 44 activists
# 284 activities
# 70 activities net
# 240 activity
# 319 acts
# 296 actual
# 1653 actually
# 297 ad
# 189 adam
# 184 adams
# 39 adams nsmca
# 39 adams nsmca acad
# 39 adams nsmca acad alaska
# 39 adams nsmca acad alaska edu
# 39 adams nsmca acad alaska edu high
# 109 adaptec
# 156 adapter
# 39 adaptor
# 651 add
# 319 added
# 124 adding
# 331 addition
# 258 additional
# 39 additionally
# 38 additions
# 938 address
# 74 addressed
# 171 addresses
# 70 addressing
# 75 adds
# 63 adequate
# 51 adirondack
# 62 adjust
# 40 adjusted
# 253 adl
# 62 admin
# 410 administration
# 50 administration official
# 88 administrator
# 43 admission
# 264 admit
# 78 admitted
# 47 admittedly
# 47 admitting
# 164 adobe
# 72 adobe com
# 40 adopt
# 54 adopted
# 102 ads
# 59 adult
# 74 adults
# 647 advance
# 189 advanced
# 243 advantage
# 65 advantages
# 39 advertised
# 89 advertising
# 352 advice
# 70 advocate
# 47 advocates
# 59 ae
# 39 aerospace
# 71 af
# 53 affair
# 105 affairs
# 134 affect
# 93 affected
# 181 afford
# 243 afraid
# 65 africa
# 92 african
# 67 afternoon
# 50 afterwards
# 50 ag
# 373 age
# 263 agencies
# 232 agency
# 112 agenda
# 162 agent
# 310 agents
# 68 ages
# 40 aggression
# 43 aggressive
# 1014 ago
# 991 agree
# 157 agreed
# 170 agreement
# 47 agreements
# 45 agrees
# 220 ah
# 250 ahead
# 131 ahl
# 198 ai
# 73 ai uga
# 73 ai uga edu
# 145 aid
# 265 aids
# 70 aim
# 64 aimed
# 505 air
# 44 air force
# 89 aircraft
# 79 aix
# 54 aj
# 63 ak
# 82 aka
# 568 al
# 42 ala
# 220 alan
# 68 alarm
# 120 alaska
# 91 alaska edu
# 39 alaska edu high
# 41 alaska edu writes
# 40 albany
# 85 albert
# 56 alchemy
# 111 alcohol
# 40 alert
# 71 alex
# 104 alexander
# 103 alexia
# 103 alexia lis
# 103 alexia lis uiuc
# 103 alexia lis uiuc edu
# 61 alexia lis uiuc edu mike
# 61 alexia lis uiuc edu mike cobb
# 388 algorithm
# 127 algorithms
# 40 ali
# 46 alias
# 42 alice
# 55 alien
# 66 alike
# 79 alink
# 70 alink ksand
# 70 alink ksand private
# 70 alink ksand private activities
# 70 alink ksand private activities net
# 43 alittle
# 259 alive
# 52 allah
# 70 allan
# 47 allegations
# 93 alleged
# 166 allen
# 57 allergic
# 75 allies
# 73 allocation
# 42 allocation unit
# 527 allow
# 395 allowed
# 143 allowing
# 291 allows
# 41 allthe
# 42 almanac
# 848 almost
# 46 almost certainly
# 102 alomar
# 394 alone
# 528 along
# 42 along lines
# 128 alot
# 105 alpha
# 1058 already
# 5675 also
# 98 also available
# 44 also heard
# 41 also interested
# 46 also know
# 60 also like
# 38 also need
# 60 also said
# 45 also think
# 39 also use
# 44 also used
# 462 alt
# 103 alt atheism
# 41 alter
# 39 alternate
# 227 alternative
# 86 alternatives
# 844 although
# 63 altitude
# 61 altogether
# 52 aluminum
# 1270 always
# 124 ama
# 47 amanda
# 137 amateur
# 78 amateur radio
# 42 amateur radio tmi
# 46 amazed
# 119 amazing
# 39 ambassador
# 40 amd
# 38 amend
# 339 amendment
# 423 america
# 1000 american
# 39 american people
# 384 americans
# 120 ames
# 52 ami
# 283 amiga
# 51 amiga amiga
# 46 amiga amiga amiga
# 43 amiga amiga amiga amiga
# 40 amiga amiga amiga amiga amiga
# 68 ammunition
# 607 among
# 42 among others
# 38 among things
# 57 amongst
# 443 amount
# 116 amounts
# 154 amp
# 41 amplifier
# 51 amps
# 40 amusing
# 87 analog
# 42 analogous
# 101 analogy
# 352 analysis
# 51 analyst
# 61 anatolia
# 158 ancient
# 144 anderson
# 60 andgeb
# 60 andgeb cadre
# 60 andgeb cadre dsl
# 60 andgeb cadre dsl pitt
# 60 andgeb cadre dsl pitt edu
# 60 andgeb cadre dsl pitt edu shameful
# 119 andi
# 41 andi beyer
# 99 andre
# 53 andre beck
# 469 andrew
# 109 andrew cmu
# 104 andrew cmu edu
# 142 andthe
# 288 andy
# 55 anecdotal
# 48 angel
# 217 angeles
# 135 angels
# 70 anger
# 87 angle
# 75 angry
# 110 animal
# 169 animals
# 124 animation
# 85 ankara
# 93 ann
# 51 ann arbor
# 47 anniversary
# 76 announce
# 174 announced
# 110 announcement
# 100 announcing
# 51 announcing announcing
# 87 annoying
# 167 annual
# 80 anon
# 89 anonymity
# 438 anonymous
# 208 anonymous ftp
# 40 anonymous posting
# 2118 another
# 40 another one
# 65 another way
# 65 ansi
# 1003 answer
# 126 answer question
# 53 answer questions
# 148 answered
# 67 answering
# 377 answers
# 78 antenna
# 119 anthony
# 38 anthony landreneau
# 601 anti
# 45 anti gun
# 44 anti semitism
# 768 anybody
# 50 anybody else
# 133 anybody know
# 45 anyhow
# 189 anymore
# 3312 anyone
# 45 anyone could
# 280 anyone else
# 46 anyone experience
# 38 anyone help
# 44 anyone interested
# 511 anyone know
# 67 anyone knows
# 74 anyone tell
# 38 anyone would
# 1864 anything
# 111 anything else
# 51 anything like
# 865 anyway
# 50 anyways
# 234 anywhere
# 46 aol
# 109 ap
# 175 apart
# 186 apartment
# 42 api
# 105 apollo
# 42 apollo hp
# 40 apollo hp com
# 75 apologies
# 66 apologize
# 40 apostle
# 75 apostles
# 212 app
# 49 app defaults
# 126 apparent
# 379 apparently
# 100 appeal
# 39 appeals
# 358 appear
# 86 appearance
# 153 appeared
# 472 appears
# 869 apple
# 252 apple com
# 70 apple com alink
# 70 apple com alink ksand
# 70 apple com alink ksand private
# 70 apple com alink ksand private activities
# 56 apple com kent
# 56 apple com kent sandvik
# 52 apple com kent sandvik writes
# 49 applicable
# 614 application
# 463 applications
# 193 applied
# 143 applies
# 356 apply
# 45 applying
# 44 appointed
# 336 appreciate
# 38 appreciate help
# 524 appreciated
# 98 appreciated thanks
# 123 appressian
# 110 appressian soviet
# 110 appressian soviet armenia
# 110 appressian soviet armenia today
# 110 appressian soviet armenia today longer
# 110 appressian soviet armenia today longer exists
# 343 approach
# 82 approaches
# 38 approaching
# 336 appropriate
# 67 approval
# 137 approved
# 54 approx
# 98 approximately
# 128 apps
# 470 apr
# 184 apr gmt
# 868 april
# 44 april th
# 42 apt
# 48 aq
# 190 ar
# 464 arab
# 64 arabia
# 256 arabs
# 89 arbitrary
# 54 arbor
# 104 arc
# 45 arc nasa
# 44 arc nasa gov
# 81 archie
# 54 architecture
# 364 archive
# 74 archive name
# 114 archives
# 867 area
# 331 areas
# 85 arena
# 47 arens
# 93 arf
# 146 argic
# 111 argic closed
# 110 argic closed roads
# 110 argic closed roads mountain
# 110 argic closed roads mountain passes
# 110 argic closed roads mountain passes might
# 84 args
# 253 argue
# 69 argued
# 109 arguing
# 725 argument
# 311 arguments
# 50 argv
# 44 arise
# 80 arithmetic
# 172 arizona
# 113 arizona edu
# 170 arm
# 285 armed
# 518 armenia
# 118 armenia today
# 113 armenia today longer
# 113 armenia today longer exists
# 113 armenia today longer exists single
# 113 armenia today longer exists single turkish
# 903 armenian
# 48 armenian genocide
# 39 armenian genocide million
# 94 armenian government
# 760 armenians
# 64 armored
# 500 arms
# 387 army
# 54 army mil
# 46 arnold
# 1803 around
# 41 around world
# 75 array
# 40 arrays
# 102 arrest
# 60 arrested
# 40 arrive
# 94 arrived
# 65 arrogance
# 100 arrogant
# 120 arromdee
# 58 arromdee jyusenkyou
# 58 arromdee jyusenkyou cs
# 58 arromdee jyusenkyou cs jhu
# 58 arromdee jyusenkyou cs jhu edu
# 39 arromdee jyusenkyou cs jhu edu ken
# 355 art
# 109 arthur
# 9972 article
# 54 article cobb
# 54 article cobb alexia
# 54 article cobb alexia lis
# 54 article cobb alexia lis uiuc
# 54 article cobb alexia lis uiuc edu
# 54 article cramer
# 54 article cramer optilink
# 54 article cramer optilink com
# 54 article cramer optilink com clayton
# 54 article cramer optilink com clayton cramer
# 49 article ekr
# 162 article frank
# 161 article frank uucp
# 157 article frank uucp frank
# 157 article frank uucp frank dwyer
# 141 article frank uucp frank dwyer writes
# 44 article hallam
# 40 article king
# 52 article livesey
# 52 article livesey solntze
# 52 article livesey solntze wpd
# 52 article livesey solntze wpd sgi
# 52 article livesey solntze wpd sgi com
# 52 article mathew
# 41 article mathew writes
# 43 article sandvik
# 43 article sandvik newton
# 43 article sandvik newton apple
# 43 article sandvik newton apple com
# 43 article sandvik newton apple com kent
# 69 article writes
# 324 articles
# 108 artificial
# 58 artificial intelligence
# 42 artificial intelligence programs
# 41 artillery
# 54 arts
# 52 asa
# 60 asala
# 44 asala sdpa
# 42 asala sdpa arf
# 91 ascii
# 175 aside
# 1071 ask
# 40 ask questions
# 681 asked
# 52 asked questions
# 530 asking
# 84 asks
# 83 aspect
# 147 aspects
# 51 aspi
# 41 aspi dos
# 133 ass
# 206 assault
# 130 assembly
# 90 assert
# 175 assertion
# 42 assessment
# 42 assign
# 41 assigned
# 68 assist
# 113 assistance
# 59 assistant
# 135 associate
# 175 associated
# 55 associates
# 177 association
# 574 assume
# 160 assumed
# 86 assumes
# 302 assuming
# 183 assumption
# 95 assumptions
# 44 assure
# 52 assured
# 42 asthe
# 104 astro
# 48 astronaut
# 47 astronomers
# 67 astronomical
# 178 astronomy
# 44 astros
# 38 aswell
# 39 asynchronous
# 47 ata
# 85 atari
# 38 ate
# 277 atf
# 50 atf fbi
# 390 atheism
# 290 atheist
# 324 atheists
# 154 athena
# 80 athena mit
# 74 athena mit edu
# 73 athens
# 43 athens georgia
# 42 athens georgia amateur
# 42 athens georgia amateur radio
# 42 athens georgia amateur radio tmi
# 201 ati
# 38 ati graphics
# 63 ati ultra
# 213 atlanta
# 46 atlantaga
# 46 atlantaga ncr
# 39 atlantaga ncr com
# 74 atlantic
# 63 atlas
# 68 atleast
# 42 atm
# 141 atmosphere
# 58 atmospheric
# 42 atom
# 99 atomic
# 100 atoms
# 56 atrocities
# 341 att
# 265 att com
# 44 attach
# 126 attached
# 417 attack
# 132 attacked
# 91 attacking
# 229 attacks
# 363 attempt
# 91 attempted
# 114 attempting
# 161 attempts
# 49 attend
# 40 attendance
# 255 attention
# 80 atthe
# 228 attitude
# 179 attorney
# 122 attorney general
# 42 attractive
# 49 attribute
# 80 attributed
# 51 attributes
# 517 au
# 65 audience
# 230 audio
# 56 aug
# 145 august
# 49 aurora
# 44 aurora alaska
# 44 aurora alaska edu
# 40 aurora alaska edu writes
# 181 austin
# 70 austin ibm
# 69 austin ibm com
# 187 australia
# 58 austria
# 414 author
# 222 authorities
# 337 authority
# 73 authorized
# 131 authors
# 305 auto
# 43 autoexec
# 40 automated
# 231 automatic
# 53 automatic weapons
# 153 automatically
# 57 automobile
# 115 autos
# 54 av
# 87 availability
# 1823 available
# 50 available anonymous
# 49 available anonymous ftp
# 48 available ftp
# 107 available via
# 64 available via anonymous
# 56 available via anonymous ftp
# 95 ave
# 84 avenue
# 465 average
# 374 avoid
# 64 avoided
# 103 aw
# 82 award
# 319 aware
# 39 awareness
# 1220 away
# 57 awesome
# 121 awful
# 42 awful lot
# 30962 ax
# 27931 ax ax
# 25119 ax ax ax
# 22450 ax ax ax ax
# 19926 ax ax ax ax ax
# 17567 ax ax ax ax ax ax
# 1933 ax ax ax ax ax max
# 1969 ax ax ax ax max
# 1933 ax ax ax ax max ax
# 2033 ax ax ax max
# 1976 ax ax ax max ax
# 1947 ax ax ax max ax ax
# 2086 ax ax max
# 2019 ax ax max ax
# 1988 ax ax max ax ax
# 1944 ax ax max ax ax ax
# 2148 ax max
# 2077 ax max ax
# 2042 ax max ax ax
# 1992 ax max ax ax ax
# 1956 ax max ax ax ax ax
# 64 axe
# 61 axis
# 66 az
# 232 azerbaijan
# 142 azerbaijani
# 92 azerbaijanis
# 142 azeri
# 99 azeris
# 105 ba
# 77 baalke
# 89 babies
# 159 baby
# 2597 back
# 82 backed
# 225 background
# 53 backing
# 183 backup
# 40 backups
# 46 bacteria
# 1285 bad
# 41 bad idea
# 39 baden
# 86 badly
# 56 baerga
# 99 bag
# 43 bagged
# 38 bailey
# 59 bait
# 115 baker
# 39 baker writes
# 137 baku
# 105 balance
# 58 balanced
# 66 balcony
# 256 ball
# 48 balloon
# 100 balls
# 142 baltimore
# 104 ban
# 162 band
# 70 bands
# 101 bandwidth
# 51 bang
# 235 bank
# 172 banks
# 65 banks jxp
# 65 banks jxp skepticism
# 65 banks jxp skepticism chastity
# 65 banks jxp skepticism chastity intellect
# 60 banks jxp skepticism chastity intellect andgeb
# 80 banned
# 99 baptism
# 46 baptist
# 143 bar
# 44 barbara
# 53 bare
# 44 barely
# 39 barrasso
# 55 barrel
# 75 barry
# 66 bars
# 448 base
# 526 baseball
# 1332 based
# 48 based upon
# 116 bases
# 41 bashing
# 466 basic
# 352 basically
# 476 basis
# 38 basketball
# 55 bastard
# 179 bat
# 63 batch
# 510 batf
# 60 batf fbi
# 41 bathroom
# 62 batman
# 55 batter
# 103 batteries
# 42 batters
# 258 battery
# 108 batting
# 139 battle
# 81 baud
# 181 bay
# 67 bay area
# 88 bb
# 396 bbs
# 210 bc
# 93 bc ca
# 287 bd
# 65 bds
# 118 beach
# 73 beam
# 40 bean
# 356 bear
# 159 bear arms
# 67 bearing
# 61 bears
# 113 beast
# 242 beat
# 64 beaten
# 103 beating
# 60 beats
# 54 beauchaine
# 95 beautiful
# 55 beauty
# 267 became
# 65 beck
# 58 beckman
# 667 become
# 227 becomes
# 144 becoming
# 95 bed
# 52 bedroom
# 91 beer
# 220 began
# 301 begin
# 317 beginning
# 101 begins
# 60 begun
# 47 behalf
# 68 behanna
# 45 behave
# 279 behavior
# 93 behaviour
# 535 behind
# 38 behold
# 137 beings
# 65 beleive
# 483 belief
# 310 beliefs
# 2746 believe
# 101 believe god
# 61 believe speak
# 61 believe speak company
# 61 believe speak company cdt
# 61 believe speak company cdt vos
# 61 believe speak company cdt vos stratus
# 231 believed
# 69 believer
# 97 believers
# 160 believes
# 149 believing
# 232 bell
# 59 bellcore
# 49 bellcore com
# 135 belong
# 39 belonging
# 67 belongs
# 78 belt
# 95 ben
# 51 bench
# 61 benedikt
# 190 benefit
# 108 benefits
# 48 benjamin
# 349 berkeley
# 261 berkeley edu
# 40 berkeley edu dennis
# 38 berkeley edu dennis kriz
# 75 berlin
# 298 besides
# 1728 best
# 91 best offer
# 75 best way
# 226 bet
# 131 beta
# 52 beth
# 2382 better
# 41 beware
# 54 beyer
# 346 beyond
# 66 bh
# 188 bhj
# 57 bhj bhj
# 103 bi
# 87 bias
# 78 biased
# 984 bible
# 39 bible says
# 165 biblical
# 38 bibliography
# 1121 big
# 75 big brother
# 58 big deal
# 59 big enough
# 140 bigger
# 133 biggest
# 61 bigotry
# 614 bike
# 69 biker
# 43 bikers
# 150 bikes
# 1206 bill
# 108 bill clinton
# 40 bill mr
# 53 bill rawlins
# 58 bill rights
# 44 billboard
# 260 billion
# 38 billions
# 54 bills
# 43 billy
# 130 bin
# 106 binaries
# 111 binary
# 56 binding
# 49 bio
# 42 biochemistry
# 84 biological
# 94 biology
# 284 bios
# 80 bird
# 146 birth
# 144 bis
# 39 bishop
# 42 bison
# 39 bison mb
# 2091 bit
# 60 bit color
# 49 bit image
# 41 bit images
# 108 bitmap
# 337 bitnet
# 403 bits
# 69 biz
# 39 bizarre
# 145 bj
# 822 black
# 87 black hole
# 45 black holes
# 38 black panther
# 70 black white
# 39 blackhawks
# 69 blacks
# 84 blah
# 52 blah blah
# 197 blame
# 77 blank
# 46 blast
# 78 blessed
# 68 blew
# 149 blind
# 42 blindly
# 42 blinking
# 314 block
# 97 blocks
# 356 blood
# 57 bloody
# 127 blow
# 62 blowing
# 70 blown
# 490 blue
# 38 blue book
# 61 blue jays
# 182 blues
# 41 blvd
# 83 bm
# 103 bmp
# 40 bmug
# 244 bmw
# 77 bn
# 206 bnr
# 154 bnr ca
# 62 bo
# 677 board
# 42 board service
# 234 boards
# 578 bob
# 54 bob waldrop
# 55 bobbe
# 55 bobbe vice
# 53 bobbe vice ico
# 53 bobbe vice ico tek
# 53 bobbe vice ico tek com
# 111 bobby
# 219 bodies
# 46 bodily
# 709 body
# 97 boeing
# 58 boeing com
# 67 boggs
# 65 bogus
# 39 bohr
# 47 bold
# 52 bolt
# 130 bomb
# 94 bombing
# 38 bombs
# 127 bonds
# 61 bone
# 55 bones
# 49 bontchev
# 38 bonus
# 152 bony
# 75 bony bony
# 75 bony bony com
# 47 bony bony com ten
# 47 bony bony com ten years
# 47 bony bony com ten years george
# 75 bony com
# 47 bony com ten
# 47 bony com ten years
# 47 bony com ten years george
# 47 bony com ten years george bush
# 1186 book
# 40 booklet
# 647 books
# 61 boomer
# 83 boost
# 173 boot
# 40 booth
# 62 boots
# 165 border
# 92 borders
# 56 boring
# 46 borland
# 294 born
# 253 bos
# 209 bosnia
# 142 bosnian
# 57 bosnian muslims
# 68 boss
# 379 boston
# 160 bother
# 58 bothered
# 39 bothers
# 49 bottle
# 181 bottom
# 39 bottom line
# 469 bought
# 91 boulder
# 126 bound
# 43 boundaries
# 50 bowman
# 917 box
# 185 boxes
# 191 boy
# 39 boyle
# 84 boys
# 40 bp
# 99 bps
# 43 bq
# 131 br
# 53 br com
# 192 brad
# 125 bradley
# 53 brady
# 278 brain
# 68 brains
# 124 brake
# 84 brakes
# 52 braking
# 275 branch
# 120 branch davidians
# 197 brand
# 89 brand new
# 48 brandeis
# 38 brandeis edu
# 40 brands
# 47 brave
# 196 braves
# 45 bread
# 416 break
# 69 breaker
# 124 breaking
# 67 breaks
# 75 breast
# 55 breath
# 111 brent
# 39 brent irvine
# 124 brett
# 552 brian
# 62 brian kendig
# 95 brief
# 46 briefing
# 46 briefly
# 95 bright
# 379 bring
# 71 bringing
# 95 brings
# 47 bristol
# 101 britain
# 308 british
# 44 british columbia
# 81 broad
# 108 broadcast
# 124 broke
# 212 broken
# 45 brooks
# 246 brother
# 111 brothers
# 373 brought
# 236 brown
# 225 bruce
# 162 bruins
# 80 bryan
# 105 bs
# 91 bsd
# 41 bskendig
# 41 bskendig netcom
# 41 bskendig netcom com
# 52 bt
# 399 btw
# 159 bu
# 114 bu edu
# 67 buck
# 88 bucks
# 167 budget
# 208 buf
# 308 buffalo
# 145 buffalo edu
# 152 buffer
# 170 bug
# 115 bugs
# 533 build
# 536 building
# 83 buildings
# 535 built
# 41 bulk
# 103 bull
# 116 bullet
# 73 bulletin
# 49 bulletin board
# 42 bulletin board service
# 91 bullets
# 128 bullock
# 45 bullpen
# 97 bullshit
# 45 bumper
# 273 bunch
# 40 buphy
# 40 buphy bu
# 40 buphy bu edu
# 90 burden
# 55 bure
# 64 bureau
# 42 buried
# 158 burn
# 173 burned
# 153 burning
# 45 burns
# 43 burnt
# 83 burst
# 85 bursts
# 648 bus
# 38 buses
# 209 bush
# 44 bush willamerican
# 44 bush willamerican occupied
# 44 bush willamerican occupied new
# 44 bush willamerican occupied new york
# 44 bush willamerican occupied new york replaced
# 664 business
# 52 businesses
# 89 busy
# 68 buti
# 45 butit
# 57 butt
# 223 button
# 63 buttons
# 938 buy
# 50 buy one
# 66 buyer
# 289 buying
# 38 bw
# 47 bx
# 56 bye
# 117 byte
# 198 bytes
# 70 bythe
# 2072 ca
# 57 ca us
# 79 ca writes
# 50 cabinet
# 393 cable
# 83 cables
# 196 cache
# 53 cactus
# 39 cactus org
# 80 cad
# 71 cadre
# 63 cadre dsl
# 63 cadre dsl pitt
# 63 cadre dsl pitt edu
# 63 cadre dsl pitt edu shameful
# 63 cadre dsl pitt edu shameful surrender
# 81 cage
# 240 cal
# 41 calcium
# 40 calculate
# 50 calculations
# 44 calendar
# 118 calgary
# 361 california
# 1470 call
# 41 callback
# 1524 called
# 279 calling
# 76 callison
# 319 calls
# 66 calm
# 57 calpoly
# 56 calpoly edu
# 179 caltech
# 156 caltech edu
# 104 cam
# 47 camaro
# 196 cambridge
# 1006 came
# 45 came back
# 132 camera
# 59 cameras
# 90 camp
# 136 campaign
# 68 campbell
# 62 camps
# 103 campus
# 617 canada
# 207 canadian
# 73 canadians
# 47 canadiens
# 51 canbe
# 42 canberra
# 313 cancer
# 109 candida
# 83 candidate
# 120 candidates
# 1068 cannot
# 141 canon
# 55 cant
# 82 canucks
# 73 cap
# 88 capabilities
# 149 capability
# 212 capable
# 41 capacitor
# 94 capacity
# 65 cape
# 126 capital
# 70 capitals
# 161 caps
# 99 captain
# 80 capture
# 57 captured
# 1652 car
# 57 carbon
# 1370 card
# 44 cardinals
# 428 cards
# 941 care
# 42 care taken
# 40 care taken ensure
# 40 care taken ensure accuracy
# 39 care taken ensure accuracy information
# 39 care taken ensure accuracy information errors
# 172 career
# 159 careful
# 145 carefully
# 108 cares
# 133 carl
# 114 carleton
# 96 carleton ca
# 59 carolina
# 53 carpenter
# 208 carried
# 58 carrier
# 38 carriers
# 73 carries
# 403 carry
# 191 carrying
# 567 cars
# 54 carson
# 114 carter
# 44 carter themy
# 44 carter themy opinions
# 44 carter themy opinions employer
# 44 carter themy opinions employer opinions
# 44 carter themy opinions employer opinions standard
# 69 cartridge
# 49 cartridges
# 1829 case
# 524 cases
# 41 casey
# 103 cash
# 64 cassette
# 65 cast
# 41 casual
# 117 cat
# 100 catalog
# 140 catch
# 52 catcher
# 40 categories
# 90 category
# 240 catholic
# 46 catholic church
# 84 catholics
# 54 cats
# 41 caucasus
# 176 caught
# 850 cause
# 326 caused
# 230 causes
# 118 causing
# 249 cb
# 98 cb att
# 97 cb att com
# 58 cbc
# 53 cbr
# 820 cc
# 93 cc buffalo
# 91 cc buffalo edu
# 89 cc columbia
# 87 cc columbia edu
# 57 cc monash
# 57 cc monash edu
# 56 cc monash edu au
# 41 cc purdue
# 39 cc purdue edu
# 40 cc rochester
# 40 cc rochester edu
# 96 cc utexas
# 87 cc utexas edu
# 39 cci
# 102 cco
# 101 cco caltech
# 101 cco caltech edu
# 41 ccu
# 81 ccwf
# 79 ccwf cc
# 79 ccwf cc utexas
# 73 ccwf cc utexas edu
# 599 cd
# 160 cd rom
# 62 cdc
# 62 cdrom
# 47 cds
# 176 cdt
# 61 cdt rocket
# 61 cdt rocket sw
# 61 cdt rocket sw stratus
# 61 cdt rocket sw stratus com
# 61 cdt rocket sw stratus com believe
# 41 cdt sw
# 41 cdt sw stratus
# 41 cdt sw stratus com
# 40 cdt sw stratus com tavares
# 39 cdt sw stratus com tavares writes
# 61 cdt vos
# 61 cdt vos stratus
# 61 cdt vos stratus com
# 61 cdt vos stratus com write
# 61 cdt vos stratus com write today
# 48 ce
# 45 cease
# 65 cec
# 65 celebrate
# 55 celebration
# 98 cell
# 52 cellar
# 116 cells
# 94 cellular
# 45 cement
# 47 centaur
# 840 center
# 82 center policy
# 82 center policy research
# 39 center policy research writes
# 38 centerline
# 97 centers
# 189 central
# 117 centre
# 136 centris
# 40 cents
# 95 centuries
# 242 century
# 40 ceremonial
# 53 ceremony
# 713 certain
# 856 certainly
# 41 certainty
# 98 cf
# 66 cg
# 41 cgy
# 201 ch
# 141 chain
# 75 chair
# 39 chairman
# 109 challenge
# 42 challenged
# 49 chamber
# 51 champaign
# 74 champions
# 43 championships
# 80 champs
# 465 chance
# 126 chances
# 1082 change
# 407 changed
# 306 changes
# 192 changing
# 182 channel
# 74 channels
# 135 chapter
# 132 char
# 209 character
# 39 characteristic
# 59 characteristics
# 129 characters
# 304 charge
# 82 charged
# 128 charges
# 41 charging
# 41 charity
# 239 charles
# 76 charlie
# 38 chart
# 66 charter
# 57 chase
# 67 chastity
# 65 chastity intellect
# 60 chastity intellect andgeb
# 60 chastity intellect andgeb cadre
# 60 chastity intellect andgeb cadre dsl
# 60 chastity intellect andgeb cadre dsl pitt
# 351 cheap
# 220 cheaper
# 782 check
# 44 check io
# 181 checked
# 158 checking
# 81 checks
# 191 cheers
# 62 cheers kent
# 62 cheers kent sandvik
# 61 cheers kent sandvik newton
# 61 cheers kent sandvik newton apple
# 61 cheers kent sandvik newton apple com
# 48 chem
# 149 chemical
# 41 chemicals
# 150 chemistry
# 45 chen
# 78 cherry
# 51 chess
# 49 chest
# 38 chevy
# 251 chi
# 352 chicago
# 135 chief
# 468 child
# 64 child abuse
# 1160 children
# 67 china
# 119 chinese
# 1075 chip
# 324 chips
# 46 chipset
# 489 choice
# 93 choices
# 360 choose
# 49 chooses
# 52 choosing
# 52 chopin
# 51 chopin udel
# 45 chopin udel edu
# 138 chose
# 149 chosen
# 367 chris
# 45 chris behanna
# 847 christ
# 1028 christian
# 446 christianity
# 763 christians
# 62 christmas
# 38 christmas truelove
# 38 christmas truelove served
# 106 christopher
# 99 chronic
# 104 chuck
# 39 chuq
# 878 church
# 154 churches
# 49 chz
# 67 ci
# 91 cia
# 103 cica
# 45 cica indiana
# 41 cica indiana edu
# 41 cigarette
# 61 cincinnati
# 104 cipher
# 49 ciphers
# 58 ciphertext
# 46 circa
# 107 circle
# 66 circles
# 238 circuit
# 86 circuits
# 63 circular
# 173 circumstances
# 130 cis
# 83 cite
# 83 cited
# 173 cities
# 153 citizen
# 376 citizens
# 62 citizenship
# 678 city
# 50 civic
# 342 civil
# 76 civil rights
# 68 civil war
# 112 civilian
# 185 civilians
# 51 civilization
# 45 civilized
# 110 cj
# 63 ck
# 114 cl
# 962 claim
# 273 claimed
# 191 claiming
# 504 claims
# 43 claremont
# 39 claremont edu
# 54 clarify
# 39 clarinet
# 128 clark
# 58 clarke
# 75 clarkson
# 44 clarkson edu
# 431 class
# 41 class pay
# 41 class pay programs
# 99 classes
# 119 classic
# 39 classical
# 104 classified
# 46 clause
# 207 clayton
# 146 clayton cramer
# 54 clayton cramer uunet
# 54 clayton cramer uunet pyramid
# 54 clayton cramer uunet pyramid optilink
# 54 clayton cramer uunet pyramid optilink cramer
# 76 clayton cramer writes
# 217 clean
# 77 cleaning
# 59 cleansing
# 733 clear
# 40 cleared
# 491 clearly
# 72 clemens
# 254 cleveland
# 154 cleveland freenet
# 151 cleveland freenet edu
# 40 clever
# 156 clh
# 70 click
# 210 client
# 150 clients
# 42 cliff
# 73 clinic
# 128 clinical
# 657 clinton
# 68 clinton administration
# 75 clip
# 599 clipper
# 234 clipper chip
# 375 clock
# 93 clone
# 540 close
# 331 closed
# 122 closed roads
# 122 closed roads mountain
# 122 closed roads mountain passes
# 122 closed roads mountain passes might
# 122 closed roads mountain passes might serve
# 112 closely
# 151 closer
# 60 closest
# 44 closing
# 73 clothes
# 47 clothing
# 94 cloud
# 50 clouds
# 201 club
# 39 clubs
# 86 clue
# 219 clutch
# 97 cm
# 70 cmos
# 265 cmu
# 240 cmu edu
# 112 cnn
# 651 co
# 231 co uk
# 144 coach
# 44 coalition
# 86 coast
# 49 coat
# 214 cobb
# 102 cobb alexia
# 102 cobb alexia lis
# 102 cobb alexia lis uiuc
# 102 cobb alexia lis uiuc edu
# 61 cobb alexia lis uiuc edu mike
# 58 cobb writes
# 43 cocaine
# 46 cod
# 939 code
# 87 codes
# 60 coding
# 53 coffee
# 41 coincidence
# 120 col
# 255 cold
# 42 collaboration
# 61 collapse
# 70 collect
# 56 collected
# 39 collecting
# 143 collection
# 48 collective
# 323 college
# 53 collins
# 58 collision
# 890 color
# 363 colorado
# 169 colorado edu
# 107 colormap
# 303 colors
# 81 colostate
# 81 colostate edu
# 183 colour
# 63 colours
# 251 columbia
# 146 columbia edu
# 59 columbus
# 77 column
# 7753 com
# 70 com alink
# 70 com alink ksand
# 70 com alink ksand private
# 70 com alink ksand private activities
# 70 com alink ksand private activities net
# 62 com believe
# 61 com believe speak
# 61 com believe speak company
# 61 com believe speak company cdt
# 61 com believe speak company cdt vos
# 66 com bill
# 46 com bob
# 42 com brian
# 45 com chris
# 77 com clayton
# 77 com clayton cramer
# 72 com clayton cramer writes
# 56 com dave
# 114 com david
# 60 com david sternlight
# 58 com david sternlight writes
# 89 com eric
# 50 com eric rescorla
# 50 com eric rescorla writes
# 43 com jack
# 110 com jim
# 105 com john
# 42 com john king
# 41 com john king writes
# 105 com jon
# 86 com jon livesey
# 84 com jon livesey writes
# 58 com kent
# 56 com kent sandvik
# 52 com kent sandvik writes
# 132 com mark
# 68 com michael
# 40 com mike
# 46 com pat
# 41 com pat writes
# 49 com paul
# 39 com peter
# 56 com richard
# 74 com robert
# 117 com steve
# 40 com tavares
# 39 com tavares writes
# 47 com ten
# 47 com ten years
# 47 com ten years george
# 47 com ten years george bush
# 44 com ten years george bush willamerican
# 47 com tom
# 44 com uunet
# 63 com write
# 61 com write today
# 61 com write today special
# 61 com write today special investors
# 61 com write today special investors packet
# 295 com writes
# 75 com writes article
# 148 com wrote
# 43 combat
# 99 combination
# 97 combined
# 1920 come
# 68 come back
# 839 comes
# 84 comet
# 39 comfort
# 84 comfortable
# 43 comic
# 61 comics
# 578 coming
# 94 comm
# 463 command
# 43 command line
# 61 commander
# 47 commandment
# 93 commandments
# 170 commands
# 358 comment
# 58 commentary
# 464 comments
# 62 commerce
# 389 commercial
# 72 commission
# 105 commit
# 93 commitment
# 254 committed
# 291 committee
# 659 common
# 101 commonly
# 51 communicate
# 136 communication
# 302 communications
# 70 communist
# 80 communities
# 403 community
# 440 comp
# 74 comp graphics
# 88 comp sys
# 49 comp sys mac
# 58 comp windows
# 51 compact
# 388 companies
# 681 company
# 61 company cdt
# 61 company cdt vos
# 61 company cdt vos stratus
# 61 company cdt vos stratus com
# 61 company cdt vos stratus com write
# 52 compaq
# 95 comparable
# 231 compare
# 265 compared
# 66 comparing
# 168 comparison
# 55 compass
# 53 compatibility
# 290 compatible
# 57 compelled
# 49 compete
# 60 competing
# 101 competition
# 48 competitive
# 106 compile
# 94 compiled
# 79 compiler
# 100 complain
# 68 complaining
# 89 complaints
# 478 complete
# 70 completed
# 457 completely
# 220 complex
# 46 complexity
# 104 complicated
# 87 component
# 121 components
# 40 composed
# 59 composite
# 41 composition
# 366 compound
# 86 comprehensive
# 71 compress
# 108 compressed
# 231 compression
# 128 compromise
# 196 compuserve
# 84 compuserve com
# 55 compute
# 1483 computer
# 81 computer graphics
# 158 computer science
# 40 computer services
# 245 computers
# 225 computing
# 59 con
# 76 concealed
# 283 concept
# 56 conception
# 69 concepts
# 168 concern
# 273 concerned
# 162 concerning
# 123 concerns
# 99 conclude
# 60 concluded
# 38 concludes
# 252 conclusion
# 115 conclusions
# 103 concrete
# 76 condemn
# 38 condemnation
# 74 condemned
# 49 condemning
# 432 condition
# 200 conditions
# 109 conduct
# 75 conducted
# 53 conductor
# 369 conference
# 53 confidence
# 44 confident
# 48 confidential
# 105 config
# 59 config sys
# 171 configuration
# 42 configure
# 49 configured
# 55 confirm
# 80 confirmed
# 184 conflict
# 54 conflicts
# 56 confuse
# 148 confused
# 79 confusing
# 108 confusion
# 418 congress
# 43 congressional
# 60 conlon
# 166 connect
# 214 connected
# 248 connection
# 75 connections
# 150 connector
# 47 connectors
# 63 conner
# 58 conscience
# 66 conscious
# 48 consciousness
# 87 consensus
# 91 consent
# 42 consequence
# 112 consequences
# 38 consequently
# 102 conservative
# 751 consider
# 46 considerable
# 56 considerably
# 112 consideration
# 50 considerations
# 548 considered
# 312 considering
# 46 considers
# 181 consistent
# 75 consistently
# 75 consists
# 42 console
# 51 consortium
# 108 conspiracy
# 118 constant
# 82 constantly
# 41 constitute
# 42 constitutes
# 336 constitution
# 103 constitutional
# 39 construct
# 107 construction
# 50 consult
# 46 consultant
# 38 consulting
# 71 consumer
# 54 consumption
# 678 contact
# 66 contacts
# 160 contain
# 93 contained
# 155 containing
# 338 contains
# 45 contend
# 143 content
# 38 contention
# 122 contents
# 99 contest
# 385 context
# 46 continental
# 379 continue
# 149 continued
# 142 continues
# 90 continuing
# 47 continuous
# 124 contract
# 51 contracts
# 59 contradict
# 71 contradiction
# 74 contradictory
# 173 contrary
# 80 contrast
# 154 contrib
# 81 contribute
# 53 contributed
# 50 contribution
# 55 contributions
# 1130 control
# 135 controlled
# 507 controller
# 73 controller card
# 66 controllers
# 107 controls
# 44 convenience
# 83 convenient
# 269 convention
# 84 conventional
# 125 conversation
# 109 conversations
# 174 conversion
# 326 convert
# 122 converted
# 139 converter
# 63 convertible
# 111 converting
# 42 converts
# 96 convex
# 54 convex com
# 53 convicted
# 60 conviction
# 51 convictions
# 147 convince
# 130 convinced
# 64 convincing
# 83 cook
# 45 cookson
# 167 cool
# 86 cooling
# 46 cooper
# 82 cooperation
# 107 cop
# 47 copied
# 262 copies
# 48 coprocessor
# 198 cops
# 778 copy
# 53 copy protection
# 54 copying
# 136 copyright
# 52 cor
# 42 cord
# 180 core
# 54 corinthians
# 67 corn
# 125 cornell
# 93 cornell edu
# 125 corner
# 54 corners
# 219 corp
# 48 corporate
# 198 corporation
# 52 corps
# 51 corpses
# 735 correct
# 47 corrected
# 87 correction
# 64 corrections
# 215 correctly
# 62 correlation
# 64 corresponding
# 64 corrupt
# 45 corruption
# 42 cos
# 55 cosmic
# 819 cost
# 329 costs
# 47 cosy
# 4606 could
# 40 could also
# 42 could done
# 42 could easily
# 85 could find
# 121 could get
# 46 could give
# 39 could go
# 38 could help
# 61 could make
# 46 could please
# 39 could see
# 129 could someone
# 55 could someone please
# 69 could use
# 56 could used
# 47 could wrong
# 140 council
# 295 count
# 53 counted
# 129 counter
# 60 countersteering
# 43 counting
# 317 countries
# 824 country
# 57 counts
# 79 county
# 732 couple
# 61 couple weeks
# 56 couple years
# 1655 course
# 60 courses
# 474 court
# 54 court order
# 54 courtesy
# 91 courts
# 40 courtyard
# 91 covenant
# 450 cover
# 315 coverage
# 200 covered
# 73 covering
# 68 covers
# 77 covington
# 45 cox
# 52 cp
# 373 cpu
# 67 cr
# 116 crack
# 95 craft
# 196 craig
# 310 cramer
# 54 cramer opinions
# 54 cramer opinions mine
# 48 cramer opinions mine relations
# 48 cramer opinions mine relations people
# 48 cramer opinions mine relations people mutual
# 76 cramer optilink
# 76 cramer optilink com
# 74 cramer optilink com clayton
# 74 cramer optilink com clayton cramer
# 72 cramer optilink com clayton cramer writes
# 54 cramer uunet
# 54 cramer uunet pyramid
# 54 cramer uunet pyramid optilink
# 54 cramer uunet pyramid optilink cramer
# 54 cramer uunet pyramid optilink cramer opinions
# 76 cramer writes
# 117 crap
# 50 crary
# 144 crash
# 47 crashes
# 70 cray
# 44 cray com
# 133 crazy
# 463 create
# 468 created
# 62 creates
# 114 creating
# 264 creation
# 64 creationism
# 50 creative
# 63 creator
# 44 creature
# 49 credibility
# 178 credit
# 87 crew
# 521 crime
# 175 crimes
# 231 criminal
# 285 criminals
# 68 crisis
# 78 criteria
# 127 critical
# 89 criticism
# 62 croats
# 39 crop
# 305 cross
# 44 cross linked
# 41 cross linked allocation
# 41 cross linked allocation unit
# 145 crowd
# 47 crucial
# 63 cruel
# 56 cruise
# 55 cry
# 69 crying
# 90 crypt
# 48 cryptanalysis
# 213 crypto
# 53 cryptographic
# 169 cryptography
# 44 cryptology
# 50 cryptosystem
# 47 cryptosystems
# 62 crystal
# 1784 cs
# 66 cs cmu
# 62 cs cmu edu
# 56 cs colorado
# 47 cs colorado edu
# 38 cs cornell
# 38 cs cornell edu
# 114 cs du
# 111 cs du edu
# 61 cs jhu
# 61 cs jhu edu
# 39 cs jhu edu ken
# 39 cs jhu edu ken arromdee
# 67 cs laurentian
# 67 cs laurentian ca
# 75 cs uiuc
# 72 cs uiuc edu
# 51 cs umd
# 51 cs umd edu
# 48 cs utexas
# 40 cs utexas edu
# 69 csc
# 111 csd
# 39 cse
# 293 cso
# 293 cso uiuc
# 288 cso uiuc edu
# 41 csrc
# 38 csrc ncsl
# 38 csrc ncsl nist
# 38 csrc ncsl nist gov
# 93 ct
# 63 ctrl
# 58 ctron
# 56 ctron com
# 42 ctron com john
# 42 ctron com john king
# 41 ctron com john king writes
# 72 cts
# 64 cu
# 41 cub
# 54 cube
# 145 cubs
# 301 cult
# 54 cult members
# 120 cultural
# 235 culture
# 52 cunixb
# 52 cunixb cc
# 52 cunixb cc columbia
# 50 cunixb cc columbia edu
# 345 cup
# 50 cup portal
# 41 cup portal com
# 72 cure
# 206 curious
# 893 current
# 43 current version
# 494 currently
# 119 cursor
# 43 curt
# 52 curtis
# 76 curve
# 96 custom
# 65 customer
# 76 customers
# 517 cut
# 43 cute
# 85 cuts
# 89 cutting
# 84 cv
# 53 cview
# 183 cwru
# 143 cwru edu
# 39 cwru edu keith
# 39 cwru edu keith ryan
# 396 cx
# 90 cx cx
# 46 cx scx
# 59 cy
# 40 cyberspace
# 144 cycle
# 50 cycles
# 75 cylinder
# 60 cylinders
# 94 cyprus
# 57 cz
# 45 czech
# 98 da
# 49 dad
# 186 daily
# 64 dal
# 151 dale
# 93 dallas
# 235 damage
# 53 damaged
# 49 dammit
# 203 damn
# 45 damned
# 342 dan
# 39 dance
# 147 danger
# 289 dangerous
# 189 daniel
# 77 danny
# 115 dare
# 39 darius
# 192 dark
# 56 darkness
# 62 darren
# 45 dartmouth
# 39 darwin
# 49 daryl
# 59 das
# 38 dat
# 1870 data
# 151 database
# 47 databases
# 532 date
# 50 date apr
# 49 dates
# 142 daughter
# 582 dave
# 1645 david
# 50 david david
# 56 david davidian
# 171 david koresh
# 126 david sternlight
# 40 david sternlight great
# 40 david sternlight great care
# 40 david sternlight great care taken
# 40 david sternlight great care taken ensure
# 61 david sternlight writes
# 59 david veal
# 136 davidian
# 229 davidians
# 127 davis
# 47 dawn
# 38 dawson
# 1858 day
# 39 day christmas
# 38 day christmas truelove
# 38 day christmas truelove served
# 58 day day
# 966 days
# 57 days ago
# 159 db
# 53 dbd
# 52 dbd urartu
# 52 dbd urartu sdpa
# 52 dbd urartu sdpa org
# 361 dc
# 74 dcs
# 70 dd
# 789 de
# 38 de phill
# 38 de phill hallam
# 38 de phill hallam baker
# 725 dead
# 38 deadline
# 52 deadly
# 734 deal
# 308 dealer
# 132 dealers
# 165 dealing
# 96 deals
# 46 dealt
# 167 dean
# 136 dear
# 799 death
# 56 death penalty
# 207 deaths
# 237 debate
# 39 debating
# 42 debt
# 327 dec
# 103 dec com
# 63 decade
# 75 decades
# 145 december
# 161 decent
# 282 decide
# 393 decided
# 53 decides
# 385 decision
# 164 decisions
# 40 deck
# 61 declare
# 62 declared
# 46 decnet
# 38 decode
# 51 decrease
# 56 decrypt
# 38 decryption
# 69 dedicated
# 86 dee
# 42 dee dee
# 57 deeds
# 187 deep
# 68 deeply
# 39 deer
# 46 defamation
# 41 defamation league
# 233 default
# 77 defaults
# 48 defeat
# 44 defeated
# 38 defects
# 78 defence
# 215 defend
# 79 defending
# 478 defense
# 60 defenseman
# 153 defensive
# 76 deficit
# 41 deficits
# 369 define
# 310 defined
# 76 defines
# 53 defining
# 53 definite
# 233 definitely
# 390 definition
# 89 definitions
# 255 degree
# 174 degrees
# 58 deity
# 41 del
# 75 delay
# 94 delete
# 532 deleted
# 46 deletion
# 50 deletions
# 77 deliberately
# 54 delivered
# 67 delivery
# 40 dell
# 74 delta
# 52 deluxe
# 190 demand
# 79 demands
# 136 demo
# 104 democracy
# 105 democratic
# 47 democrats
# 112 demon
# 67 demon co
# 61 demon co uk
# 72 demonstrate
# 89 demonstrated
# 46 demonstrates
# 63 demonstration
# 60 den
# 50 denial
# 88 denied
# 98 denning
# 132 dennis
# 41 dennis kriz
# 91 density
# 56 denver
# 146 deny
# 53 denying
# 538 department
# 110 depend
# 75 dependent
# 173 depending
# 224 depends
# 49 depression
# 252 dept
# 128 depth
# 38 deputy
# 48 der
# 80 derek
# 91 derived
# 403 des
# 143 describe
# 308 described
# 128 describes
# 81 describing
# 244 description
# 56 descriptions
# 71 desert
# 128 deserve
# 55 deserved
# 72 deserves
# 498 design
# 44 designated
# 401 designed
# 67 designs
# 40 desirable
# 182 desire
# 78 desired
# 39 desires
# 87 desk
# 89 deskjet
# 165 desktop
# 38 desperate
# 250 despite
# 48 desqview
# 149 destroy
# 178 destroyed
# 64 destroying
# 136 destruction
# 69 desy
# 67 desy de
# 38 desy de phill
# 38 desy de phill hallam
# 38 desy de phill hallam baker
# 278 det
# 166 detail
# 120 detailed
# 412 details
# 93 detect
# 46 detected
# 63 detection
# 139 detector
# 103 detectors
# 48 determination
# 218 determine
# 135 determined
# 52 determining
# 230 detroit
# 92 dev
# 203 develop
# 275 developed
# 67 developer
# 69 developers
# 119 developing
# 413 development
# 418 device
# 399 devices
# 94 devil
# 168 devils
# 45 devoted
# 42 df
# 119 dg
# 59 dg com
# 39 dg com bill
# 57 dh
# 183 di
# 93 di di
# 72 di di di
# 56 di di di di
# 43 di di di di di
# 56 diagnosed
# 51 diagnosis
# 93 dial
# 84 dialog
# 39 diameter
# 132 diamond
# 113 dick
# 124 dictionary
# 471 die
# 356 died
# 128 diego
# 41 dies
# 170 diet
# 61 differ
# 765 difference
# 185 differences
# 1671 different
# 79 differential
# 88 differently
# 392 difficult
# 76 difficulty
# 46 dig
# 67 digest
# 130 digex
# 106 digex com
# 45 digex com pat
# 41 digex com pat writes
# 386 digital
# 49 digitized
# 38 dignity
# 46 dim
# 45 dimensional
# 68 dimensions
# 50 dineen
# 43 dinner
# 50 dip
# 42 diplomatic
# 88 dir
# 296 direct
# 94 directed
# 203 direction
# 47 directions
# 430 directly
# 170 director
# 67 directories
# 466 directory
# 52 directory pub
# 77 dirt
# 73 dirty
# 42 disable
# 39 disabled
# 287 disagree
# 64 disappear
# 54 disappeared
# 69 disaster
# 54 disc
# 84 discharge
# 84 disciples
# 38 discipline
# 371 disclaimer
# 70 disclaimer opinions
# 78 disclaimers
# 39 disclaimers apply
# 61 discount
# 63 discover
# 199 discovered
# 59 discovery
# 126 discrimination
# 249 discuss
# 187 discussed
# 50 discusses
# 113 discussing
# 631 discussion
# 180 discussions
# 347 disease
# 85 diseases
# 39 disgusting
# 44 dishonest
# 1067 disk
# 52 disk controller
# 54 disk drive
# 68 disk drives
# 85 disk space
# 301 disks
# 41 dislike
# 44 dismiss
# 50 disorder
# 813 display
# 83 displayed
# 53 displaying
# 148 displays
# 103 dispute
# 41 disregard
# 176 distance
# 45 distinct
# 86 distinction
# 55 distinguish
# 41 distortion
# 58 distribute
# 144 distributed
# 271 distribution
# 74 district
# 58 ditto
# 78 div
# 50 divide
# 53 divided
# 124 divine
# 434 division
# 38 divorce
# 40 dj
# 104 dk
# 99 dl
# 100 dm
# 116 dma
# 45 dn
# 55 dna
# 126 doc
# 38 dock
# 84 docs
# 293 doctor
# 212 doctors
# 166 doctrine
# 52 doctrines
# 252 document
# 46 documentary
# 226 documentation
# 75 documented
# 221 documents
# 617 dod
# 52 dodge
# 53 dodgers
# 60 doesnot
# 237 dog
# 76 dogma
# 120 dogs
# 45 dole
# 103 dollar
# 197 dollars
# 236 domain
# 94 domestic
# 47 domi
# 41 dominated
# 68 donald
# 1366 done
# 42 donot
# 123 dont
# 429 door
# 110 doors
# 54 dorothy
# 39 dorothy denning
# 39 dortmund
# 1752 dos
# 406 dos dos
# 383 dos dos dos
# 366 dos dos dos dos
# 349 dos dos dos dos dos
# 332 dos dos dos dos dos dos
# 82 dos windows
# 47 dose
# 118 dot
# 368 double
# 535 doubt
# 318 doug
# 157 douglas
# 53 download
# 39 downloaded
# 91 dozen
# 47 dozens
# 49 dp
# 81 dpi
# 65 dpy
# 550 dr
# 166 draft
# 136 drag
# 52 dragon
# 54 drain
# 58 dram
# 49 dramatically
# 309 draw
# 185 drawing
# 131 drawn
# 119 dream
# 78 dreams
# 51 drew
# 45 drill
# 135 drink
# 67 drinking
# 1949 drive
# 165 driven
# 654 driver
# 570 drivers
# 496 drives
# 302 driving
# 50 dro
# 277 drop
# 130 dropped
# 51 dropping
# 61 drops
# 87 drove
# 501 drug
# 53 drug dealers
# 42 drug use
# 437 drugs
# 55 drunk
# 116 dry
# 98 ds
# 48 dscomsa
# 39 dscomsa desy
# 39 dscomsa desy de
# 38 dscomsa desy de phill
# 38 dscomsa desy de phill hallam
# 38 dscomsa desy de phill hallam baker
# 47 dsd
# 45 dsd es
# 44 dsd es com
# 83 dseg
# 65 dseg ti
# 65 dseg ti com
# 63 dsl
# 63 dsl pitt
# 63 dsl pitt edu
# 63 dsl pitt edu shameful
# 63 dsl pitt edu shameful surrender
# 63 dsl pitt edu shameful surrender soon
# 60 dsp
# 74 dt
# 41 dtr
# 193 du
# 116 du edu
# 108 dual
# 604 due
# 171 duke
# 108 duke edu
# 42 dull
# 84 dumb
# 62 dump
# 55 dunn
# 40 dunno
# 102 duo
# 44 duration
# 99 dust
# 142 duty
# 289 dwyer
# 75 dwyer hatching
# 75 dwyer hatching odwyer
# 75 dwyer hatching odwyer sse
# 75 dwyer hatching odwyer sse ie
# 75 dwyer hatching odwyer sse ie hens
# 178 dwyer writes
# 102 dwyer writes article
# 406 dx
# 65 dx mhz
# 56 dy
# 74 dyer
# 108 dying
# 67 dynamic
# 60 dynamics
# 51 dzkriz
# 51 dzkriz ocf
# 51 dzkriz ocf berkeley
# 51 dzkriz ocf berkeley edu
# 40 dzkriz ocf berkeley edu dennis
# 38 dzkriz ocf berkeley edu dennis kriz
# 62 ea
# 46 eagle
# 69 ear
# 42 earl
# 317 earlier
# 609 early
# 49 earn
# 47 earned
# 71 ears
# 922 earth
# 40 ease
# 266 easier
# 413 easily
# 433 east
# 72 east sun
# 72 east sun com
# 74 easter
# 160 eastern
# 649 easy
# 215 eat
# 126 eating
# 67 ec
# 59 ece
# 151 echo
# 154 ecn
# 90 ecn purdue
# 88 ecn purdue edu
# 46 ecn uoknor
# 46 ecn uoknor edu
# 41 econ
# 214 economic
# 51 economics
# 132 economy
# 53 ecs
# 673 ed
# 76 ed green
# 52 eddie
# 205 edge
# 58 edges
# 103 edit
# 59 edited
# 70 editing
# 172 edition
# 203 editor
# 52 editorial
# 104 edm
# 86 edmonton
# 63 edt
# 11522 edu
# 84 edu andrew
# 48 edu andy
# 250 edu au
# 61 edu bill
# 94 edu brian
# 55 edu contrib
# 44 edu dan
# 52 edu daniel
# 215 edu david
# 42 edu dennis
# 38 edu dennis kriz
# 50 edu edward
# 61 edu eric
# 39 edu file
# 43 edu gary
# 42 edu go
# 38 edu gregg
# 39 edu high
# 40 edu incoming
# 62 edu james
# 173 edu john
# 97 edu keith
# 39 edu keith ryan
# 54 edu ken
# 39 edu ken arromdee
# 75 edu mark
# 129 edu michael
# 89 edu mike
# 61 edu mike cobb
# 58 edu mike cobb writes
# 44 edu new
# 43 edu peter
# 130 edu pub
# 84 edu robert
# 70 edu scott
# 63 edu shameful
# 63 edu shameful surrender
# 63 edu shameful surrender soon
# 68 edu stephen
# 54 edu tim
# 85 edu university
# 40 edu university georgia
# 62 edu utzoo
# 57 edu utzoo henry
# 664 edu writes
# 117 edu writes article
# 261 edu wrote
# 39 edu wrote article
# 63 educated
# 258 education
# 92 educational
# 126 edward
# 40 edwards
# 180 ee
# 44 ef
# 113 eff
# 637 effect
# 330 effective
# 131 effectively
# 47 effectiveness
# 305 effects
# 38 efficiency
# 100 efficient
# 301 effort
# 137 efforts
# 128 eg
# 47 ega
# 84 egypt
# 149 eh
# 250 ei
# 72 ei ei
# 140 eight
# 44 eighth
# 108 einstein
# 164 eisa
# 63 eitech
# 63 eitech com
# 50 eitech com eric
# 50 eitech com eric rescorla
# 50 eitech com eric rescorla writes
# 1552 either
# 57 either way
# 76 ekr
# 75 el
# 54 elaborate
# 91 elected
# 90 election
# 47 elections
# 119 electric
# 190 electrical
# 56 electricity
# 54 electron
# 246 electronic
# 45 electronic mail
# 224 electronics
# 95 element
# 132 elements
# 40 elevator
# 80 elias
# 73 eliminate
# 42 eliminated
# 60 eliot
# 39 elizabeth
# 153 elohim
# 1491 else
# 128 elsewhere
# 38 elvis
# 228 em
# 1236 email
# 93 email address
# 42 embargo
# 73 emergency
# 42 emissions
# 66 emm
# 80 emotional
# 90 emphasis
# 132 empire
# 51 empirical
# 41 employ
# 65 employed
# 40 employee
# 89 employees
# 229 employer
# 54 employer opinions
# 47 employer opinions standard
# 47 employer opinions standard failed
# 47 employer opinions standard failed president
# 114 empty
# 99 en
# 80 enable
# 52 encounter
# 60 encountered
# 88 encourage
# 74 encouraged
# 48 encrypt
# 208 encrypted
# 724 encryption
# 48 encryption algorithm
# 44 encryption devices
# 41 encryption technology
# 1445 end
# 122 ended
# 41 endif
# 50 ending
# 138 ends
# 92 enemies
# 84 enemy
# 367 energy
# 61 enet
# 58 enet dec
# 56 enet dec com
# 68 enforce
# 365 enforcement
# 51 enforcement agencies
# 214 eng
# 60 eng sun
# 58 eng sun com
# 56 eng umd
# 54 eng umd edu
# 52 engage
# 84 engaged
# 445 engine
# 177 engineer
# 417 engineering
# 68 engineers
# 146 engines
# 153 england
# 239 english
# 61 engr
# 75 enhanced
# 40 enhancement
# 174 enjoy
# 43 enjoyed
# 49 enormous
# 1630 enough
# 191 ensure
# 40 ensure accuracy
# 39 ensure accuracy information
# 39 ensure accuracy information errors
# 39 ensure accuracy information errors omissions
# 39 ensure accuracy information errors omissions excepted
# 187 enter
# 106 entered
# 74 entering
# 70 enterprise
# 41 entertaining
# 438 entire
# 290 entirely
# 42 entities
# 98 entitled
# 81 entity
# 98 entries
# 296 entry
# 41 entryway
# 38 envelope
# 356 environment
# 81 environmental
# 41 environments
# 71 eof
# 46 eof ok
# 40 eof ok xx
# 62 eos
# 39 eos ncsu
# 43 ep
# 44 eq
# 249 equal
# 144 equally
# 50 equation
# 334 equipment
# 66 equipped
# 157 equivalent
# 123 er
# 146 era
# 42 ergo
# 437 eric
# 64 eric rescorla
# 50 eric rescorla writes
# 50 ericsson
# 38 ericsson se
# 62 erik
# 57 ermeni
# 603 error
# 44 error message
# 266 errors
# 40 errors omissions
# 39 errors omissions excepted
# 55 erzurum
# 145 es
# 70 es com
# 261 escape
# 110 escape turks
# 110 escape turks proceeded
# 110 escape turks proceeded work
# 110 escape turks proceeded work extermination
# 110 escape turks proceeded work extermination ohanus
# 66 escaped
# 288 escrow
# 39 escrow agencies
# 39 escrow system
# 41 escrowed
# 74 esdi
# 45 eskimo
# 59 esp
# 726 especially
# 235 espn
# 70 essence
# 122 essential
# 185 essentially
# 48 est
# 118 establish
# 190 established
# 38 establishing
# 53 establishment
# 53 estimate
# 60 estimated
# 51 estimates
# 293 et
# 131 et al
# 2238 etc
# 113 etc etc
# 236 eternal
# 41 eternity
# 151 ethernet
# 45 ethernet card
# 60 ethical
# 62 ethics
# 151 ethnic
# 43 ethnic cleansing
# 51 eu
# 38 eugene
# 288 europe
# 252 european
# 76 europeans
# 58 evaluate
# 53 evaluation
# 66 evans
# 62 eve
# 82 evelyn
# 60 evelyn conlon
# 4216 even
# 44 even better
# 61 even know
# 55 even one
# 280 even though
# 116 evening
# 425 event
# 42 event horizon
# 393 events
# 226 eventually
# 1294 ever
# 48 ever heard
# 55 ever seen
# 1732 every
# 139 every day
# 46 every one
# 129 every time
# 65 every year
# 284 everybody
# 48 everyday
# 902 everyone
# 88 everyone else
# 934 everything
# 77 everything else
# 42 everytime
# 108 everywhere
# 1245 evidence
# 46 evident
# 375 evil
# 234 evolution
# 43 evolutionary
# 296 ex
# 217 exact
# 714 exactly
# 65 examination
# 76 examine
# 52 examined
# 1335 example
# 228 examples
# 46 exceed
# 347 excellent
# 62 excellent condition
# 680 except
# 42 excepted
# 125 exception
# 51 exceptions
# 53 excerpts
# 40 excess
# 56 excessive
# 116 exchange
# 44 exciting
# 42 exclude
# 53 exclusive
# 60 exclusively
# 209 excuse
# 141 exe
# 60 execute
# 55 executed
# 44 execution
# 82 executive
# 131 exercise
# 42 exercises
# 71 exhaust
# 642 exist
# 60 existance
# 136 existed
# 497 existence
# 65 existence god
# 46 existent
# 240 existing
# 515 exists
# 113 exists single
# 113 exists single turkish
# 113 exists single turkish soul
# 110 exists single turkish soul sahak
# 110 exists single turkish soul sahak melkonian
# 109 exit
# 80 expand
# 52 expanded
# 137 expansion
# 601 expect
# 264 expected
# 65 expecting
# 38 expects
# 54 expense
# 297 expensive
# 652 experience
# 97 experienced
# 157 experiences
# 134 experiment
# 103 experimental
# 82 experiments
# 118 expert
# 152 experts
# 573 explain
# 152 explained
# 62 explaining
# 67 explains
# 175 explanation
# 43 explanations
# 47 explicit
# 94 explicitly
# 82 exploration
# 56 explosion
# 45 explosive
# 105 expo
# 281 export
# 109 export lcs
# 108 export lcs mit
# 102 export lcs mit edu
# 50 export lcs mit edu contrib
# 71 expose
# 83 exposed
# 94 exposure
# 112 express
# 271 expressed
# 53 expressed mine
# 99 expression
# 68 ext
# 59 extend
# 155 extended
# 149 extension
# 85 extensions
# 76 extensive
# 121 extent
# 176 extermination
# 111 extermination ohanus
# 111 extermination ohanus appressian
# 110 extermination ohanus appressian soviet
# 110 extermination ohanus appressian soviet armenia
# 110 extermination ohanus appressian soviet armenia today
# 230 external
# 423 extra
# 39 extract
# 134 extreme
# 191 extremely
# 163 ey
# 48 ey ey
# 245 eye
# 247 eyes
# 80 ez
# 625 face
# 70 faced
# 74 faces
# 100 facilities
# 112 facility
# 45 facing
# 2001 fact
# 197 factor
# 123 factors
# 87 factory
# 389 facts
# 189 fail
# 45 fail see
# 268 failed
# 47 failed president
# 55 failing
# 118 fails
# 168 failure
# 306 fair
# 308 fairly
# 785 faith
# 348 fall
# 117 fallacy
# 69 fallen
# 65 falling
# 120 falls
# 358 false
# 61 fame
# 166 familiar
# 105 families
# 460 family
# 122 famous
# 402 fan
# 49 fanatic
# 48 fanatics
# 73 fancy
# 367 fans
# 62 fantasy
# 667 faq
# 1578 far
# 38 far enough
# 110 far know
# 43 far tell
# 77 farm
# 40 fascinating
# 66 fascist
# 65 fashion
# 651 fast
# 439 faster
# 54 fastest
# 149 fat
# 73 fatal
# 67 fate
# 460 father
# 74 fathers
# 213 fault
# 139 favor
# 123 favorite
# 40 favors
# 1010 fax
# 49 fax email
# 999 fbi
# 54 fbi batf
# 63 fc
# 45 fd
# 286 fear
# 45 fears
# 57 feasible
# 225 feature
# 291 features
# 103 feb
# 161 february
# 66 fed
# 526 federal
# 90 federal government
# 45 federalist
# 182 feds
# 125 fee
# 130 feed
# 74 feedback
# 40 feeding
# 914 feel
# 89 feel free
# 188 feeling
# 73 feelings
# 107 feels
# 51 fees
# 239 feet
# 49 felix
# 111 fell
# 144 fellow
# 205 felt
# 82 female
# 83 fewer
# 94 ff
# 73 fg
# 314 fi
# 78 fiction
# 137 fidonet
# 64 fidonet org
# 476 field
# 44 fielding
# 166 fields
# 138 fifth
# 53 fifty
# 267 fight
# 47 fighters
# 209 fighting
# 444 figure
# 92 figured
# 160 figures
# 2349 file
# 48 file congress
# 54 file format
# 39 file formats
# 48 file manager
# 49 filed
# 80 filename
# 1238 files
# 132 fill
# 119 filled
# 40 filling
# 111 film
# 101 filter
# 63 filters
# 380 final
# 450 finally
# 70 finals
# 83 financial
# 2470 find
# 53 find one
# 54 find way
# 179 finding
# 56 findings
# 70 finds
# 704 fine
# 131 finger
# 65 fingers
# 141 finish
# 117 finished
# 45 finite
# 119 finland
# 962 fire
# 71 fire started
# 119 firearm
# 297 firearms
# 172 fired
# 74 fires
# 87 firing
# 93 firm
# 41 firmly
# 3729 first
# 53 first day
# 45 first paragraph
# 47 first period
# 159 first place
# 41 first round
# 42 first second
# 185 first time
# 58 first two
# 38 firstly
# 52 fischer
# 84 fish
# 45 fisher
# 40 fist
# 326 fit
# 118 fits
# 47 fitting
# 390 five
# 44 five years
# 252 fix
# 190 fixed
# 55 fixes
# 41 fixing
# 72 fj
# 81 fl
# 88 flag
# 275 flame
# 255 flames
# 71 flaming
# 88 flash
# 159 flat
# 45 flawed
# 59 fled
# 38 flee
# 60 flesh
# 46 flew
# 60 flexible
# 223 flight
# 50 flights
# 43 flip
# 52 floating
# 183 floor
# 78 floppies
# 399 floppy
# 60 floppy disk
# 96 floppy drive
# 142 florida
# 113 flow
# 56 fluid
# 38 fluids
# 172 fly
# 51 flyby
# 147 flyers
# 125 flying
# 166 fm
# 87 fnal
# 46 fnal gov
# 153 focus
# 443 folks
# 507 follow
# 217 followed
# 193 followers
# 1265 following
# 252 follows
# 65 followup
# 64 followups
# 298 font
# 319 fonts
# 435 food
# 93 foods
# 137 fool
# 52 foolish
# 59 fools
# 165 foot
# 78 football
# 54 fora
# 696 force
# 198 forced
# 261 forces
# 83 forcing
# 226 ford
# 263 foreign
# 186 forever
# 393 forget
# 53 forgive
# 125 forgot
# 78 forgotten
# 46 fork
# 653 form
# 72 formal
# 670 format
# 63 formation
# 238 formats
# 58 formatted
# 53 formatting
# 145 formed
# 335 former
# 68 formerly
# 39 forming
# 140 forms
# 54 formula
# 77 forsale
# 48 fort
# 129 forth
# 150 forthe
# 44 fortran
# 70 fortunately
# 103 forum
# 288 forward
# 40 forwards
# 43 fought
# 44 foul
# 1355 found
# 130 foundation
# 76 founded
# 57 founding
# 664 four
# 41 four years
# 149 fourth
# 73 fox
# 59 fp
# 61 fprintf
# 47 fprintf stderr
# 38 fps
# 139 fpu
# 61 fq
# 131 fr
# 39 fraction
# 270 frame
# 48 frame reference
# 77 frames
# 154 france
# 50 franchise
# 141 francis
# 207 francisco
# 863 frank
# 50 frank crary
# 280 frank dwyer
# 75 frank dwyer hatching
# 75 frank dwyer hatching odwyer
# 75 frank dwyer hatching odwyer sse
# 75 frank dwyer hatching odwyer sse ie
# 178 frank dwyer writes
# 102 frank dwyer writes article
# 206 frank uucp
# 198 frank uucp frank
# 198 frank uucp frank dwyer
# 178 frank uucp frank dwyer writes
# 102 frank uucp frank dwyer writes article
# 44 franklin
# 59 frankly
# 62 fraud
# 178 fred
# 41 fred rice
# 1491 free
# 38 free state
# 514 freedom
# 38 freedom speech
# 61 freedoms
# 82 freely
# 62 freeman
# 218 freenet
# 48 freenet carleton
# 46 freenet carleton ca
# 151 freenet edu
# 51 freeware
# 164 french
# 71 frequencies
# 140 frequency
# 64 frequent
# 173 frequently
# 42 frequently asked
# 58 fresh
# 47 fri
# 142 friday
# 53 friedman
# 564 friend
# 104 friend mine
# 119 friendly
# 349 friends
# 39 frightened
# 43 frog
# 90 fromthe
# 592 front
# 40 frost
# 39 fruit
# 43 frustrated
# 62 fs
# 43 fsu
# 40 fsu edu
# 103 ft
# 1019 ftp
# 42 ftp cica
# 39 ftp cica indiana
# 39 ftp ftp
# 117 ftp site
# 54 ftp sites
# 61 fuck
# 200 fuel
# 93 fuhr
# 42 fulfill
# 40 fulfilled
# 1088 full
# 62 full color
# 281 fully
# 253 fun
# 369 function
# 48 functional
# 60 functionality
# ...
# 115 terrorists
# 92 terry
# 49 tesla
# 613 test
# 146 testament
# 177 tested
# 76 testimony
# 163 testing
# 203 tests
# 46 tex
# 377 texas
# 655 text
# 100 texts
# 52 tg
# 904 th
# 82 th century
# 447 thank
# 38 thank much
# 2209 thanks
# 400 thanks advance
# 96 thanks help
# 52 thanks lot
# 124 thanx
# 46 thati
# 43 thatis
# 57 thatit
# 89 thats
# 169 thatthe
# 43 thatthere
# 60 thatthey
# 62 thatyou
# 42 thave
# 77 thee
# 79 thefirst
# 38 theft
# 62 thegovernment
# 133 theism
# 74 theist
# 41 theistic
# 99 theists
# 41 theme
# 44 themy
# 44 themy opinions
# 44 themy opinions employer
# 44 themy opinions employer opinions
# 44 themy opinions employer opinions standard
# 44 themy opinions employer opinions standard failed
# 63 theodore
# 40 theodore kaldis
# 39 theological
# 94 theology
# 47 theonly
# 72 theoretical
# 150 theories
# 657 theory
# 41 theory creationism
# 52 theother
# 77 therapy
# 47 thereby
# 660 therefore
# 74 thereis
# 39 thereof
# 75 thermal
# 95 thesame
# 41 thesis
# 42 theworld
# 72 theyare
# 38 theywere
# 46 thf
# 38 thief
# 51 thier
# 64 thin
# 2078 thing
# 40 thing would
# 2260 things
# 135 things like
# 6050 think
# 39 think need
# 42 think one
# 50 think people
# 39 think right
# 38 think way
# 144 think would
# 566 thinking
# 165 thinks
# 700 third
# 40 third parties
# 96 third party
# 49 third period
# 44 thirty
# 66 thisis
# 458 thomas
# 54 thomas jefferson
# 56 thompson
# 87 thor
# 47 thor isc
# 47 thor isc br
# 47 thor isc br com
# 44 thoroughly
# 125 thou
# 1581 though
# 1251 thought
# 57 thought would
# 183 thoughts
# 154 thousand
# 270 thousands
# 310 thread
# 66 threads
# 202 threat
# 81 threatened
# 57 threatening
# 40 threats
# 1323 three
# 54 three days
# 39 three months
# 39 three times
# 57 three years
# 107 threw
# 57 throttle
# 162 throughout
# 244 throw
# 98 throwing
# 133 thrown
# 100 thru
# 64 thu
# 46 thu apr
# 43 thug
# 55 thumb
# 40 thunder
# 111 thursday
# 717 thus
# 60 thy
# 142 ti
# 83 ti com
# 147 ticket
# 92 tickets
# 130 tie
# 101 tied
# 170 tiff
# 38 tiger
# 52 tigers
# 84 tight
# 130 till
# 324 tim
# 55 tim clock
# 5286 time
# 60 time ago
# 75 time time
# 40 time would
# 81 timer
# 1183 times
# 83 timing
# 98 timothy
# 84 tiny
# 62 tip
# 50 tips
# 101 tire
# 110 tired
# 144 tires
# 43 tissue
# 87 titan
# 330 title
# 42 titles
# 60 tk
# 39 tknow
# 53 tl
# 420 tm
# 47 tmc
# 46 tmi
# 45 tmp
# 59 tn
# 38 toa
# 44 tobacco
# 127 tobe
# 1178 today
# 114 today longer
# 113 today longer exists
# 113 today longer exists single
# 113 today longer exists single turkish
# 113 today longer exists single turkish soul
# 61 today special
# 61 today special investors
# 61 today special investors packet
# 98 todd
# 59 todo
# 41 toget
# 525 together
# 42 tohave
# 47 toilet
# 1020 told
# 76 told us
# 43 tolerance
# 50 toll
# 444 tom
# 54 tomake
# 85 tommy
# 109 tomorrow
# 83 tone
# 45 tongue
# 123 tonight
# 57 tons
# 212 tony
# 725 took
# 50 took place
# 244 tool
# 138 toolkit
# 41 toolkits
# 353 tools
# 689 top
# 227 topic
# 98 topics
# 45 toplevel
# 237 tor
# 38 torn
# 545 toronto
# 158 toronto edu
# 62 toronto edu utzoo
# 57 toronto edu utzoo henry
# 40 toronto zoology
# 67 torque
# 71 torture
# 43 tortured
# 55 toshiba
# 45 tossed
# 548 total
# 240 totally
# 48 totals
# 198 tothe
# 156 touch
# 45 touched
# 145 tough
# 39 tour
# 44 tournament
# 209 toward
# 274 towards
# 121 tower
# 49 towers
# 280 town
# 45 towns
# 78 toxic
# 97 toyota
# 56 tr
# 70 trace
# 61 tracing
# 203 track
# 53 tracking
# 351 trade
# 107 traded
# 161 tradition
# 124 traditional
# 56 traditions
# 237 traffic
# 93 tragedy
# 48 tragic
# 93 train
# 84 trained
# 261 training
# 44 trans
# 39 transaction
# 263 transfer
# 47 transfers
# 43 transition
# 38 translate
# 67 translated
# 183 translation
# 50 translations
# 170 transmission
# 60 transmit
# 68 transmitted
# 48 transmitter
# 47 transport
# 41 transportation
# 61 trap
# 72 trash
# 94 travel
# 129 treat
# 144 treated
# 54 treating
# 315 treatment
# 54 treatments
# 47 treaty
# 102 tree
# 53 trees
# 43 trek
# 64 trend
# 267 trial
# 100 trials
# 56 triangle
# 108 trick
# 43 tricks
# 42 tricky
# 45 trident
# 797 tried
# 93 tries
# 58 trigger
# 49 trinity
# 111 trip
# 56 triple
# 51 trips
# 64 trivial
# 242 troops
# 384 trouble
# 118 truck
# 58 trucks
# 1817 true
# 39 truelove
# 38 truelove served
# 39 truely
# 52 truetype
# 210 truly
# 42 trunk
# 335 trust
# 57 trusted
# 904 truth
# 77 truths
# 71 trw
# 53 trw com
# 1693 try
# 40 try find
# 65 try get
# 1218 trying
# 47 trying find
# 82 trying get
# 68 trying make
# 66 trying say
# 46 ts
# 85 tt
# 50 ttl
# 140 tu
# 105 tube
# 56 tubes
# 106 tue
# 51 tue apr
# 114 tuesday
# 54 tune
# 41 turan
# 182 turbo
# 68 turk
# 451 turkey
# 941 turkish
# 95 turkish genocide
# 113 turkish soul
# 110 turkish soul sahak
# 110 turkish soul sahak melkonian
# 64 turkiye
# 443 turks
# 47 turks kurds
# 110 turks proceeded
# 110 turks proceeded work
# 110 turks proceeded work extermination
# 110 turks proceeded work extermination ohanus
# 110 turks proceeded work extermination ohanus appressian
# 651 turn
# 348 turned
# 61 turner
# 122 turning
# 178 turns
# 44 tutorial
# 493 tv
# 88 tw
# 45 twelve
# 67 twenty
# 181 twice
# 65 twin
# 68 twins
# 39 twist
# 42 twisted
# 58 twm
# 3829 two
# 46 two days
# 65 two different
# 38 two months
# 69 two people
# 79 two things
# 56 two three
# 90 two weeks
# 130 two years
# 182 tx
# 63 txt
# 886 type
# 308 types
# 229 typical
# 107 typically
# 92 typing
# 58 tyre
# 49 ua
# 78 ub
# 44 ubc
# 38 ubc ca
# 46 ubvmsb
# 46 ubvmsb cc
# 46 ubvmsb cc buffalo
# 46 ubvmsb cc buffalo edu
# 68 uc
# 140 uchicago
# 126 uchicago edu
# 129 uci
# 115 uci edu
# 38 uci edu incoming
# 49 ucla
# 177 ucs
# 82 ucs indiana
# 82 ucs indiana edu
# 50 ucsc
# 43 ucsc edu
# 116 ucsd
# 72 ucsd edu
# 42 ud
# 127 udel
# 108 udel edu
# 67 ufl
# 54 ufl edu
# 52 ug
# 112 uga
# 108 uga edu
# 40 uga edu university
# 40 uga edu university georgia
# 66 ugly
# 159 uh
# 42 uh edu
# 50 uhura
# 633 uiuc
# 584 uiuc edu
# 62 uiuc edu mike
# 61 uiuc edu mike cobb
# 58 uiuc edu mike cobb writes
# 1014 uk
# 71 uk ac
# 45 uky
# 43 uky edu
# 51 ul
# 69 ulf
# 42 ultb
# 38 ultb isc
# 38 ultb isc rit
# 89 ultimate
# 75 ultimately
# 149 ultra
# 49 ultra pro
# 38 ultrix
# 38 ulysses
# 231 um
# 60 um um
# 43 um um um
# 49 umanitoba
# 41 umanitoba ca
# 52 umass
# 206 umd
# 183 umd edu
# 116 umich
# 104 umich edu
# 80 umn
# 66 umn edu
# 50 umpire
# 278 un
# 148 unable
# 39 unarmed
# 97 unc
# 81 unc edu
# 45 uncle
# 45 unclear
# 55 undefined
# 42 underground
# 40 underlying
# 889 understand
# 320 understanding
# 40 understands
# 153 understood
# 51 unfair
# 63 unfortunate
# 428 unfortunately
# 176 uni
# 84 uniform
# 130 union
# 108 unique
# 379 unit
# 578 united
# 49 united nations
# 430 united states
# 163 units
# 59 unity
# 159 univ
# 114 universal
# 419 universe
# 67 universities
# 1819 university
# 64 university california
# 48 university georgia
# 56 university illinois
# 48 university press
# 590 unix
# 161 unknown
# 787 unless
# 46 unless otherwise
# 159 unlike
# 150 unlikely
# 41 unlimited
# 48 unm
# 42 unm edu
# 53 unnecessary
# 69 unreasonable
# 157 unto
# 95 unusual
# 66 uoknor
# 65 uoknor edu
# 123 update
# 100 updated
# 45 updates
# 115 upenn
# 108 upenn edu
# 231 upgrade
# 69 upgraded
# 41 upgrades
# 47 upgrading
# 41 upi
# 659 upon
# 96 upper
# 84 ups
# 90 upset
# 45 uq
# 40 uranium
# 57 urartu
# 55 urartu sdpa
# 55 urartu sdpa org
# 51 urban
# 67 urbana
# 43 urge
# 3946 us
# 50 us government
# 48 us know
# 601 usa
# 39 usable
# 161 usage
# 92 usc
# 66 usc edu
# 5019 use
# 49 use force
# 49 use one
# 3092 used
# 486 useful
# 134 useless
# 470 usenet
# 62 usenet news
# 45 usenet news answers
# 714 user
# 70 user interface
# 582 users
# 600 uses
# 2281 using
# 47 usl
# 38 usl edu
# 280 usr
# 96 usr lib
# 203 usual
# 668 usually
# 93 ut
# 151 utah
# 184 utexas
# 160 utexas edu
# 38 utica
# 142 utilities
# 181 utility
# 91 utk
# 86 utk edu
# 59 utkvm
# 59 utkvm utk
# 59 utkvm utk edu
# 57 utoronto
# 53 utoronto ca
# 48 utter
# 57 utterly
# 66 utzoo
# 57 utzoo henry
# 160 uu
# 82 uu net
# 691 uucp
# 199 uucp frank
# 198 uucp frank dwyer
# 178 uucp frank dwyer writes
# 102 uucp frank dwyer writes article
# 99 uucp uunet
# 48 uuencode
# 464 uunet
# 61 uunet pyramid
# 56 uunet pyramid optilink
# 54 uunet pyramid optilink cramer
# 54 uunet pyramid optilink cramer opinions
# 54 uunet pyramid optilink cramer opinions mine
# 53 uunet uu
# 50 uunet uu net
# 69 uv
# 61 uw
# 74 uwaterloo
# 71 uwaterloo ca
# 41 uwm
# 87 uwo
# 74 uwo ca
# 131 ux
# 62 ux cso
# 62 ux cso uiuc
# 62 ux cso uiuc edu
# 164 uxa
# 150 uxa cso
# 150 uxa cso uiuc
# 147 uxa cso uiuc edu
# 47 uxh
# 47 uxh cso
# 47 uxh cso uiuc
# 47 uxh cso uiuc edu
# 39 uy
# 132 va
# 40 vacation
# 72 vacuum
# 48 vague
# 73 valentine
# 250 valid
# 50 validity
# 65 valley
# 102 valuable
# 889 value
# 48 valued
# 628 values
# 95 valve
# 343 van
# 259 vancouver
# 96 variable
# 56 variables
# 43 variations
# 149 variety
# 521 various
# 104 vary
# 100 vast
# 66 vat
# 175 vax
# 55 vb
# 45 vcr
# 41 vd
# 67 veal
# 53 vector
# 252 vehicle
# 112 vehicles
# 64 velocity
# 120 vendor
# 96 vendors
# 46 venture
# 186 venus
# 44 ver
# 76 verify
# 57 vernon
# 44 versa
# 123 verse
# 131 verses
# 1249 version
# 47 version available
# 275 versions
# 83 versus
# 103 vertical
# 131 vesa
# 39 vesselin
# 43 veteran
# 66 vf
# 40 vfr
# 39 vg
# 332 vga
# 40 vhs
# 81 vi
# 635 via
# 87 via anonymous
# 78 via anonymous ftp
# 65 via email
# 47 via ftp
# 90 via mail
# 189 vice
# 55 vice ico
# 55 vice ico tek
# 55 vice ico tek com
# 60 vice president
# 39 vice versa
# 100 victim
# 163 victims
# 38 victor
# 66 victory
# 726 video
# 103 video card
# 42 vietnam
# 734 view
# 54 viewed
# 139 viewer
# 72 viewers
# 107 viewing
# 60 viewpoint
# 351 views
# 70 viking
# 186 village
# 206 villages
# 47 vincent
# 44 viola
# 45 violate
# 67 violated
# 128 violation
# 70 violations
# 213 violence
# 160 violent
# 64 virgin
# 319 virginia
# 190 virginia edu
# 196 virtual
# 43 virtual reality
# 135 virtually
# 45 virtue
# 104 virus
# 182 visible
# 170 vision
# 131 visit
# 55 visited
# 222 visual
# 72 visualization
# 40 vital
# 158 vitamin
# 93 vl
# 124 vlb
# 112 vm
# 143 vms
# 89 vnet
# 70 vnet ibm
# 68 vnet ibm com
# 46 vo
# 510 voice
# 64 voice fax
# 94 void
# 132 vol
# 46 volt
# 150 voltage
# 49 volts
# 361 volume
# 76 volume number
# 68 volume number april
# 52 voluntary
# 55 volunteer
# 40 volunteers
# 49 von
# 69 vos
# 69 vos stratus
# 69 vos stratus com
# 61 vos stratus com write
# 61 vos stratus com write today
# 61 vos stratus com write today special
# 246 vote
# 66 voted
# 83 votes
# 52 voting
# 62 voyager
# 53 vp
# 51 vpic
# 46 vr
# 114 vram
# 541 vs
# 129 vt
# 61 vt edu
# 46 vv
# 73 vw
# 163 wa
# 315 waco
# 56 wade
# 44 wagon
# 431 wait
# 66 waited
# 240 waiting
# 51 wake
# 54 waldrop
# 198 walk
# 71 walked
# 108 walker
# 45 walker writes
# 94 walking
# 61 walks
# 243 wall
# 77 walls
# 49 walsh
# 69 walter
# 77 wam
# 76 wam umd
# 57 wam umd edu
# 60 wanna
# 3392 want
# 74 want get
# 56 want go
# 115 want know
# 69 want see
# 82 want use
# 666 wanted
# 45 wanted know
# 73 wanting
# 514 wants
# 44 wantto
# 979 war
# 46 war drugs
# 43 war ii
# 76 ward
# 48 warfare
# 86 warm
# 47 warn
# 54 warned
# 215 warning
# 292 warrant
# 66 warrants
# 118 warranty
# 82 warren
# 146 wars
# 67 wash
# 39 washed
# 576 washington
# 77 washington dc
# 125 washington edu
# 213 waste
# 67 waste time
# 46 wasted
# 47 wasting
# 385 watch
# 104 watched
# 234 watching
# 551 water
# 38 waterloo
# 118 watson
# 64 watson ibm
# 64 watson ibm com
# 60 watt
# 69 watts
# 184 wave
# 47 waves
# 63 wax
# 4060 way
# 38 way around
# 87 way get
# 40 way make
# 187 wayne
# 495 ways
# 122 ways escape
# 110 ways escape turks
# 110 ways escape turks proceeded
# 110 ways escape turks proceeded work
# 110 ways escape turks proceeded work extermination
# 79 wb
# 89 wc
# 157 wd
# 191 weak
# 47 weakness
# 38 wealthy
# 253 weapon
# 569 weapons
# 126 wear
# 128 wearing
# 91 weather
# 70 weaver
# 77 wed
# 47 wed apr
# 99 wednesday
# 610 week
# 127 weekend
# 51 weekly
# 479 weeks
# 107 weeks ago
# 262 weight
# 117 weird
# 39 weird al
# 48 weiss
# 250 welcome
# 65 welfare
# 4511 well
# 57 well know
# 99 well known
# 67 well regulated
# 51 well regulated militia
# 45 well sf
# 45 well sf ca
# 40 well sf ca us
# 45 well think
# 44 wells
# 941 went
# 373 west
# 66 west bank
# 376 western
# 58 western digital
# 41 wet
# 61 wg
# 46 whalers
# 695 whatever
# 88 whatsoever
# 177 wheel
# 98 wheels
# 137 whenever
# 110 whereas
# 42 wherever
# 1218 whether
# 795 white
# 183 white house
# 117 whoever
# 960 whole
# 64 whole thing
# 424 whose
# 51 wi
# 313 wide
# 135 widely
# 82 widespread
# 332 widget
# 139 widgets
# 126 width
# 39 width height
# 388 wife
# 151 wild
# 44 willamerican
# 44 willamerican occupied
# 44 willamerican occupied new
# 44 willamerican occupied new york
# 44 willamerican occupied new york replaced
# 44 willamerican occupied new york replaced jimmy
# 55 willbe
# 238 william
# 127 williams
# 41 willie
# 490 willing
# 150 wilson
# 1023 win
# 130 wind
# 1129 window
# 146 window manager
# 60 window system
# 2375 windows
# 44 windows dos
# 87 windows microsoft
# 84 windows microsoft windows
# 71 windows microsoft windows microsoft
# 71 windows microsoft windows microsoft windows
# 58 windows microsoft windows microsoft windows microsoft
# 81 windows nt
# 40 windows version
# 75 winfield
# 113 wing
# 40 wingate
# 225 wings
# 83 winner
# 51 winners
# 213 winning
# 141 winnipeg
# 59 winnipeg jets
# 150 wins
# 88 winter
# 244 wire
# 40 wired
# 103 wires
# 139 wiretap
# 58 wiretaps
# 105 wiring
# 77 wisc
# 75 wisc edu
# 48 wisconsin
# 142 wisdom
# 159 wise
# 458 wish
# 77 wishes
# 64 witha
# 40 withdraw
# 754 within
# 2071 without
# 141 withthe
# 126 witness
# 45 witnessed
# 109 witnesses
# 49 wives
# 44 wk
# 191 wm
# 41 wn
# 113 wolverine
# 40 wolves
# 332 woman
# 683 women
# 82 women children
# 436 wonder
# 70 wondered
# 138 wonderful
# 404 wondering
# 80 wondering anyone
# 156 wood
# 48 woods
# 1120 word
# 44 word god
# 43 wordperfect
# 765 words
# 2962 work
# 122 work extermination
# 111 work extermination ohanus
# 111 work extermination ohanus appressian
# 110 work extermination ohanus appressian soviet
# 110 work extermination ohanus appressian soviet armenia
# 46 work fine
# 45 work one
# 51 work well
# 385 worked
# 115 workers
# 822 working
# 980 works
# 101 works fine
# 47 works great
# 50 works well
# 39 workshop
# 98 workstation
# 77 workstations
# 2080 world
# 52 world series
# 130 world std
# 120 world std com
# 105 world war
# 40 worldwide
# 100 worried
# 232 worry
# 372 worse
# 201 worship
# 199 worst
# 578 worth
# 70 worthless
# 67 worthwhile
# 75 worthy
# 11830 would
# 59 would able
# 47 would agree
# 140 would also
# 38 would also like
# 120 would appreciate
# 141 would appreciated
# 40 would ask
# 116 would better
# 39 would certainly
# 48 would come
# 41 would consider
# 42 would cost
# 60 would expect
# 44 would find
# 101 would get
# 59 would give
# 90 would go
# 54 would good
# 42 would great
# 143 would greatly
# 104 would greatly appreciated
# 45 would happen
# 74 would help
# 53 would interested
# 38 would know
# 823 would like
# 47 would like get
# 90 would like know
# 41 would likely
# 38 would look
# 52 would love
# 41 would made
# 147 would make
# 105 would much
# 80 would need
# 98 would never
# 115 would nice
# 49 would prefer
# 105 would probably
# 92 would rather
# 70 would really
# 156 would say
# 40 would see
# 53 would seem
# 42 would someone
# 49 would still
# 61 would suggest
# 90 would take
# 99 would think
# 92 would want
# 42 would willing
# 58 would work
# 64 wouldbe
# 47 wouldhave
# 44 wound
# 76 wounded
# 66 wounds
# 96 wow
# 53 wp
# 94 wpd
# 94 wpd sgi
# 94 wpd sgi com
# 86 wpd sgi com jon
# 86 wpd sgi com jon livesey
# 84 wpd sgi com jon livesey writes
# 42 wpg
# 115 wpi
# 65 wpi edu
# 45 wpi wpi
# 44 wpi wpi edu
# 40 wq
# 49 wrap
# 114 wright
# 780 write
# 61 write today
# 61 write today special
# 61 write today special investors
# 61 write today special investors packet
# 101 writer
# 72 writers
# 11687 writes
# 41 writes actually
# 41 writes also
# 44 writes anybody
# 177 writes anyone
# 56 writes anyone know
# 2245 writes article
# 78 writes article frank
# 78 writes article frank uucp
# 78 writes article frank uucp frank
# 78 writes article frank uucp frank dwyer
# 41 writes heard
# 73 writes hello
# 146 writes hi
# 73 writes know
# 73 writes looking
# 104 writes one
# 43 writes previous
# 41 writes previous article
# 48 writes question
# 49 writes recently
# 38 writes since
# 59 writes someone
# 48 writes stuff
# 95 writes think
# 100 writes well
# 47 writes wondering
# 99 writes would
# 40 writes would like
# 336 writing
# 102 writings
# 578 written
# 1496 wrong
# 1332 wrote
# 134 wrote article
# 87 ws
# 55 wsh
# 90 wt
# 39 wu
# 60 wuarchive
# 42 wuarchive wustl
# 42 wuarchive wustl edu
# 87 wustl
# 81 wustl edu
# 44 wv
# 99 ww
# 72 wwii
# 38 xa
# 52 xc
# 112 xdm
# 43 xerox
# 136 xfree
# 42 xi
# 70 xl
# 130 xlib
# 52 xloadimage
# 71 xm
# 68 xmu
# 53 xmu libxmu
# 40 xor
# 57 xp
# 41 xr
# 49 xs
# 279 xt
# 258 xterm
# 280 xv
# 200 xview
# 44 xwd
# 406 xx
# 51 xxx
# 38 xxxxx
# 130 ya
# 91 yale
# 61 yale edu
# 68 yamaha
# 79 yankees
# 39 yanks
# 48 yard
# 62 yassin
# 51 yd
# 103 ye
# 364 yeah
# 41 yeah right
# 2377 year
# 60 year ago
# 211 year old
# 2266 years
# 416 years ago
# 47 years george
# 47 years george bush
# 44 years george bush willamerican
# 44 years george bush willamerican occupied
# 44 years george bush willamerican occupied new
# 100 years old
# 117 yeast
# 74 yellow
# 56 yep
# 1441 yes
# 44 yes know
# 302 yesterday
# 1317 yet
# 96 yet another
# 65 yf
# 42 yield
# 52 yigal
# 39 yo
# 570 york
# 47 york replaced
# 47 york replaced jimmy
# 47 york replaced jimmy carter
# 44 york replaced jimmy carter themy
# 44 york replaced jimmy carter themy opinions
# 48 york times
# 38 youare
# 57 youcan
# 54 youhave
# 513 young
# 44 young people
# 50 younger
# 72 youth
# 42 yoyo
# 42 yoyo cc
# 42 yoyo cc monash
# 42 yoyo cc monash edu
# 42 yoyo cc monash edu au
# 44 yr
# 89 yugoslavia
# 47 yup
# 88 yx
# 67 za
# 54 zd
# 86 zealand
# 173 zero
# 51 zeus
# 43 zinaida
# 77 zionism
# 89 zionist
# 255 zip
# 49 zm
# 184 zone
# 112 zoo
# 101 zoo toronto
# 101 zoo toronto edu
# 62 zoo toronto edu utzoo
# 57 zoo toronto edu utzoo henry
# 42 zoology
# 54 zoom
# 57 zv
# 76 zx

# %%
from operator import itemgetter
f = zip(vocab, dist)
sorted(f,key=itemgetter(1), reverse=True)
# Out:
# [(u'ax', 30962),
#  (u'ax ax', 27931),
#  (u'ax ax ax', 25119),
#  (u'ax ax ax ax', 22450),
#  (u'ax ax ax ax ax', 19926),
#  (u'ax ax ax ax ax ax', 17567),
#  (u'would', 11830),
#  (u'one', 11816),
#  (u'writes', 11687),
#  (u'edu', 11522),
#  (u'article', 9972),
#  (u'com', 7753),
#  (u'like', 7747),
#  (u'people', 7545),
#  (u'know', 6930),
#  (u'get', 6441),
#  (u'think', 6050),
#  (u'also', 5675),
#  (u'time', 5286),
#  (u'use', 5019),
#  (u'could', 4606),
#  (u'well', 4511),
#  (u'good', 4488),
#  (u'new', 4371),
#  (u'may', 4223),
#  (u'even', 4216),
#  (u'see', 4160),
#  (u'way', 4060),
#  (u'us', 3946),
#  (u'god', 3918),
#  (u'make', 3843),
#  (u'two', 3829),
#  (u'much', 3758),
#  (u'right', 3756),
#  (u'many', 3744),
#  (u'say', 3739),
#  (u'first', 3729),
#  (u'want', 3392),
#  (u'said', 3371),
#  (u'system', 3316),
#  (u'anyone', 3312),
#  (u'go', 3150),
#  (u'used', 3092),
#  (u'work', 2962),
#  (u'need', 2901),
#  (u'really', 2861),
#  (u'something', 2833),
#  (u'since', 2776),
#  (u'believe', 2746),
#  (u'please', 2684),
#  (u'problem', 2672),
#  (u'still', 2645),
#  (u'back', 2597),
#  (u'max', 2539),
#  (u'going', 2496),
#  (u'point', 2488),
#  (u'find', 2470),
#  (u'mail', 2469),
#  (u'take', 2433),
#  (u'might', 2405),
#  (u'better', 2382),
#  (u'year', 2377),
#  (u'windows', 2375),
#  (u'never', 2358),
#  (u'file', 2349),
#  (u'last', 2346),
#  (u'government', 2337),
#  (u'information', 2314),
#  (u'using', 2281),
#  (u'years', 2266),
#  (u'things', 2260),
#  (u'writes article', 2245),
#  (u'etc', 2238),
#  (u'must', 2218),
#  (u'thanks', 2209),
#  (u'sure', 2192),
#  (u'read', 2184),
#  (u'question', 2183),
#  (u'ax max', 2148),
#  (u'max ax', 2146),
#  (u'help', 2130),
#  (u'made', 2128),
#  (u'someone', 2128),
#  (u'another', 2118),
#  (u'max ax ax', 2108),
#  (u'bit', 2091),
#  (u'ax ax max', 2086),
#  (u'world', 2080),
#  (u'thing', 2078),
#  (u'ax max ax', 2077),
#  (u'let', 2074),
#  (u'ca', 2072),
#  (u'without', 2071),
#  (u'max ax ax ax', 2053),
#  (u'got', 2046),
#  (u'ax max ax ax', 2042),
#  (u'number', 2040),
#  (u'ax ax ax max', 2033),
#  (u'ax ax max ax', 2019),
#  (u'look', 2018),
#  (u'max ax ax ax ax', 2014),
#  (u'fact', 2001),
#  (u'ax max ax ax ax', 1992),
#  (u'ax ax max ax ax', 1988),
#  (u'ax ax ax max ax', 1976),
#  (u'ax ax ax ax max', 1969),
#  (u'ax max ax ax ax ax', 1956),
#  (u'however', 1956),
#  (u'drive', 1949),
#  (u'ax ax ax max ax ax', 1947),
#  (u'max ax ax ax ax ax', 1945),
#  (u'ax ax max ax ax ax', 1944),
#  (u'ax ax ax ax ax max', 1933),
#  (u'ax ax ax ax max ax', 1933),
#  (u'part', 1933),
#  (u'state', 1922),
#  (u'come', 1920),
#  (u'long', 1908),
#  (u'data', 1870),
#  (u'anything', 1864),
#  (u'law', 1862),
#  (u'program', 1859),
#  (u'day', 1858),
#  (u'case', 1829),
#  (u'available', 1823),
#  (u'university', 1819),
#  (u'true', 1817),
#  (u'power', 1812),
#  (u'around', 1803),
#  (u'space', 1795),
#  (u'cs', 1784),
#  (u'little', 1784),
#  (u'give', 1762),
#  (u'dos', 1752),
#  (u'every', 1732),
#  (u'best', 1728),
#  (u'seems', 1710),
#  (u'game', 1709),
#  (u'probably', 1694),
#  (u'try', 1693),
#  (u'least', 1672),
#  (u'different', 1671),
#  (u'put', 1671),
#  (u'course', 1655),
#  (u'lot', 1655),
#  (u'actually', 1653),
#  (u'car', 1652),
#  (u'set', 1650),
#  (u'david', 1645),
#  (u'tell', 1645),
#  (u'enough', 1630),
#  (u'says', 1605),
#  (u'great', 1596),
#  (u'though', 1581),
#  (u'far', 1578),
#  (u'run', 1577),
#  (u'real', 1574),
#  (u'software', 1565),
#  (u'support', 1556),
#  (u'either', 1552),
#  (u'life', 1551),
#  (u'mean', 1545),
#  (u'high', 1538),
#  (u'key', 1538),
#  (u'man', 1535),
#  (u'nothing', 1532),
#  (u'called', 1524),
#  (u'name', 1516),
#  (u'line', 1514),
#  (u'hard', 1513),
#  (u'second', 1513),
#  (u'wrong', 1496),
#  (u'group', 1495),
#  (u'else', 1491),
#  (u'free', 1491),
#  (u'john', 1490),
#  (u'computer', 1483),
#  (u'call', 1470),
#  (u'old', 1455),
#  (u'possible', 1454),
#  (u'end', 1445),
#  (u'rather', 1441),
#  (u'yes', 1441),
#  (u'jesus', 1436),
#  (u'post', 1426),
#  (u'image', 1419),
#  (u'reason', 1411),
#  (u'maybe', 1405),
#  (u'non', 1398),
#  (u'others', 1389),
#  (u'list', 1380),
#  (u'card', 1370),
#  (u'done', 1366),
#  (u'keep', 1359),
#  (u'found', 1355),
#  (u'order', 1343),
#  (u'example', 1335),
#  (u'based', 1332),
#  (u'wrote', 1332),
#  (u'seen', 1329),
#  (u'next', 1323),
#  (u'three', 1323),
#  (u'able', 1322),
#  (u'place', 1320),
#  (u'person', 1318),
#  (u'yet', 1317),
#  (u'team', 1304),
#  (u'ever', 1294),
#  (u'quite', 1292),
#  (u'bad', 1285),
#  (u'looking', 1274),
#  (u'always', 1270),
#  (u'heard', 1267),
#  (u'following', 1265),
#  (u'public', 1260),
#  (u'thought', 1251),
#  (u'version', 1249),
#  (u'means', 1247),
#  (u'problems', 1247),
#  (u'evidence', 1245),
#  (u'left', 1240),
#  (u'files', 1238),
#  (u'email', 1236),
#  (u'general', 1235),
#  (u'send', 1234),
#  (u'away', 1220),
#  (u'trying', 1218),
#  (u'whether', 1218),
#  (u'given', 1217),
#  (u'net', 1216),
#  (u'science', 1212),
#  (u'start', 1208),
#  (u'gun', 1207),
#  (u'bill', 1206),
#  (u'idea', 1206),
#  (u'book', 1186),
#  (u'times', 1183),
#  (u'phone', 1182),
#  (u'less', 1180),
#  (u'today', 1178),
#  (u'note', 1167),
#  (u'mr', 1162),
#  (u'children', 1160),
#  (u'kind', 1160),
#  (u'home', 1153),
#  (u'seem', 1151),
#  (u'getting', 1148),
#  (u'news', 1139),
#  (u'remember', 1136),
#  (u'control', 1130),
#  (u'pc', 1129),
#  (u'window', 1129),
#  (u'big', 1121),
#  (u'human', 1121),
#  (u'sun', 1120),
#  (u'word', 1120),
#  (u'subject', 1117),
#  (u'several', 1113),
#  (u'perhaps', 1109),
#  (u'systems', 1101),
#  (u'st', 1096),
#  (u'full', 1088),
#  (u'makes', 1088),
#  (u'change', 1082),
#  (u'mac', 1080),
#  (u'saying', 1080),
#  (u'internet', 1079),
#  (u'president', 1077),
#  (u'chip', 1075),
#  (u'ask', 1071),
#  (u'cannot', 1068),
#  (u'disk', 1067),
#  (u'price', 1066),
#  (u'standard', 1066),
#  (u'opinions', 1060),
#  (u'already', 1058),
#  (u'mark', 1054),
#  (u'graphics', 1053),
#  (u'local', 1050),
#  (u'scsi', 1049),
#  (u'israel', 1036),
#  (u'religion', 1032),
#  (u'christian', 1028),
#  (u'mb', 1028),
#  (u'rights', 1026),
#  (u'research', 1025),
#  (u'win', 1023),
#  (u'told', 1020),
#  (u'ftp', 1019),
#  (u'money', 1017),
#  (u'ms', 1015),
#  (u'ago', 1014),
#  (u'uk', 1014),
#  (u'fax', 1010),
#  (u'interested', 1010),
#  (u'speed', 1007),
#  (u'came', 1006),
#  (u'matter', 1004),
#  (u'questions', 1004),
#  (u'answer', 1003),
#  (u'american', 1000),
#  (u'fbi', 999),
#  (u'large', 999),
#  (u'agree', 991),
#  (u'games', 990),
#  (u'jews', 988),
#  (u'info', 986),
#  (u'bible', 984),
#  (u'hope', 981),
#  (u'works', 980),
#  (u'small', 979),
#  (u'war', 979),
#  (u'issue', 978),
#  (u'show', 978),
#  (u'source', 971),
#  (u'states', 968),
#  (u'days', 966),
#  (u'stuff', 965),
#  (u'play', 963),
#  (u'claim', 962),
#  (u'fire', 962),
#  (u'whole', 960),
#  (u'running', 958),
#  (u'access', 951),
#  (u'care', 941),
#  (u'live', 941),
#  (u'pretty', 941),
#  (u'turkish', 941),
#  (u'went', 941),
#  (u'code', 939),
#  (u'address', 938),
#  (u'buy', 938),
#  (u'everything', 934),
#  (u'national', 932),
#  (u'earth', 922),
#  (u'box', 917),
#  (u'original', 917),
#  (u'feel', 914),
#  (u'th', 904),
#  (u'truth', 904),
#  (u'armenian', 903),
#  (u'message', 903),
#  (u'everyone', 902),
#  (u'hand', 902),
#  (u'often', 898),
#  (u'started', 898),
#  (u'current', 893),
#  (u'important', 893),
#  (u'open', 893),
#  (u'ac', 890),
#  (u'color', 890),
#  (u'understand', 889),
#  (u'value', 889),
#  (u'type', 886),
#  (u'mind', 883),
#  (u'nasa', 883),
#  (u'church', 878),
#  (u'love', 874),
#  (u'guess', 873),
#  (u'apple', 869),
#  (u'april', 868),
#  (u'area', 867),
#  (u'pay', 866),
#  (u'side', 866),
#  (u'anyway', 865),
#  (u'history', 864),
#  (u'machine', 864),
#  (u'frank', 863),
#  (u'simply', 862),
#  (u'including', 859),
#  (u'programs', 858),
#  (u'certainly', 856),
#  (u'cause', 850),
#  (u'almost', 848),
#  (u'instead', 848),
#  (u'men', 848),
#  (u'christ', 847),
#  (u'include', 846),
#  (u'although', 844),
#  (u'memory', 842),
#  (u'center', 840),
#  (u'comes', 839),
#  (u'later', 831),
#  (u'light', 828),
#  (u'michael', 827),
#  (u'country', 824),
#  (u'making', 824),
#  (u'would like', 823),
#  (u'black', 822),
#  (u'working', 822),
#  (u'cc', 820),
#  (u'cost', 819),
#  (u'paul', 815),
#  (u'display', 813),
#  (u'mike', 812),
#  (u'ibm', 806),
#  (u'steve', 806),
#  (u'server', 803),
#  (u'death', 799),
#  (u'talk', 798),
#  (u'technology', 797),
#  (u'tried', 797),
#  (u'gov', 796),
#  (u'objective', 796),
#  (u'white', 795),
#  (u'low', 794),
#  (u'de', 789),
#  (u'sort', 787),
#  (u'unless', 787),
#  (u'faith', 785),
#  (u'house', 784),
#  (u'oh', 783),
#  (u'check', 782),
#  (u'write', 780),
#  (u'opinion', 779),
#  (u'copy', 778),
#  (u'org', 777),
#  (u'hi', 776),
#  (u'ok', 776),
#  (u'posting', 774),
#  (u'sense', 774),
#  (u'anybody', 768),
#  (u'difference', 765),
#  (u'words', 765),
#  (u'known', 764),
#  (u'christians', 763),
#  (u'major', 761),
#  (u'single', 761),
#  (u'armenians', 760),
#  (u'talking', 758),
#  (u'night', 755),
#  (u'within', 754),
#  (u'hell', 753),
#  (u'consider', 751),
#  (u'package', 747),
#  (u'similar', 744),
#  (u'koresh', 743),
#  (u'saw', 743),
#  (u'religious', 740),
#  (u'jpeg', 736),
#  (u'correct', 735),
#  (u'hp', 735),
#  (u'deal', 734),
#  (u'view', 734),
#  (u'clear', 733),
#  (u'couple', 732),
#  (u'jim', 728),
#  (u'likely', 728),
#  (u'especially', 726),
#  (u'video', 726),
#  (u'argument', 725),
#  (u'dead', 725),
#  (u'nice', 725),
#  (u'took', 725),
#  (u'encryption', 724),
#  (u'police', 722),
#  (u'sorry', 718),
#  (u'thus', 717),
#  (u'press', 715),
#  (u'exactly', 714),
#  (u'user', 714),
#  (u'certain', 713),
#  (u'jewish', 713),
#  (u'size', 713),
#  (u'guns', 711),
#  (u'stop', 710),
#  (u'body', 709),
#  (u'simple', 709),
#  (u'fine', 704),
#  (u'goes', 704),
#  (u'moral', 702),
#  (u'per', 700),
#  (u'third', 700),
#  (u'provide', 699),
#  (u'taken', 698),
#  (u'private', 697),
#  (u'force', 696),
#  (u'sound', 695),
#  (u'whatever', 695),
#  (u'uucp', 691),
#  (u'hockey', 689),
#  (u'top', 689),
#  (u'situation', 686),
#  (u'women', 683),
#  (u'self', 682),
#  (u'asked', 681),
#  (u'company', 681),
#  (u'laws', 681),
#  (u'except', 680),
#  (u'city', 678),
#  (u'contact', 678),
#  (u'security', 678),
#  (u'board', 677),
#  (u'level', 675),
#  (u'ed', 673),
#  (u'happened', 673),
#  (u'killed', 673),
#  (u'screen', 673),
#  (u'format', 670),
#  (u'mine', 669),
#  (u'rest', 668),
#  (u'statement', 668),
#  (u'usually', 668),
#  (u'become', 667),
#  (u'faq', 667),
#  (u'hear', 667),
#  (u'service', 667),
#  (u'wanted', 666),
#  (u'past', 665),
#  (u'position', 665),
#  (u'business', 664),
#  (u'edu writes', 664),
#  (u'four', 664),
#  (u'therefore', 660),
#  (u'common', 659),
#  (u'upon', 659),
#  (u'clinton', 657),
#  (u'theory', 657),
#  (u'head', 656),
#  (u'health', 656),
#  (u'society', 656),
#  (u'text', 655),
#  (u'driver', 654),
#  (u'lines', 654),
#  (u'form', 653),
#  (u'mit', 653),
#  (u'experience', 652),
#  (u'hardware', 652),
#  (u'add', 651),
#  (u'co', 651),
#  (u'fast', 651),
#  (u'model', 651),
#  (u'short', 651),
#  (u'turn', 651),
#  (u'easy', 649),
#  (u'bus', 648),
#  (u'advance', 647),
#  (u'books', 647),
#  (u'reading', 646),
#  (u'political', 645),
#  (u'school', 644),
#  (u'interesting', 643),
#  (u'exist', 642),
#  (u'according', 641),
#  (u'guy', 639),
#  (u'lost', 639),
#  (u'images', 638),
#  (u'effect', 637),
#  (u'groups', 637),
#  (u'inc', 636),
#  (u'via', 635),
#  (u'uiuc', 633),
#  (u'numbers', 632),
#  (u'players', 632),
#  (u'discussion', 631),
#  (u'points', 630),
#  (u'months', 629),
#  (u'values', 628),
#  (u'peace', 627),
#  (u'season', 627),
#  (u'face', 625),
#  (u'move', 623),
#  (u'os', 621),
#  (u'hit', 620),
#  (u'happen', 619),
#  (u'netcom', 619),
#  (u'personal', 619),
#  (u'particular', 618),
#  (u'red', 618),
#  (u'canada', 617),
#  (u'dod', 617),
#  (u'application', 614),
#  (u'bike', 614),
#  (u'monitor', 614),
#  (u'radio', 613),
#  (u'test', 613),
#  (u'kill', 611),
#  (u'series', 611),
#  (u'week', 610),
#  (u'early', 609),
#  (u'needs', 609),
#  (u'among', 607),
#  (u'due', 604),
#  (u'error', 603),
#  (u'ones', 603),
#  (u'period', 603),
#  (u'anti', 601),
#  (u'expect', 601),
#  (u'outside', 601),
#  (u'usa', 601),
#  (u'job', 600),
#  (u'sell', 600),
#  (u'uses', 600),
#  (u'cd', 599),
#  (u'clipper', 599),
#  (u'mhz', 598),
#  (u'gets', 597),
#  (u'recently', 597),
#  (u'ground', 594),
#  (u'special', 593),
#  (u'accept', 592),
#  (u'front', 592),
#  (u'robert', 592),
#  (u'keys', 591),
#  (u'longer', 590),
#  (u'shall', 590),
#  (u'unix', 590),
#  (u'specific', 587),
#  (u'members', 586),
#  (u'posted', 586),
#  (u'uiuc edu', 584),
#  (u'dave', 582),
#  (u'users', 582),
#  (u'netcom com', 580),
#  (u'bob', 578),
#  (u'coming', 578),
#  (u'united', 578),
#  (u'worth', 578),
#  (u'written', 578),
#  (u'plus', 576),
#  (u'washington', 576),
#  (u'assume', 574),
#  (u'network', 574),
#  (u'explain', 573),
#  (u'study', 572),
#  (u'taking', 572),
#  (u'runs', 571),
#  (u'drivers', 570),
#  (u'output', 570),
#  (u'york', 570),
#  (u'weapons', 569),
#  (u'al', 568),
#  (u'cars', 567),
#  (u'mode', 567),
#  (u'process', 567),
#  (u'insurance', 566),
#  (u'reference', 566),
#  (u'thinking', 566),
#  (u'league', 565),
#  (u'sometimes', 565),
#  (u'action', 564),
#  (u'friend', 564),
#  (u'future', 558),
#  (u'gif', 558),
#  (u'lord', 558),
#  (u'israeli', 557),
#  (u'looks', 557),
#  (u'medical', 557),
#  (u'necessary', 557),
#  (u'response', 557),
#  (u'involved', 555),
#  (u'brian', 552),
#  (u'gas', 552),
#  (u'knows', 551),
#  (u'save', 551),
#  (u'water', 551),
#  (u'dr', 550),
#  (u'speak', 549),
#  (u'considered', 548),
#  (u'total', 548),
#  (u'million', 546),
#  (u'office', 546),
#  (u'toronto', 545),
#  (u'hold', 544),
#  (u'near', 543),
#  (u'james', 541),
#  (u'soon', 541),
#  (u'vs', 541),
#  (u'close', 540),
#  (u'land', 540),
#  (u'offer', 540),
#  (u'san', 540),
#  (u'military', 539),
#  (u'party', 539),
#  (u'department', 538),
#  (u'quality', 538),
#  (u'building', 536),
#  (u'legal', 536),
#  (u'behind', 535),
#  (u'built', 535),
#  (u'doubt', 535),
#  (u'ii', 535),
#  (u'manager', 535),
#  (u'return', 535),
#  (u'act', 534),
#  (u'build', 533),
#  (u'date', 532),
#  (u'deleted', 532),
#  (u'result', 532),
#  (u'results', 532),
#  (u'includes', 531),
#  (u'asking', 530),
#  (u'rate', 529),
#  (u'along', 528),
#  (u'story', 528),
#  (u'allow', 527),
#  (u'baseball', 526),
#  (u'federal', 526),
#  (u'new york', 526),
#  (u'together', 525),
#  (u'appreciated', 524),
#  (u'cases', 524),
#  (u'player', 523),
#  (u'road', 522),
#  (u'crime', 521),
#  (u'policy', 521),
#  (u'various', 521),
#  (u'strong', 519),
#  (u'armenia', 518),
#  (u'leave', 518),
#  (u'report', 518),
#  (u'au', 517),
#  (u'cut', 517),
#  (u'sources', 517),
#  (u'sin', 516),
#  (u'exists', 515),
#  (u'freedom', 514),
#  (u'peter', 514),
#  (u'wants', 514),
#  (u'young', 513),
#  (u'previous', 512),
#  (u'anyone know', 511),
#  (u'parts', 511),
#  (u'sale', 511),
#  (u'batf', 510),
#  (u'request', 510),
#  (u'voice', 510),
#  (u'controller', 507),
#  (u'follow', 507),
#  (u'knowledge', 507),
#  (u'soviet', 507),
#  (u'present', 506),
#  (u'air', 505),
#  (u'included', 505),
#  (u'claims', 504),
#  (u'performance', 504),
#  (u'pub', 504),
#  (u'drug', 501),
#  (u'arms', 500),
#  (u'higher', 499),
#  (u'design', 498),
#  (u'existence', 497),
#  (u'drives', 496),
#  (u'related', 496),
#  (u'sent', 496),
#  (u'ways', 495),
#  (u'currently', 494),
#  (u'ideas', 494),
#  (u'morality', 493),
#  (u'ofthe', 493),
#  (u'tv', 493),
#  (u'clearly', 491),
#  (u'blue', 490),
#  (u'sounds', 490),
#  (u'willing', 490),
#  (u'choice', 489),
#  (u'takes', 489),
#  (u'half', 488),
#  (u'mentioned', 488),
#  (u'serious', 488),
#  (u'la', 487),
#  (u'interest', 486),
#  (u'useful', 486),
#  (u'belief', 483),
#  (u'otherwise', 482),
#  (u'population', 482),
#  (u'smith', 481),
#  (u'nature', 480),
#  (u'weeks', 479),
#  (u'complete', 478),
#  (u'defense', 478),
#  (u'gives', 478),
#  (u'none', 477),
#  (u'basis', 476),
#  (u'field', 476),
#  (u'term', 476),
#  (u'court', 474),
#  (u'reply', 473),
#  (u'appears', 472),
#  (u'tape', 472),
#  (u'die', 471),
#  (u'main', 471),
#  (u'apr', 470),
#  (u'usenet', 470),
#  (u'andrew', 469),
#  (u'bought', 469),
#  (u'child', 468),
#  (u'created', 468),
#  (u'basic', 466),
#  (u'directory', 466),
#  (u'living', 466),
#  (u'mouse', 466),
#  (u'ram', 466),
#  (u'site', 466),
#  (u'average', 465),
#  (u'chance', 465),
#  (u'arab', 464),
#  (u'comments', 464),
#  (u'uunet', 464),
#  (u'applications', 463),
#  (u'command', 463),
#  (u'create', 463),
#  (u'international', 463),
#  (u'alt', 462),
#  (u'needed', 462),
#  (u'reasons', 461),
#  (u'family', 460),
#  (u'father', 460),
#  (u'media', 460),
#  (u'paper', 460),
#  (u'page', 459),
#  (u'thomas', 458),
#  (u'wish', 458),
#  (u'completely', 457),
#  (u'obviously', 457),
#  (u'rule', 457),
#  (u'indeed', 456),
#  (u'gave', 454),
#  (u'project', 454),
#  (u'shot', 454),
#  (u'supposed', 454),
#  (u'section', 452),
#  (u'king', 451),
#  (u'turkey', 451),
#  (u'cover', 450),
#  (u'finally', 450),
#  (u'institute', 449),
#  (u'manual', 449),
#  (u'base', 448),
#  (u'purpose', 448),
#  (u'rd', 448),
#  (u'scientific', 448),
#  (u'scott', 447),
#  (u'thank', 447),
#  (u'christianity', 446),
#  (u'pro', 446),
#  (u'engine', 445),
#  (u'looked', 445),
#  (u'figure', 444),
#  (u'inside', 444),
#  (u'learn', 444),
#  (u'tom', 444),
#  (u'amount', 443),
#  (u'folks', 443),
#  (u'turks', 443),
#  (u'normal', 442),
#  (u'suggest', 442),
#  (u'comp', 440),
#  (u'terms', 440),
#  (u'faster', 439),
#  (u'genocide', 439),
#  (u'issues', 439),
#  (u'russian', 439),
#  (u'sex', 439),
#  (u'anonymous', 438),
#  (u'entire', 438),
#  (u'miles', 438),
#  (u'neither', 438),
#  (u'son', 438),
#  (u'drugs', 437),
#  (u'eric', 437),
#  (u'lead', 437),
#  (u'plan', 436),
#  (u'required', 436),
#  (u'wonder', 436),
#  (u'food', 435),
#  (u'division', 434),
#  (u'individual', 434),
#  (u'east', 433),
#  (u'mass', 433),
#  (u'record', 433),
#  (u'rules', 433),
#  (u'condition', 432),
#  (u'meaning', 432),
#  (u'motif', 432),
#  (u'newsgroup', 432),
#  (u'class', 431),
#  (u'goal', 431),
#  (u'wait', 431),
#  (u'directly', 430),
#  (u'language', 430),
#  (u'united states', 430),
#  (u'door', 429),
#  (u'cards', 428),
#  (u'ide', 428),
#  (u'oil', 428),
#  (u'reasonable', 428),
#  (u'unfortunately', 428),
#  (u'event', 425),
#  (u'muslims', 424),
#  (u'whose', 424),
#  (u'america', 423),
#  (u'extra', 423),
#  (u'lives', 421),
#  (u'serial', 421),
#  (u'stated', 421),
#  (u'lots', 420),
#  (u'tm', 420),
#  (u'george', 419),
#  (u'universe', 419),
#  (u'congress', 418),
#  (u'device', 418),
#  (u'prove', 418),
#  (u'actions', 417),
#  (u'attack', 417),
#  (u'engineering', 417),
#  (u'room', 417),
#  (u'break', 416),
#  (u'years ago', 416),
#  (u'author', 414),
#  (u'development', 413),
#  (u'easily', 413),
#  (u'green', 413),
#  (u'modem', 413),
#  (u'details', 412),
#  (u'joe', 412),
#  (u'tax', 412),
#  (u'object', 411),
#  (u'pick', 411),
#  (u'administration', 410),
#  (u'places', 410),
#  (u'changed', 407),
#  (u'illegal', 407),
#  (u'organization', 407),
#  (u'reality', 407),
#  (u'dos dos', 406),
#  (u'dx', 406),
#  (u'xx', 406),
#  (u'launch', 405),
#  (u'happy', 404),
#  (u'hours', 404),
#  (u'nd', 404),
#  (u'wondering', 404),
#  (u'ac uk', 403),
#  (u'bits', 403),
#  (u'carry', 403),
#  (u'community', 403),
#  (u'des', 403),
#  (u'fan', 402),
#  (u'designed', 401),
#  (u'market', 401),
#  (u'member', 400),
#  (u'stand', 400),
#  (u'thanks advance', 400),
#  (u'btw', 399),
#  (u'devices', 399),
#  (u'floppy', 399),
#  (u'ie', 399),
#  (u'mit edu', 399),
#  (u'ray', 399),
#  (u'microsoft', 398),
#  (u'muslim', 398),
#  (u'port', 397),
#  (u'something like', 397),
#  (u'bbs', 396),
#  (u'cx', 396),
#  (u'happens', 396),
#  (u'allowed', 395),
#  (u'mention', 395),
#  (u'alone', 394),
#  (u'interface', 394),
#  (u'cable', 393),
#  (u'decided', 393),
#  (u'events', 393),
#  (u'forget', 393),
#  (u'difficult', 392),
#  (u'last year', 392),
#  (u'product', 391),
#  (u'release', 391),
#  (u'atheism', 390),
#  (u'definition', 390),
#  (u'five', 390),
#  (u'month', 390),
#  (u'physical', 390),
#  (u'responsible', 390),
#  (u'commercial', 389),
#  (u'facts', 389),
#  (u'murder', 389),
#  (u'suppose', 389),
#  (u'algorithm', 388),
#  (u'companies', 388),
#  (u'method', 388),
#  (u'wife', 388),
#  (u'army', 387),
#  (u'digital', 386),
#  (u'mother', 386),
#  (u'solution', 386),
#  (u'context', 385),
#  (u'decision', 385),
#  (u'installed', 385),
#  (u'knew', 385),
#  (u'late', 385),
#  (u'services', 385),
#  (u'watch', 385),
#  (u'worked', 385),
#  (u'americans', 384),
#  (u'richard', 384),
#  (u'sci', 384),
#  (u'trouble', 384),
#  (u'dos dos dos', 383),
#  ...]

# %%
print "Training the random forest..."
from sklearn.ensemble import RandomForestClassifier

# Initialize a Random Forest classifier with 100 trees
forest = RandomForestClassifier(n_estimators = 100) 

# Fit the forest to the training set, using the bag of words as 
# features and the sentiment labels as the response variable
#
# This may take a few minutes to run
forest = forest.fit( train_data_features, df_train["class"] )
print 'Training complete'
# Out:
# Training the random forest...
# Training complete

# %%
# Get a bag of words for the test set, and convert to a numpy array
test_data_features = vectorizer.transform(clean_paths_test)
test_data_features = test_data_features.toarray()

# Use the random forest to make sentiment label predictions
result = forest.predict(test_data_features)

# %%
accuracy_score(df_test['class'], result)
# Out:
# 0.74518629657414348

# %%
cohen_kappa_score(df_test['class'], result)
# Out:
# 0.73173542577604689

# %%
jaccard_similarity_score(df_test['class'], result)
# Out:
# 0.74518629657414348

# %%
def plot_confusion_matrix(classes, cm, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j], horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

cmatrix = confusion_matrix(df_test['class'], result)
plt.figure(figsize=(20,10))
plot_confusion_matrix(df_train['class'].unique(),cmatrix)
plt.show()
