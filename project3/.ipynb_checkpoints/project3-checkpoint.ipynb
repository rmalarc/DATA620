# %% [markdown]
# # DATA 620, Project 3
#
# ### Groups and Members
#
# ####Team 1: *Mauricio Alarcon, Sekhar Mekala, Aadi Kalloo, Srinivasa Illapani, Param Singh*
# ####Team 2: *Christophe Hunt, Joel Park, Ilya Kats, Pavan Akula, Nathan (Seoungyoon) Lim*
# ####Team 3: *Blandon Casenave, Kelly Shaffer, Michael Muller, Xiomeng (Vivian) Kong, Raphael Nash *
#
# ### Project Requirements
#
# **This is a Team Project!  For this project, please work with the entire class as one collaborative group!  Your project should be submitted (as an IPython Notebook via GitHub) by end of day on Monday, July 10th.  The group should present their code and findings in our meet-up on Tuesday July 11th.**
#
#
# Using any of the three classifiers described in chapter 6 of Natural Language Processing with Python, and any features you can think of, build the best name gender classifier you can. Begin by splitting the Names Corpus into three subsets: 500 words for the test set, 500 words for the dev-test set, and the remaining 6900 words for the training set. Then, starting with the example name gender classifier, make incremental improvements. Use the dev-test set to check your progress. Once you are satisfied with your classifier, check its final performance on the test set. How does the performance on the test set compare to the performance on the dev-test set? Is this what you'd expect?

# %%
from nltk.corpus import names as names_ntlk
import nltk
import pandas as pd
import matplotlib
import statistics
import scipy


nltk.download("names")
# Out:
# [nltk_data] Downloading package names to /Users/andrew/nltk_data...
# [nltk_data]   Package names is already up-to-date!
# True

# %%
# %matplotlib inline

# %%
matplotlib.style.use('ggplot')

# %% [markdown]
# ## Data Loading

# %%
import random
names = ([( name, 'male') for name in names_ntlk.words('male.txt')] + [( name, 'female') for name in names_ntlk.words('female.txt')]) 
random.seed(1234)
random.shuffle(names)
print names[:10]
# Out:
# [(u'Garwin', 'male'), (u'Cindie', 'female'), (u'Juanita', 'male'), (u'Dael', 'female'), (u'Jillayne', 'female'), (u'Sean', 'male'), (u'Nell', 'female'), (u'Christie', 'male'), (u'Shannen', 'female'), (u'Jessamine', 'female')]

# %%
len(names)
# Out:
# 7944

# %%
test_dataset = names[:500]
print "test_dataset: ", len(test_dataset)
devtest_dataset = names[500:1000]
print "devtest_dataset: ", len(devtest_dataset)
train_dataset = names[1000:]
print "train_dataset: ", len(train_dataset)
# Out:
# test_dataset:  500
# devtest_dataset:  500
# train_dataset:  6944

# %% [markdown]
# ## Model Building: Naive Bayes
#
# ### Baseline Model

# %% [markdown]
# Let's calculate the accuracy for the initial model as described in the book

# %%
# Book's classifier - baseline
def gender_features( word):
    w = word.lower()
    return {'last_letter': w[-1]} 

test_featureset = [(gender_features(n),g) for (n,g) in test_dataset]
devtest_featureset = [(gender_features(n),g) for (n,g) in devtest_dataset]
train_featureset = [(gender_features(n),g) for (n,g) in train_dataset]

classifier = nltk.NaiveBayesClassifier.train( train_featureset)

print ('Accuracy: %4.2f' %nltk.classify.accuracy( classifier, devtest_featureset))
# Out:
# Accuracy: 0.75

# %%
#errors = []
#for (name, tag) in devtest_dataset:
#     guess = classifier.classify(gender_features(name))
#     if guess != tag:
#         errors.append( (tag, guess, name) )

# %%
#for (tag, guess, name) in sorted(errors):
 #    print('correct={:<8} guess={:<8s} name={:<30}'.format(tag, guess, name))

# %% [markdown]
# Let's now add some features to it such as:
#
# * Entropy
# * First Trigram
# * Last Trigram
#
# by adding a feature at a time and see what happens
#
# ### Baseline + Last Trigram

# %%
#from nltk.classify import apply_features
def gender_features( word):
    w = word.lower()
    return {'last_letter': w[-1],'last_trigram': w[-3:]} #,'last_bigram': word[-2:]

test_featureset = [(gender_features(n),g) for (n,g) in test_dataset]
devtest_featureset = [(gender_features(n),g) for (n,g) in devtest_dataset]
train_featureset = [(gender_features(n),g) for (n,g) in train_dataset]
print test_featureset[1]
classifier = nltk.NaiveBayesClassifier.train( train_featureset)

print 'Accuracy: %4.2f' %nltk.classify.accuracy( classifier, devtest_featureset)
# Out:
# ({'last_letter': u'e', 'last_trigram': u'die'}, 'female')
# Accuracy: 0.77

# %% [markdown]
# ### Baseline + Last Trigram + First Trigram

# %%
#from nltk.classify import apply_features
def gender_features( word):
    w = word.lower()
    return {'last_letter': w[-1],'last_trigram': w[-3:], 'first_trigram': w[:3]} #,'last_bigram': word[-2:]

test_featureset = [(gender_features(n),g) for (n,g) in test_dataset]
devtest_featureset = [(gender_features(n),g) for (n,g) in devtest_dataset]
train_featureset = [(gender_features(n),g) for (n,g) in train_dataset]
print test_featureset[1]
classifier = nltk.NaiveBayesClassifier.train( train_featureset)

print 'Accuracy: %4.2f' %nltk.classify.accuracy( classifier, devtest_featureset)
# Out:
# ({'first_trigram': u'cin', 'last_letter': u'e', 'last_trigram': u'die'}, 'female')
# Accuracy: 0.81

# %% [markdown]
# ### Baseline + Last Trigram + First Trigram + First Four-gram

# %%
#from nltk.classify import apply_features
def gender_features( word):
    w = word.lower()
    return {'last_letter': w[-1],'last_trigram': w[-3:],'first_trigram': w[:3], 'first_fourgram': w[:4]} #,'last_bigram': word[-2:]

test_featureset = [(gender_features(n),g) for (n,g) in test_dataset]
devtest_featureset = [(gender_features(n),g) for (n,g) in devtest_dataset]
train_featureset = [(gender_features(n),g) for (n,g) in train_dataset]
print test_featureset[1]
classifier = nltk.NaiveBayesClassifier.train( train_featureset)

print 'Accuracy: %4.2f' %nltk.classify.accuracy( classifier, devtest_featureset)
# Out:
# ({'first_trigram': u'cin', 'last_letter': u'e', 'first_fourgram': u'cind', 'last_trigram': u'die'}, 'female')
# Accuracy: 0.85

# %% [markdown]
# ### Baseline + Last Trigram + First Trigram + Entropy

# %% [markdown]
# PS - not sure that we need to include Entropy at all in this.
#
# Per the text and section on the NLTK site entropy measures how disorganized the input variables are. This can however be used as an alternative method for identifying the most informative features by creating stumps for each branch of the decision tree and comparing the organization levels before and after via the entropy method. For this project, likely not needed as we will utilize the show_most_informative_features() NLTK method.

# %%
#from nltk.classify import apply_features
#textbook method
import math 
def entropy( labels): 
    freqdist = nltk.FreqDist( labels) 
    probs = [freqdist.freq( l) for l in nltk.FreqDist( labels)] 
    return -sum([ p * math.log( p, 2) for p in probs])

    
def gender_features( word):
    w = word.lower()
    return {'last_letter': w[-1],'last_trigram': w[-3:],'first_trigram': w[:3], 'first_four-gram': w[:4], 'entropy': entropy(list(w))} #,'last_bigram': word[-2:]

test_featureset = [(gender_features(n),g) for (n,g) in test_dataset]
devtest_featureset = [(gender_features(n),g) for (n,g) in devtest_dataset]
train_featureset = [(gender_features(n),g) for (n,g) in train_dataset]
print test_featureset[1]
classifier = nltk.NaiveBayesClassifier.train( train_featureset)

print 'Accuracy: %4.2f' %nltk.classify.accuracy( classifier, devtest_featureset)
# Out:
# ({'first_trigram': u'cin', 'first_four-gram': u'cind', 'last_letter': u'e', 'entropy': 2.2516291673878226, 'last_trigram': u'die'}, 'female')
# Accuracy: 0.84

# %% [markdown]
# ### Looking at Entropy and Model Performance

# %%
#sample entropy from text
print entropy(['male','male','male','male'])
print entropy(['male','female','male','male'])
print entropy(['female','male','female','male'])
print entropy(['female','female','male','female'])
print entropy(['female','female','female','female'])
# Out:
# -0.0
# 0.811278124459
# 1.0
# 0.811278124459
# -0.0

# %% [markdown]
# Entropy for input labels

# %%
entropy_input = [item[1] for item in names]
#entropy_input[:10] -- sanity check for input

print entropy(entropy_input)
# Out:
# 0.951030970455

# %% [markdown]
# Entropy is close to to 1 and is considered high. This means that there is a wide variety of labels and they are at a "medium" frequency - P(l) and log2P(l) are not small. Attempting to run entropy against a single decision stump (only one level) based on the first classifier with the text's gender features

# %%
classifier.classify( gender_features('Mauricio'))
# Out:
# 'male'

# %%
preds = pd.DataFrame({'observed':[gender for (f,gender) in devtest_dataset],'predicted': [classifier.classify(gender_features(n)) for (n,g) in devtest_dataset]})
pd.crosstab(preds.observed,preds.predicted)
# Out:
# predicted  female  male
# observed
# female        273    50
# male           39   138

# %%
#print 'Precision: %4.2f' %nltk.classify.precision( classifier, devtest_featureset)
cm = nltk.ConfusionMatrix([gender for (f,gender) in devtest_featureset], [classifier.classify(gender_features(n)) for (n,g) in devtest_dataset])
#[(gender_features(n),g) for (n,g) in devtest_dataset]

# %%
cm
# Out:
# <ConfusionMatrix: 411/500 correct>

# %%
classifier.show_most_informative_features()
# Out:
# Most Informative Features
#              last_letter = u'a'           female : male   =     42.4 : 1.0
#             last_trigram = u'nne'         female : male   =     31.1 : 1.0
#              last_letter = u'k'             male : female =     29.8 : 1.0
#             last_trigram = u'ita'         female : male   =     24.2 : 1.0
#             last_trigram = u'ana'         female : male   =     23.4 : 1.0
#             last_trigram = u'tta'         female : male   =     22.5 : 1.0
#             last_trigram = u'ard'           male : female =     20.2 : 1.0
#             last_trigram = u'vin'           male : female =     18.2 : 1.0
#             last_trigram = u'old'           male : female =     15.0 : 1.0
#              last_letter = u'f'             male : female =     14.6 : 1.0

# %%
classifier.most_informative_features()
# Out:
# [('last_letter', u'a'),
#  ('last_trigram', u'nne'),
#  ('last_letter', u'k'),
#  ('last_trigram', u'ita'),
#  ('last_trigram', u'ana'),
#  ('last_trigram', u'tta'),
#  ('last_trigram', u'ard'),
#  ('last_trigram', u'vin'),
#  ('last_trigram', u'old'),
#  ('last_letter', u'f'),
#  ('first_trigram', u'gar'),
#  ('first_trigram', u'tha'),
#  ('last_trigram', u'ria'),
#  ('last_trigram', u'dra'),
#  ('first_trigram', u'cat'),
#  ('last_trigram', u'ter'),
#  ('last_trigram', u'ert'),
#  ('last_trigram', u'son'),
#  ('last_letter', u'v'),
#  ('last_letter', u'm'),
#  ('last_letter', u'p'),
#  ('last_trigram', u'nni'),
#  ('last_letter', u'd'),
#  ('first_trigram', u'dor'),
#  ('first_trigram', u'wal'),
#  ('first_trigram', u'ros'),
#  ('last_trigram', u'cia'),
#  ('first_trigram', u'par'),
#  ('last_trigram', u'ler'),
#  ('last_trigram', u'van'),
#  ('last_trigram', u'ias'),
#  ('last_trigram', u'dor'),
#  ('last_trigram', u'den'),
#  ('first_fourgram', u'flor'),
#  ('last_letter', u'o'),
#  ('last_trigram', u'lli'),
#  ('last_trigram', u'isa'),
#  ('first_trigram', u'cli'),
#  ('last_trigram', u'ene'),
#  ('last_trigram', u'und'),
#  ('last_trigram', u'ven'),
#  ('last_trigram', u'bel'),
#  ('last_trigram', u'ssy'),
#  ('first_trigram', u'arl'),
#  ('first_fourgram', u'torr'),
#  ('last_letter', u'r'),
#  ('last_trigram', u'lle'),
#  ('last_trigram', u'iah'),
#  ('last_trigram', u'ine'),
#  ('last_trigram', u'and'),
#  ('first_trigram', u'god'),
#  ('first_trigram', u'bur'),
#  ('first_trigram', u'mik'),
#  ('first_trigram', u'nev'),
#  ('first_trigram', u'dom'),
#  ('last_trigram', u'nan'),
#  ('last_trigram', u'uel'),
#  ('first_trigram', u'mal'),
#  ('first_trigram', u'ama'),
#  ('first_trigram', u'mel'),
#  ('first_fourgram', u'dani'),
#  ('last_trigram', u'ree'),
#  ('first_trigram', u'lor'),
#  ('first_trigram', u'flo'),
#  ('first_trigram', u'lyn'),
#  ('first_trigram', u'bro'),
#  ('last_letter', u'g'),
#  ('last_trigram', u'cie'),
#  ('last_trigram', u'sie'),
#  ('first_trigram', u'hel'),
#  ('first_trigram', u'rod'),
#  ('first_trigram', u'nea'),
#  ('first_trigram', u'ser'),
#  ('first_trigram', u'gio'),
#  ('first_trigram', u'say'),
#  ('last_trigram', u'per'),
#  ('last_trigram', u'nus'),
#  ('last_trigram', u'las'),
#  ('last_trigram', u'lee'),
#  ('last_trigram', u'her'),
#  ('last_trigram', u'lyn'),
#  ('last_trigram', u'tha'),
#  ('first_trigram', u'jan'),
#  ('last_trigram', u'sta'),
#  ('last_trigram', u'ryn'),
#  ('first_fourgram', u'barb'),
#  ('first_fourgram', u'carm'),
#  ('first_trigram', u'alf'),
#  ('first_fourgram', u'chad'),
#  ('first_fourgram', u'saun'),
#  ('first_fourgram', u'darr'),
#  ('first_fourgram', u'neal'),
#  ('first_fourgram', u'ambr'),
#  ('last_trigram', u'ott'),
#  ('last_trigram', u'lan'),
#  ('last_trigram', u'han'),
#  ('last_trigram', u'ise'),
#  ('first_trigram', u'jen'),
#  ('first_fourgram', u'matt'),
#  ('first_trigram', u'tho')]

# %% [markdown]
# Not sure if this entropy business means anything, perhaps the entropy distribution for male/female names is different

# %%
e_male = filter(None,[gender_features(n)['entropy'] if (g=='male') else None for (n,g) in devtest_dataset])
print ("Male Mean: %4.2f" %statistics.mean(e_male))
print ("Male SD: %4.2f" %statistics.stdev(e_male))
pd.DataFrame(e_male).plot.hist()
# Out:
# Male Mean: 2.32
# Male SD: 0.35

# %%
e_female = filter(None,[gender_features(n)['entropy'] if (g=='female') else None for (n,g) in devtest_dataset])
print 'Female Mean: %4.2f' %statistics.mean(e_female)
print 'Female SD: %4.2f' %statistics.stdev(e_female)
pd.DataFrame(e_female).plot.hist()
# Out:
# Female Mean: 2.27
# Female SD: 0.37

# %%
scipy.stats.ttest_ind(e_male,e_female)
# Out:
# Ttest_indResult(statistic=1.4909191968274809, pvalue=0.13661582489681476)

# %% [markdown]
# Although there is no statistical difference in the distribution of entropy values, the histograms appear to have a different configuration.

# %% [markdown]
# ### Predictions
#
# Let's run some predicitons now:

# %%
preds = pd.DataFrame({'name':[f for (f,gender) in test_dataset],'observed':[gender for (f,gender) in test_dataset],'predicted': [classifier.classify(gender_features(n)) for (n,g) in test_dataset]})

# %%
pd.crosstab(preds.observed,preds.predicted)
# Out:
# predicted  female  male
# observed
# female        267    39
# male           37   157

# %%
import seaborn as sn
import matplotlib.pyplot as plt
import numpy as np
genderDf = pd.crosstab(preds.observed,preds.predicted)

genderDf = pd.DataFrame(genderDf)
genderArray = np.array([[genderDf.at['female','female'], genderDf.at['female','male']],
                   [genderDf.at['male','female'], genderDf.at['male','male']]])

genderCM = pd.DataFrame(genderArray, index = ['female','male'],
                  columns = ['female','male'])
plt.figure(figsize = (5,4))
ax = plt.axes()
sn.heatmap(genderCM, annot=True,cmap='YlGnBu', fmt='g', ax = ax)

ax.set_title('Actual Vs. Predicted')

# %% [markdown]
# # Testing With Real Data
#
# I tested how well the algorithm predicted Male Vs Female with the top 1000 baby names from the US Social Security Administration for each year since 1880

# %%
years = [] 
percents = [] 
from __future__ import division


for year in range(1880, 2017):
    url_base = "https://raw.githubusercontent.com/RaphaelNash/CUNY-DATA-620-WebAnalytics/master/Project3/names/yob"
    url = url_base + str(year) + ".txt"
    yob_df = pd.read_csv(url, header=None)
    yob_df["predicted_gender"] = yob_df[0].apply(lambda x:  classifier.classify(gender_features(x )))
    yob_df["predicted_gender"] = ['F' if x == 'female' else 'M' for x in yob_df['predicted_gender']]
    years.append(year)
    percents.append(len( yob_df [  yob_df['predicted_gender'] == yob_df[1]])/len(yob_df))
    
year_accuracy_df = pd.Series(percents, index = years)

ax = year_accuracy_df.plot(figsize=(20,10))

vals = ax.get_yticks()
ax.set_yticklabels(['{:3.0f}%'.format(x*100) for x in vals])
ax.get_xaxis().get_major_formatter().set_useOffset(False)

ax.set_title("Prediction Acuracy with SSA Data over time")
ax.set_xlabel('Year')
ax.set_ylabel('% Accurately Predicted')

# %% [markdown]
# ## Model Building: N-Gram Tagging with Decision Trees

# %%
just_names = ([(name) for name in names_ntlk.words('male.txt')] + [(name) for name in names_ntlk.words('female.txt')]) 
random.shuffle(just_names)

end_ngram_fdist = nltk.FreqDist()
for ngram in just_names:
    ngram = ngram.lower()
    end_ngram_fdist[ngram[-1:]] +=1
    end_ngram_fdist[ngram[-2:]] +=1
    end_ngram_fdist[ngram[-3:]] +=1
    end_ngram_fdist[ngram[-4:]] +=1

common_endings = [ending for (ending, count) in end_ngram_fdist.most_common(200)]

begin_ngram_fdist = nltk.FreqDist()
for ngram in just_names:
    ngram = ngram.lower()
    begin_ngram_fdist[ngram[:1]] +=1
    begin_ngram_fdist[ngram[:2]] +=1
    begin_ngram_fdist[ngram[:3]] +=1
    begin_ngram_fdist[ngram[:4]] +=1

common_beginnings = [begin for (begin, count) in begin_ngram_fdist.most_common(200)]

# %%
#Define feature extractor
def pos_features_both(word):
    features = {}
    for suffix in common_beginnings:
        features['startswith({})'.format(suffix)] = word.lower().startswith(suffix)
    for suffix in common_endings:
        features['endswith({})'.format(suffix)] = word.lower().endswith(suffix)
    return features

# %%
featuresets = [(pos_features_both(n), g) for (n,g) in names]
featuresets[:10]
# Out:
# [({'endswith(a)': False,
#    'endswith(ad)': False,
#    'endswith(ah)': False,
#    'endswith(aine)': False,
#    'endswith(al)': False,
#    'endswith(am)': False,
#    'endswith(an)': False,
#    'endswith(ana)': False,
#    'endswith(and)': False,
#    'endswith(ane)': False,
#    'endswith(ann)': False,
#    'endswith(anna)': False,
#    'endswith(anne)': False,
#    'endswith(ar)': False,
#    'endswith(ara)': False,
#    'endswith(ard)': False,
#    'endswith(as)': False,
#    'endswith(ay)': False,
#    'endswith(b)': False,
#    'endswith(bel)': False,
#    'endswith(bert)': False,
#    'endswith(bie)': False,
#    'endswith(by)': False,
#    'endswith(c)': False,
#    'endswith(ca)': False,
#    'endswith(ce)': False,
#    'endswith(ch)': False,
#    'endswith(cia)': False,
#    'endswith(ck)': False,
#    'endswith(cy)': False,
#    'endswith(d)': False,
#    'endswith(da)': False,
#    'endswith(de)': False,
#    'endswith(di)': False,
#    'endswith(die)': False,
#    'endswith(do)': False,
#    'endswith(dra)': False,
#    'endswith(dy)': False,
#    'endswith(e)': False,
#    'endswith(ea)': False,
#    'endswith(ed)': False,
#    'endswith(ee)': False,
#    'endswith(een)': False,
#    'endswith(el)': False,
#    'endswith(ela)': False,
#    'endswith(elia)': False,
#    'endswith(ell)': False,
#    'endswith(ella)': False,
#    'endswith(elle)': False,
#    'endswith(en)': False,
#    'endswith(ena)': False,
#    'endswith(ene)': False,
#    'endswith(er)': False,
#    'endswith(ert)': False,
#    'endswith(es)': False,
#    'endswith(et)': False,
#    'endswith(eta)': False,
#    'endswith(etta)': False,
#    'endswith(ette)': False,
#    'endswith(ey)': False,
#    'endswith(f)': False,
#    'endswith(g)': False,
#    'endswith(ge)': False,
#    'endswith(h)': False,
#    'endswith(ha)': False,
#    'endswith(he)': False,
#    'endswith(i)': False,
#    'endswith(ia)': False,
#    'endswith(ian)': False,
#    'endswith(iana)': False,
#    'endswith(ica)': False,
#    'endswith(ice)': False,
#    'endswith(ick)': False,
#    'endswith(ida)': False,
#    'endswith(ie)': False,
#    'endswith(il)': False,
#    'endswith(in)': True,
#    'endswith(ina)': False,
#    'endswith(ine)': False,
#    'endswith(io)': False,
#    'endswith(is)': False,
#    'endswith(isa)': False,
#    'endswith(ise)': False,
#    'endswith(issa)': False,
#    'endswith(it)': False,
#    'endswith(ita)': False,
#    'endswith(k)': False,
#    'endswith(ka)': False,
#    'endswith(ke)': False,
#    'endswith(ki)': False,
#    'endswith(ky)': False,
#    'endswith(l)': False,
#    'endswith(la)': False,
#    'endswith(ld)': False,
#    'endswith(le)': False,
#    'endswith(lee)': False,
#    'endswith(leen)': False,
#    'endswith(len)': False,
#    'endswith(lene)': False,
#    'endswith(ley)': False,
#    'endswith(li)': False,
#    'endswith(lia)': False,
#    'endswith(lie)': False,
#    'endswith(lin)': False,
#    'endswith(lina)': False,
#    'endswith(line)': False,
#    'endswith(ll)': False,
#    'endswith(lla)': False,
#    'endswith(lle)': False,
#    'endswith(lli)': False,
#    'endswith(llie)': False,
#    'endswith(lly)': False,
#    'endswith(lo)': False,
#    'endswith(ly)': False,
#    'endswith(lyn)': False,
#    'endswith(m)': False,
#    'endswith(ma)': False,
#    'endswith(mie)': False,
#    'endswith(my)': False,
#    'endswith(n)': True,
#    'endswith(na)': False,
#    'endswith(nce)': False,
#    'endswith(nd)': False,
#    'endswith(nda)': False,
#    'endswith(ndra)': False,
#    'endswith(ndy)': False,
#    'endswith(ne)': False,
#    'endswith(ney)': False,
#    'endswith(ni)': False,
#    'endswith(nia)': False,
#    'endswith(nie)': False,
#    'endswith(nn)': False,
#    'endswith(nna)': False,
#    'endswith(nne)': False,
#    'endswith(nni)': False,
#    'endswith(nnie)': False,
#    'endswith(nny)': False,
#    'endswith(nt)': False,
#    'endswith(ny)': False,
#    'endswith(o)': False,
#    'endswith(on)': False,
#    'endswith(ona)': False,
#    'endswith(or)': False,
#    'endswith(ora)': False,
#    'endswith(ore)': False,
#    'endswith(p)': False,
#    'endswith(r)': False,
#    'endswith(ra)': False,
#    'endswith(rd)': False,
#    'endswith(re)': False,
#    'endswith(rey)': False,
#    'endswith(ri)': False,
#    'endswith(ria)': False,
#    'endswith(rick)': False,
#    'endswith(rie)': False,
#    'endswith(rina)': False,
#    'endswith(rine)': False,
#    'endswith(ris)': False,
#    'endswith(rrie)': False,
#    'endswith(rry)': False,
#    'endswith(rt)': False,
#    'endswith(ry)': False,
#    'endswith(s)': False,
#    'endswith(sa)': False,
#    'endswith(se)': False,
#    'endswith(sey)': False,
#    'endswith(sha)': False,
#    'endswith(si)': False,
#    'endswith(sie)': False,
#    'endswith(son)': False,
#    'endswith(ssa)': False,
#    'endswith(ssie)': False,
#    'endswith(sy)': False,
#    'endswith(t)': False,
#    'endswith(ta)': False,
#    'endswith(te)': False,
#    'endswith(ter)': False,
#    'endswith(th)': False,
#    'endswith(tha)': False,
#    'endswith(ti)': False,
#    'endswith(tie)': False,
#    'endswith(tin)': False,
#    'endswith(tina)': False,
#    'endswith(tine)': False,
#    'endswith(ton)': False,
#    'endswith(tt)': False,
#    'endswith(tta)': False,
#    'endswith(tte)': False,
#    'endswith(ty)': False,
#    'endswith(us)': False,
#    'endswith(va)': False,
#    'endswith(vin)': False,
#    'endswith(w)': False,
#    'endswith(y)': False,
#    'endswith(ya)': False,
#    'endswith(ye)': False,
#    'endswith(yl)': False,
#    'endswith(yn)': False,
#    'endswith(yne)': False,
#    'endswith(ynn)': False,
#    'startswith(a)': False,
#    'startswith(ab)': False,
#    'startswith(ad)': False,
#    'startswith(al)': False,
#    'startswith(ale)': False,
#    'startswith(ali)': False,
#    'startswith(all)': False,
#    'startswith(am)': False,
#    'startswith(an)': False,
#    'startswith(and)': False,
#    'startswith(ann)': False,
#    'startswith(ar)': False,
#    'startswith(au)': False,
#    'startswith(b)': False,
#    'startswith(ba)': False,
#    'startswith(bar)': False,
#    'startswith(be)': False,
#    'startswith(ben)': False,
#    'startswith(ber)': False,
#    'startswith(bl)': False,
#    'startswith(bo)': False,
#    'startswith(br)': False,
#    'startswith(bri)': False,
#    'startswith(c)': False,
#    'startswith(ca)': False,
#    'startswith(car)': False,
#    'startswith(carl)': False,
#    'startswith(cat)': False,
#    'startswith(ce)': False,
#    'startswith(ch)': False,
#    'startswith(cha)': False,
#    'startswith(char)': False,
#    'startswith(che)': False,
#    'startswith(chr)': False,
#    'startswith(chri)': False,
#    'startswith(cl)': False,
#    'startswith(cla)': False,
#    'startswith(clar)': False,
#    'startswith(co)': False,
#    'startswith(con)': False,
#    'startswith(cor)': False,
#    'startswith(d)': False,
#    'startswith(da)': False,
#    'startswith(dan)': False,
#    'startswith(dar)': False,
#    'startswith(de)': False,
#    'startswith(del)': False,
#    'startswith(di)': False,
#    'startswith(do)': False,
#    'startswith(dor)': False,
#    'startswith(du)': False,
#    'startswith(e)': False,
#    'startswith(ed)': False,
#    'startswith(el)': False,
#    'startswith(eli)': False,
#    'startswith(em)': False,
#    'startswith(er)': False,
#    'startswith(ev)': False,
#    'startswith(f)': False,
#    'startswith(fa)': False,
#    'startswith(fe)': False,
#    'startswith(fi)': False,
#    'startswith(fl)': False,
#    'startswith(flo)': False,
#    'startswith(flor)': False,
#    'startswith(fr)': False,
#    'startswith(fra)': False,
#    'startswith(fran)': False,
#    'startswith(fre)': False,
#    'startswith(g)': True,
#    'startswith(ga)': True,
#    'startswith(gar)': True,
#    'startswith(ge)': False,
#    'startswith(geo)': False,
#    'startswith(ger)': False,
#    'startswith(gi)': False,
#    'startswith(gl)': False,
#    'startswith(go)': False,
#    'startswith(gr)': False,
#    'startswith(gu)': False,
#    'startswith(h)': False,
#    'startswith(ha)': False,
#    'startswith(har)': False,
#    'startswith(he)': False,
#    'startswith(her)': False,
#    'startswith(hi)': False,
#    'startswith(ho)': False,
#    'startswith(i)': False,
#    'startswith(in)': False,
#    'startswith(is)': False,
#    'startswith(j)': False,
#    'startswith(ja)': False,
#    'startswith(jac)': False,
#    'startswith(jan)': False,
#    'startswith(je)': False,
#    'startswith(jen)': False,
#    'startswith(jer)': False,
#    'startswith(jo)': False,
#    'startswith(ju)': False,
#    'startswith(jul)': False,
#    'startswith(k)': False,
#    'startswith(ka)': False,
#    'startswith(kar)': False,
#    'startswith(kat)': False,
#    'startswith(ke)': False,
#    'startswith(ki)': False,
#    'startswith(kr)': False,
#    'startswith(l)': False,
#    'startswith(la)': False,
#    'startswith(lau)': False,
#    'startswith(laur)': False,
#    'startswith(le)': False,
#    'startswith(leo)': False,
#    'startswith(li)': False,
#    'startswith(lin)': False,
#    'startswith(lo)': False,
#    'startswith(lor)': False,
#    'startswith(lu)': False,
#    'startswith(luc)': False,
#    'startswith(ly)': False,
#    'startswith(lyn)': False,
#    'startswith(m)': False,
#    'startswith(ma)': False,
#    'startswith(mad)': False,
#    'startswith(mar)': False,
#    'startswith(marc)': False,
#    'startswith(marg)': False,
#    'startswith(mari)': False,
#    'startswith(mat)': False,
#    'startswith(me)': False,
#    'startswith(mel)': False,
#    'startswith(mer)': False,
#    'startswith(mi)': False,
#    'startswith(mic)': False,
#    'startswith(mo)': False,
#    'startswith(mor)': False,
#    'startswith(n)': False,
#    'startswith(na)': False,
#    'startswith(nat)': False,
#    'startswith(ne)': False,
#    'startswith(ni)': False,
#    'startswith(nic)': False,
#    'startswith(no)': False,
#    'startswith(o)': False,
#    'startswith(ol)': False,
#    'startswith(or)': False,
#    'startswith(p)': False,
#    'startswith(pa)': False,
#    'startswith(pat)': False,
#    'startswith(pe)': False,
#    'startswith(ph)': False,
#    'startswith(q)': False,
#    'startswith(qu)': False,
#    'startswith(r)': False,
#    'startswith(ra)': False,
#    'startswith(ran)': False,
#    'startswith(re)': False,
#    'startswith(ri)': False,
#    'startswith(ric)': False,
#    'startswith(ro)': False,
#    'startswith(rob)': False,
#    'startswith(ros)': False,
#    'startswith(ru)': False,
#    'startswith(s)': False,
#    'startswith(sa)': False,
#    'startswith(se)': False,
#    'startswith(sh)': False,
#    'startswith(sha)': False,
#    'startswith(she)': False,
#    'startswith(si)': False,
#    'startswith(so)': False,
#    'startswith(st)': False,
#    'startswith(sta)': False,
#    'startswith(ste)': False,
#    'startswith(su)': False,
#    'startswith(t)': False,
#    'startswith(ta)': False,
#    'startswith(te)': False,
#    'startswith(ter)': False,
#    'startswith(th)': False,
#    'startswith(the)': False,
#    'startswith(ti)': False,
#    'startswith(to)': False,
#    'startswith(tr)': False,
#    'startswith(u)': False,
#    'startswith(v)': False,
#    'startswith(va)': False,
#    'startswith(val)': False,
#    'startswith(ve)': False,
#    'startswith(ver)': False,
#    'startswith(vi)': False,
#    'startswith(w)': False,
#    'startswith(wa)': False,
#    'startswith(we)': False,
#    'startswith(wi)': False,
#    'startswith(wil)': False,
#    'startswith(win)': False,
#    'startswith(y)': False,
#    'startswith(z)': False,
#    'startswith(za)': False},
#   'male'),
#  ({'endswith(a)': False,
#    'endswith(ad)': False,
#    'endswith(ah)': False,
#    'endswith(aine)': False,
#    'endswith(al)': False,
#    'endswith(am)': False,
#    'endswith(an)': False,
#    'endswith(ana)': False,
#    'endswith(and)': False,
#    'endswith(ane)': False,
#    'endswith(ann)': False,
#    'endswith(anna)': False,
#    'endswith(anne)': False,
#    'endswith(ar)': False,
#    'endswith(ara)': False,
#    'endswith(ard)': False,
#    'endswith(as)': False,
#    'endswith(ay)': False,
#    'endswith(b)': False,
#    'endswith(bel)': False,
#    'endswith(bert)': False,
#    'endswith(bie)': False,
#    'endswith(by)': False,
#    'endswith(c)': False,
#    'endswith(ca)': False,
#    'endswith(ce)': False,
#    'endswith(ch)': False,
#    'endswith(cia)': False,
#    'endswith(ck)': False,
#    'endswith(cy)': False,
#    'endswith(d)': False,
#    'endswith(da)': False,
#    'endswith(de)': False,
#    'endswith(di)': False,
#    'endswith(die)': True,
#    'endswith(do)': False,
#    'endswith(dra)': False,
#    'endswith(dy)': False,
#    'endswith(e)': True,
#    'endswith(ea)': False,
#    'endswith(ed)': False,
#    'endswith(ee)': False,
#    'endswith(een)': False,
#    'endswith(el)': False,
#    'endswith(ela)': False,
#    'endswith(elia)': False,
#    'endswith(ell)': False,
#    'endswith(ella)': False,
#    'endswith(elle)': False,
#    'endswith(en)': False,
#    'endswith(ena)': False,
#    'endswith(ene)': False,
#    'endswith(er)': False,
#    'endswith(ert)': False,
#    'endswith(es)': False,
#    'endswith(et)': False,
#    'endswith(eta)': False,
#    'endswith(etta)': False,
#    'endswith(ette)': False,
#    'endswith(ey)': False,
#    'endswith(f)': False,
#    'endswith(g)': False,
#    'endswith(ge)': False,
#    'endswith(h)': False,
#    'endswith(ha)': False,
#    'endswith(he)': False,
#    'endswith(i)': False,
#    'endswith(ia)': False,
#    'endswith(ian)': False,
#    'endswith(iana)': False,
#    'endswith(ica)': False,
#    'endswith(ice)': False,
#    'endswith(ick)': False,
#    'endswith(ida)': False,
#    'endswith(ie)': True,
#    'endswith(il)': False,
#    'endswith(in)': False,
#    'endswith(ina)': False,
#    'endswith(ine)': False,
#    'endswith(io)': False,
#    'endswith(is)': False,
#    'endswith(isa)': False,
#    'endswith(ise)': False,
#    'endswith(issa)': False,
#    'endswith(it)': False,
#    'endswith(ita)': False,
#    'endswith(k)': False,
#    'endswith(ka)': False,
#    'endswith(ke)': False,
#    'endswith(ki)': False,
#    'endswith(ky)': False,
#    'endswith(l)': False,
#    'endswith(la)': False,
#    'endswith(ld)': False,
#    'endswith(le)': False,
#    'endswith(lee)': False,
#    'endswith(leen)': False,
#    'endswith(len)': False,
#    'endswith(lene)': False,
#    'endswith(ley)': False,
#    'endswith(li)': False,
#    'endswith(lia)': False,
#    'endswith(lie)': False,
#    'endswith(lin)': False,
#    'endswith(lina)': False,
#    'endswith(line)': False,
#    'endswith(ll)': False,
#    'endswith(lla)': False,
#    'endswith(lle)': False,
#    'endswith(lli)': False,
#    'endswith(llie)': False,
#    'endswith(lly)': False,
#    'endswith(lo)': False,
#    'endswith(ly)': False,
#    'endswith(lyn)': False,
#    'endswith(m)': False,
#    'endswith(ma)': False,
#    'endswith(mie)': False,
#    'endswith(my)': False,
#    'endswith(n)': False,
#    'endswith(na)': False,
#    'endswith(nce)': False,
#    'endswith(nd)': False,
#    'endswith(nda)': False,
#    'endswith(ndra)': False,
#    'endswith(ndy)': False,
#    'endswith(ne)': False,
#    'endswith(ney)': False,
#    'endswith(ni)': False,
#    'endswith(nia)': False,
#    'endswith(nie)': False,
#    'endswith(nn)': False,
#    'endswith(nna)': False,
#    'endswith(nne)': False,
#    'endswith(nni)': False,
#    'endswith(nnie)': False,
#    'endswith(nny)': False,
#    'endswith(nt)': False,
#    'endswith(ny)': False,
#    'endswith(o)': False,
#    'endswith(on)': False,
#    'endswith(ona)': False,
#    'endswith(or)': False,
#    'endswith(ora)': False,
#    'endswith(ore)': False,
#    'endswith(p)': False,
#    'endswith(r)': False,
#    'endswith(ra)': False,
#    'endswith(rd)': False,
#    'endswith(re)': False,
#    'endswith(rey)': False,
#    'endswith(ri)': False,
#    'endswith(ria)': False,
#    'endswith(rick)': False,
#    'endswith(rie)': False,
#    'endswith(rina)': False,
#    'endswith(rine)': False,
#    'endswith(ris)': False,
#    'endswith(rrie)': False,
#    'endswith(rry)': False,
#    'endswith(rt)': False,
#    'endswith(ry)': False,
#    'endswith(s)': False,
#    'endswith(sa)': False,
#    'endswith(se)': False,
#    'endswith(sey)': False,
#    'endswith(sha)': False,
#    'endswith(si)': False,
#    'endswith(sie)': False,
#    'endswith(son)': False,
#    'endswith(ssa)': False,
#    'endswith(ssie)': False,
#    'endswith(sy)': False,
#    'endswith(t)': False,
#    'endswith(ta)': False,
#    'endswith(te)': False,
#    'endswith(ter)': False,
#    'endswith(th)': False,
#    'endswith(tha)': False,
#    'endswith(ti)': False,
#    'endswith(tie)': False,
#    'endswith(tin)': False,
#    'endswith(tina)': False,
#    'endswith(tine)': False,
#    'endswith(ton)': False,
#    'endswith(tt)': False,
#    'endswith(tta)': False,
#    'endswith(tte)': False,
#    'endswith(ty)': False,
#    'endswith(us)': False,
#    'endswith(va)': False,
#    'endswith(vin)': False,
#    'endswith(w)': False,
#    'endswith(y)': False,
#    'endswith(ya)': False,
#    'endswith(ye)': False,
#    'endswith(yl)': False,
#    'endswith(yn)': False,
#    'endswith(yne)': False,
#    'endswith(ynn)': False,
#    'startswith(a)': False,
#    'startswith(ab)': False,
#    'startswith(ad)': False,
#    'startswith(al)': False,
#    'startswith(ale)': False,
#    'startswith(ali)': False,
#    'startswith(all)': False,
#    'startswith(am)': False,
#    'startswith(an)': False,
#    'startswith(and)': False,
#    'startswith(ann)': False,
#    'startswith(ar)': False,
#    'startswith(au)': False,
#    'startswith(b)': False,
#    'startswith(ba)': False,
#    'startswith(bar)': False,
#    'startswith(be)': False,
#    'startswith(ben)': False,
#    'startswith(ber)': False,
#    'startswith(bl)': False,
#    'startswith(bo)': False,
#    'startswith(br)': False,
#    'startswith(bri)': False,
#    'startswith(c)': True,
#    'startswith(ca)': False,
#    'startswith(car)': False,
#    'startswith(carl)': False,
#    'startswith(cat)': False,
#    'startswith(ce)': False,
#    'startswith(ch)': False,
#    'startswith(cha)': False,
#    'startswith(char)': False,
#    'startswith(che)': False,
#    'startswith(chr)': False,
#    'startswith(chri)': False,
#    'startswith(cl)': False,
#    'startswith(cla)': False,
#    'startswith(clar)': False,
#    'startswith(co)': False,
#    'startswith(con)': False,
#    'startswith(cor)': False,
#    'startswith(d)': False,
#    'startswith(da)': False,
#    'startswith(dan)': False,
#    'startswith(dar)': False,
#    'startswith(de)': False,
#    'startswith(del)': False,
#    'startswith(di)': False,
#    'startswith(do)': False,
#    'startswith(dor)': False,
#    'startswith(du)': False,
#    'startswith(e)': False,
#    'startswith(ed)': False,
#    'startswith(el)': False,
#    'startswith(eli)': False,
#    'startswith(em)': False,
#    'startswith(er)': False,
#    'startswith(ev)': False,
#    'startswith(f)': False,
#    'startswith(fa)': False,
#    'startswith(fe)': False,
#    'startswith(fi)': False,
#    'startswith(fl)': False,
#    'startswith(flo)': False,
#    'startswith(flor)': False,
#    'startswith(fr)': False,
#    'startswith(fra)': False,
#    'startswith(fran)': False,
#    'startswith(fre)': False,
#    'startswith(g)': False,
#    'startswith(ga)': False,
#    'startswith(gar)': False,
#    'startswith(ge)': False,
#    'startswith(geo)': False,
#    'startswith(ger)': False,
#    'startswith(gi)': False,
#    'startswith(gl)': False,
#    'startswith(go)': False,
#    'startswith(gr)': False,
#    'startswith(gu)': False,
#    'startswith(h)': False,
#    'startswith(ha)': False,
#    'startswith(har)': False,
#    'startswith(he)': False,
#    'startswith(her)': False,
#    'startswith(hi)': False,
#    'startswith(ho)': False,
#    'startswith(i)': False,
#    'startswith(in)': False,
#    'startswith(is)': False,
#    'startswith(j)': False,
#    'startswith(ja)': False,
#    'startswith(jac)': False,
#    'startswith(jan)': False,
#    'startswith(je)': False,
#    'startswith(jen)': False,
#    'startswith(jer)': False,
#    'startswith(jo)': False,
#    'startswith(ju)': False,
#    'startswith(jul)': False,
#    'startswith(k)': False,
#    'startswith(ka)': False,
#    'startswith(kar)': False,
#    'startswith(kat)': False,
#    'startswith(ke)': False,
#    'startswith(ki)': False,
#    'startswith(kr)': False,
#    'startswith(l)': False,
#    'startswith(la)': False,
#    'startswith(lau)': False,
#    'startswith(laur)': False,
#    'startswith(le)': False,
#    'startswith(leo)': False,
#    'startswith(li)': False,
#    'startswith(lin)': False,
#    'startswith(lo)': False,
#    'startswith(lor)': False,
#    'startswith(lu)': False,
#    'startswith(luc)': False,
#    'startswith(ly)': False,
#    'startswith(lyn)': False,
#    'startswith(m)': False,
#    'startswith(ma)': False,
#    'startswith(mad)': False,
#    'startswith(mar)': False,
#    'startswith(marc)': False,
#    'startswith(marg)': False,
#    'startswith(mari)': False,
#    'startswith(mat)': False,
#    'startswith(me)': False,
#    'startswith(mel)': False,
#    'startswith(mer)': False,
#    'startswith(mi)': False,
#    'startswith(mic)': False,
#    'startswith(mo)': False,
#    'startswith(mor)': False,
#    'startswith(n)': False,
#    'startswith(na)': False,
#    'startswith(nat)': False,
#    'startswith(ne)': False,
#    'startswith(ni)': False,
#    'startswith(nic)': False,
#    'startswith(no)': False,
#    'startswith(o)': False,
#    'startswith(ol)': False,
#    'startswith(or)': False,
#    'startswith(p)': False,
#    'startswith(pa)': False,
#    'startswith(pat)': False,
#    'startswith(pe)': False,
#    'startswith(ph)': False,
#    'startswith(q)': False,
#    'startswith(qu)': False,
#    'startswith(r)': False,
#    'startswith(ra)': False,
#    'startswith(ran)': False,
#    'startswith(re)': False,
#    'startswith(ri)': False,
#    'startswith(ric)': False,
#    'startswith(ro)': False,
#    'startswith(rob)': False,
#    'startswith(ros)': False,
#    'startswith(ru)': False,
#    'startswith(s)': False,
#    'startswith(sa)': False,
#    'startswith(se)': False,
#    'startswith(sh)': False,
#    'startswith(sha)': False,
#    'startswith(she)': False,
#    'startswith(si)': False,
#    'startswith(so)': False,
#    'startswith(st)': False,
#    'startswith(sta)': False,
#    'startswith(ste)': False,
#    'startswith(su)': False,
#    'startswith(t)': False,
#    'startswith(ta)': False,
#    'startswith(te)': False,
#    'startswith(ter)': False,
#    'startswith(th)': False,
#    'startswith(the)': False,
#    'startswith(ti)': False,
#    'startswith(to)': False,
#    'startswith(tr)': False,
#    'startswith(u)': False,
#    'startswith(v)': False,
#    'startswith(va)': False,
#    'startswith(val)': False,
#    'startswith(ve)': False,
#    'startswith(ver)': False,
#    'startswith(vi)': False,
#    'startswith(w)': False,
#    'startswith(wa)': False,
#    'startswith(we)': False,
#    'startswith(wi)': False,
#    'startswith(wil)': False,
#    'startswith(win)': False,
#    'startswith(y)': False,
#    'startswith(z)': False,
#    'startswith(za)': False},
#   'female'),
#  ({'endswith(a)': True,
#    'endswith(ad)': False,
#    'endswith(ah)': False,
#    'endswith(aine)': False,
#    'endswith(al)': False,
#    'endswith(am)': False,
#    'endswith(an)': False,
#    'endswith(ana)': False,
#    'endswith(and)': False,
#    'endswith(ane)': False,
#    'endswith(ann)': False,
#    'endswith(anna)': False,
#    'endswith(anne)': False,
#    'endswith(ar)': False,
#    'endswith(ara)': False,
#    'endswith(ard)': False,
#    'endswith(as)': False,
#    'endswith(ay)': False,
#    'endswith(b)': False,
#    'endswith(bel)': False,
#    'endswith(bert)': False,
#    'endswith(bie)': False,
#    'endswith(by)': False,
#    'endswith(c)': False,
#    'endswith(ca)': False,
#    'endswith(ce)': False,
#    'endswith(ch)': False,
#    'endswith(cia)': False,
#    'endswith(ck)': False,
#    'endswith(cy)': False,
#    'endswith(d)': False,
#    'endswith(da)': False,
#    'endswith(de)': False,
#    'endswith(di)': False,
#    'endswith(die)': False,
#    'endswith(do)': False,
#    'endswith(dra)': False,
#    'endswith(dy)': False,
#    'endswith(e)': False,
#    'endswith(ea)': False,
#    'endswith(ed)': False,
#    'endswith(ee)': False,
#    'endswith(een)': False,
#    'endswith(el)': False,
#    'endswith(ela)': False,
#    'endswith(elia)': False,
#    'endswith(ell)': False,
#    'endswith(ella)': False,
#    'endswith(elle)': False,
#    'endswith(en)': False,
#    'endswith(ena)': False,
#    'endswith(ene)': False,
#    'endswith(er)': False,
#    'endswith(ert)': False,
#    'endswith(es)': False,
#    'endswith(et)': False,
#    'endswith(eta)': False,
#    'endswith(etta)': False,
#    'endswith(ette)': False,
#    'endswith(ey)': False,
#    'endswith(f)': False,
#    'endswith(g)': False,
#    'endswith(ge)': False,
#    'endswith(h)': False,
#    'endswith(ha)': False,
#    'endswith(he)': False,
#    'endswith(i)': False,
#    'endswith(ia)': False,
#    'endswith(ian)': False,
#    'endswith(iana)': False,
#    'endswith(ica)': False,
#    'endswith(ice)': False,
#    'endswith(ick)': False,
#    'endswith(ida)': False,
#    'endswith(ie)': False,
#    'endswith(il)': False,
#    'endswith(in)': False,
#    'endswith(ina)': False,
#    'endswith(ine)': False,
#    'endswith(io)': False,
#    'endswith(is)': False,
#    'endswith(isa)': False,
#    'endswith(ise)': False,
#    'endswith(issa)': False,
#    'endswith(it)': False,
#    'endswith(ita)': True,
#    'endswith(k)': False,
#    'endswith(ka)': False,
#    'endswith(ke)': False,
#    'endswith(ki)': False,
#    'endswith(ky)': False,
#    'endswith(l)': False,
#    'endswith(la)': False,
#    'endswith(ld)': False,
#    'endswith(le)': False,
#    'endswith(lee)': False,
#    'endswith(leen)': False,
#    'endswith(len)': False,
#    'endswith(lene)': False,
#    'endswith(ley)': False,
#    'endswith(li)': False,
#    'endswith(lia)': False,
#    'endswith(lie)': False,
#    'endswith(lin)': False,
#    'endswith(lina)': False,
#    'endswith(line)': False,
#    'endswith(ll)': False,
#    'endswith(lla)': False,
#    'endswith(lle)': False,
#    'endswith(lli)': False,
#    'endswith(llie)': False,
#    'endswith(lly)': False,
#    'endswith(lo)': False,
#    'endswith(ly)': False,
#    'endswith(lyn)': False,
#    'endswith(m)': False,
#    'endswith(ma)': False,
#    'endswith(mie)': False,
#    'endswith(my)': False,
#    'endswith(n)': False,
#    'endswith(na)': False,
#    'endswith(nce)': False,
#    'endswith(nd)': False,
#    'endswith(nda)': False,
#    'endswith(ndra)': False,
#    'endswith(ndy)': False,
#    'endswith(ne)': False,
#    'endswith(ney)': False,
#    'endswith(ni)': False,
#    'endswith(nia)': False,
#    'endswith(nie)': False,
#    'endswith(nn)': False,
#    'endswith(nna)': False,
#    'endswith(nne)': False,
#    'endswith(nni)': False,
#    'endswith(nnie)': False,
#    'endswith(nny)': False,
#    'endswith(nt)': False,
#    'endswith(ny)': False,
#    'endswith(o)': False,
#    'endswith(on)': False,
#    'endswith(ona)': False,
#    'endswith(or)': False,
#    'endswith(ora)': False,
#    'endswith(ore)': False,
#    'endswith(p)': False,
#    'endswith(r)': False,
#    'endswith(ra)': False,
#    'endswith(rd)': False,
#    'endswith(re)': False,
#    'endswith(rey)': False,
#    'endswith(ri)': False,
#    'endswith(ria)': False,
#    'endswith(rick)': False,
#    'endswith(rie)': False,
#    'endswith(rina)': False,
#    'endswith(rine)': False,
#    'endswith(ris)': False,
#    'endswith(rrie)': False,
#    'endswith(rry)': False,
#    'endswith(rt)': False,
#    'endswith(ry)': False,
#    'endswith(s)': False,
#    'endswith(sa)': False,
#    'endswith(se)': False,
#    'endswith(sey)': False,
#    'endswith(sha)': False,
#    'endswith(si)': False,
#    'endswith(sie)': False,
#    'endswith(son)': False,
#    'endswith(ssa)': False,
#    'endswith(ssie)': False,
#    'endswith(sy)': False,
#    'endswith(t)': False,
#    'endswith(ta)': True,
#    'endswith(te)': False,
#    'endswith(ter)': False,
#    'endswith(th)': False,
#    'endswith(tha)': False,
#    'endswith(ti)': False,
#    'endswith(tie)': False,
#    'endswith(tin)': False,
#    'endswith(tina)': False,
#    'endswith(tine)': False,
#    'endswith(ton)': False,
#    'endswith(tt)': False,
#    'endswith(tta)': False,
#    'endswith(tte)': False,
#    'endswith(ty)': False,
#    'endswith(us)': False,
#    'endswith(va)': False,
#    'endswith(vin)': False,
#    'endswith(w)': False,
#    'endswith(y)': False,
#    'endswith(ya)': False,
#    'endswith(ye)': False,
#    'endswith(yl)': False,
#    'endswith(yn)': False,
#    'endswith(yne)': False,
#    'endswith(ynn)': False,
#    'startswith(a)': False,
#    'startswith(ab)': False,
#    'startswith(ad)': False,
#    'startswith(al)': False,
#    'startswith(ale)': False,
#    'startswith(ali)': False,
#    'startswith(all)': False,
#    'startswith(am)': False,
#    'startswith(an)': False,
#    'startswith(and)': False,
#    'startswith(ann)': False,
#    'startswith(ar)': False,
#    'startswith(au)': False,
#    'startswith(b)': False,
#    'startswith(ba)': False,
#    'startswith(bar)': False,
#    'startswith(be)': False,
#    'startswith(ben)': False,
#    'startswith(ber)': False,
#    'startswith(bl)': False,
#    'startswith(bo)': False,
#    'startswith(br)': False,
#    'startswith(bri)': False,
#    'startswith(c)': False,
#    'startswith(ca)': False,
#    'startswith(car)': False,
#    'startswith(carl)': False,
#    'startswith(cat)': False,
#    'startswith(ce)': False,
#    'startswith(ch)': False,
#    'startswith(cha)': False,
#    'startswith(char)': False,
#    'startswith(che)': False,
#    'startswith(chr)': False,
#    'startswith(chri)': False,
#    'startswith(cl)': False,
#    'startswith(cla)': False,
#    'startswith(clar)': False,
#    'startswith(co)': False,
#    'startswith(con)': False,
#    'startswith(cor)': False,
#    'startswith(d)': False,
#    'startswith(da)': False,
#    'startswith(dan)': False,
#    'startswith(dar)': False,
#    'startswith(de)': False,
#    'startswith(del)': False,
#    'startswith(di)': False,
#    'startswith(do)': False,
#    'startswith(dor)': False,
#    'startswith(du)': False,
#    'startswith(e)': False,
#    'startswith(ed)': False,
#    'startswith(el)': False,
#    'startswith(eli)': False,
#    'startswith(em)': False,
#    'startswith(er)': False,
#    'startswith(ev)': False,
#    'startswith(f)': False,
#    'startswith(fa)': False,
#    'startswith(fe)': False,
#    'startswith(fi)': False,
#    'startswith(fl)': False,
#    'startswith(flo)': False,
#    'startswith(flor)': False,
#    'startswith(fr)': False,
#    'startswith(fra)': False,
#    'startswith(fran)': False,
#    'startswith(fre)': False,
#    'startswith(g)': False,
#    'startswith(ga)': False,
#    'startswith(gar)': False,
#    'startswith(ge)': False,
#    'startswith(geo)': False,
#    'startswith(ger)': False,
#    'startswith(gi)': False,
#    'startswith(gl)': False,
#    'startswith(go)': False,
#    'startswith(gr)': False,
#    'startswith(gu)': False,
#    'startswith(h)': False,
#    'startswith(ha)': False,
#    'startswith(har)': False,
#    'startswith(he)': False,
#    'startswith(her)': False,
#    'startswith(hi)': False,
#    'startswith(ho)': False,
#    'startswith(i)': False,
#    'startswith(in)': False,
#    'startswith(is)': False,
#    'startswith(j)': True,
#    'startswith(ja)': False,
#    'startswith(jac)': False,
#    'startswith(jan)': False,
#    'startswith(je)': False,
#    'startswith(jen)': False,
#    'startswith(jer)': False,
#    'startswith(jo)': False,
#    'startswith(ju)': True,
#    'startswith(jul)': False,
#    'startswith(k)': False,
#    'startswith(ka)': False,
#    'startswith(kar)': False,
#    'startswith(kat)': False,
#    'startswith(ke)': False,
#    'startswith(ki)': False,
#    'startswith(kr)': False,
#    'startswith(l)': False,
#    'startswith(la)': False,
#    'startswith(lau)': False,
#    'startswith(laur)': False,
#    'startswith(le)': False,
#    'startswith(leo)': False,
#    'startswith(li)': False,
#    'startswith(lin)': False,
#    'startswith(lo)': False,
#    'startswith(lor)': False,
#    'startswith(lu)': False,
#    'startswith(luc)': False,
#    'startswith(ly)': False,
#    'startswith(lyn)': False,
#    'startswith(m)': False,
#    'startswith(ma)': False,
#    'startswith(mad)': False,
#    'startswith(mar)': False,
#    'startswith(marc)': False,
#    'startswith(marg)': False,
#    'startswith(mari)': False,
#    'startswith(mat)': False,
#    'startswith(me)': False,
#    'startswith(mel)': False,
#    'startswith(mer)': False,
#    'startswith(mi)': False,
#    'startswith(mic)': False,
#    'startswith(mo)': False,
#    'startswith(mor)': False,
#    'startswith(n)': False,
#    'startswith(na)': False,
#    'startswith(nat)': False,
#    'startswith(ne)': False,
#    'startswith(ni)': False,
#    'startswith(nic)': False,
#    'startswith(no)': False,
#    'startswith(o)': False,
#    'startswith(ol)': False,
#    'startswith(or)': False,
#    'startswith(p)': False,
#    'startswith(pa)': False,
#    'startswith(pat)': False,
#    'startswith(pe)': False,
#    'startswith(ph)': False,
#    'startswith(q)': False,
#    'startswith(qu)': False,
#    'startswith(r)': False,
#    'startswith(ra)': False,
#    'startswith(ran)': False,
#    'startswith(re)': False,
#    'startswith(ri)': False,
#    'startswith(ric)': False,
#    'startswith(ro)': False,
#    'startswith(rob)': False,
#    'startswith(ros)': False,
#    'startswith(ru)': False,
#    'startswith(s)': False,
#    'startswith(sa)': False,
#    'startswith(se)': False,
#    'startswith(sh)': False,
#    'startswith(sha)': False,
#    'startswith(she)': False,
#    'startswith(si)': False,
#    'startswith(so)': False,
#    'startswith(st)': False,
#    'startswith(sta)': False,
#    'startswith(ste)': False,
#    'startswith(su)': False,
#    'startswith(t)': False,
#    'startswith(ta)': False,
#    'startswith(te)': False,
#    'startswith(ter)': False,
#    'startswith(th)': False,
#    'startswith(the)': False,
#    'startswith(ti)': False,
#    'startswith(to)': False,
#    'startswith(tr)': False,
#    'startswith(u)': False,
#    'startswith(v)': False,
#    'startswith(va)': False,
#    'startswith(val)': False,
#    'startswith(ve)': False,
#    'startswith(ver)': False,
#    'startswith(vi)': False,
#    'startswith(w)': False,
#    'startswith(wa)': False,
#    'startswith(we)': False,
#    'startswith(wi)': False,
#    'startswith(wil)': False,
#    'startswith(win)': False,
#    'startswith(y)': False,
#    'startswith(z)': False,
#    'startswith(za)': False},
#   'male'),
#  ({'endswith(a)': False,
#    'endswith(ad)': False,
#    'endswith(ah)': False,
#    'endswith(aine)': False,
#    'endswith(al)': False,
#    'endswith(am)': False,
#    'endswith(an)': False,
#    'endswith(ana)': False,
#    'endswith(and)': False,
#    'endswith(ane)': False,
#    'endswith(ann)': False,
#    'endswith(anna)': False,
#    'endswith(anne)': False,
#    'endswith(ar)': False,
#    'endswith(ara)': False,
#    'endswith(ard)': False,
#    'endswith(as)': False,
#    'endswith(ay)': False,
#    'endswith(b)': False,
#    'endswith(bel)': False,
#    'endswith(bert)': False,
#    'endswith(bie)': False,
#    'endswith(by)': False,
#    'endswith(c)': False,
#    'endswith(ca)': False,
#    'endswith(ce)': False,
#    'endswith(ch)': False,
#    'endswith(cia)': False,
#    'endswith(ck)': False,
#    'endswith(cy)': False,
#    'endswith(d)': False,
#    'endswith(da)': False,
#    'endswith(de)': False,
#    'endswith(di)': False,
#    'endswith(die)': False,
#    'endswith(do)': False,
#    'endswith(dra)': False,
#    'endswith(dy)': False,
#    'endswith(e)': False,
#    'endswith(ea)': False,
#    'endswith(ed)': False,
#    'endswith(ee)': False,
#    'endswith(een)': False,
#    'endswith(el)': True,
#    'endswith(ela)': False,
#    'endswith(elia)': False,
#    'endswith(ell)': False,
#    'endswith(ella)': False,
#    'endswith(elle)': False,
#    'endswith(en)': False,
#    'endswith(ena)': False,
#    'endswith(ene)': False,
#    'endswith(er)': False,
#    'endswith(ert)': False,
#    'endswith(es)': False,
#    'endswith(et)': False,
#    'endswith(eta)': False,
#    'endswith(etta)': False,
#    'endswith(ette)': False,
#    'endswith(ey)': False,
#    'endswith(f)': False,
#    'endswith(g)': False,
#    'endswith(ge)': False,
#    'endswith(h)': False,
#    'endswith(ha)': False,
#    'endswith(he)': False,
#    'endswith(i)': False,
#    'endswith(ia)': False,
#    'endswith(ian)': False,
#    'endswith(iana)': False,
#    'endswith(ica)': False,
#    'endswith(ice)': False,
#    'endswith(ick)': False,
#    'endswith(ida)': False,
#    'endswith(ie)': False,
#    'endswith(il)': False,
#    'endswith(in)': False,
#    'endswith(ina)': False,
#    'endswith(ine)': False,
#    'endswith(io)': False,
#    'endswith(is)': False,
#    'endswith(isa)': False,
#    'endswith(ise)': False,
#    'endswith(issa)': False,
#    'endswith(it)': False,
#    'endswith(ita)': False,
#    'endswith(k)': False,
#    'endswith(ka)': False,
#    'endswith(ke)': False,
#    'endswith(ki)': False,
#    'endswith(ky)': False,
#    'endswith(l)': True,
#    'endswith(la)': False,
#    'endswith(ld)': False,
#    'endswith(le)': False,
#    'endswith(lee)': False,
#    'endswith(leen)': False,
#    'endswith(len)': False,
#    'endswith(lene)': False,
#    'endswith(ley)': False,
#    'endswith(li)': False,
#    'endswith(lia)': False,
#    'endswith(lie)': False,
#    'endswith(lin)': False,
#    'endswith(lina)': False,
#    'endswith(line)': False,
#    'endswith(ll)': False,
#    'endswith(lla)': False,
#    'endswith(lle)': False,
#    'endswith(lli)': False,
#    'endswith(llie)': False,
#    'endswith(lly)': False,
#    'endswith(lo)': False,
#    'endswith(ly)': False,
#    'endswith(lyn)': False,
#    'endswith(m)': False,
#    'endswith(ma)': False,
#    'endswith(mie)': False,
#    'endswith(my)': False,
#    'endswith(n)': False,
#    'endswith(na)': False,
#    'endswith(nce)': False,
#    'endswith(nd)': False,
#    'endswith(nda)': False,
#    'endswith(ndra)': False,
#    'endswith(ndy)': False,
#    'endswith(ne)': False,
#    'endswith(ney)': False,
#    'endswith(ni)': False,
#    'endswith(nia)': False,
#    'endswith(nie)': False,
#    'endswith(nn)': False,
#    'endswith(nna)': False,
#    'endswith(nne)': False,
#    'endswith(nni)': False,
#    'endswith(nnie)': False,
#    'endswith(nny)': False,
#    'endswith(nt)': False,
#    'endswith(ny)': False,
#    'endswith(o)': False,
#    'endswith(on)': False,
#    'endswith(ona)': False,
#    'endswith(or)': False,
#    'endswith(ora)': False,
#    'endswith(ore)': False,
#    'endswith(p)': False,
#    'endswith(r)': False,
#    'endswith(ra)': False,
#    'endswith(rd)': False,
#    'endswith(re)': False,
#    'endswith(rey)': False,
#    'endswith(ri)': False,
#    'endswith(ria)': False,
#    'endswith(rick)': False,
#    'endswith(rie)': False,
#    'endswith(rina)': False,
#    'endswith(rine)': False,
#    'endswith(ris)': False,
#    'endswith(rrie)': False,
#    'endswith(rry)': False,
#    'endswith(rt)': False,
#    'endswith(ry)': False,
#    'endswith(s)': False,
#    'endswith(sa)': False,
#    'endswith(se)': False,
#    'endswith(sey)': False,
#    'endswith(sha)': False,
#    'endswith(si)': False,
#    'endswith(sie)': False,
#    'endswith(son)': False,
#    'endswith(ssa)': False,
#    'endswith(ssie)': False,
#    'endswith(sy)': False,
#    'endswith(t)': False,
#    'endswith(ta)': False,
#    'endswith(te)': False,
#    'endswith(ter)': False,
#    'endswith(th)': False,
#    'endswith(tha)': False,
#    'endswith(ti)': False,
#    'endswith(tie)': False,
#    'endswith(tin)': False,
#    'endswith(tina)': False,
#    'endswith(tine)': False,
#    'endswith(ton)': False,
#    'endswith(tt)': False,
#    'endswith(tta)': False,
#    'endswith(tte)': False,
#    'endswith(ty)': False,
#    'endswith(us)': False,
#    'endswith(va)': False,
#    'endswith(vin)': False,
#    'endswith(w)': False,
#    'endswith(y)': False,
#    'endswith(ya)': False,
#    'endswith(ye)': False,
#    'endswith(yl)': False,
#    'endswith(yn)': False,
#    'endswith(yne)': False,
#    'endswith(ynn)': False,
#    'startswith(a)': False,
#    'startswith(ab)': False,
#    'startswith(ad)': False,
#    'startswith(al)': False,
#    'startswith(ale)': False,
#    'startswith(ali)': False,
#    'startswith(all)': False,
#    'startswith(am)': False,
#    'startswith(an)': False,
#    'startswith(and)': False,
#    'startswith(ann)': False,
#    'startswith(ar)': False,
#    'startswith(au)': False,
#    'startswith(b)': False,
#    'startswith(ba)': False,
#    'startswith(bar)': False,
#    'startswith(be)': False,
#    'startswith(ben)': False,
#    'startswith(ber)': False,
#    'startswith(bl)': False,
#    'startswith(bo)': False,
#    'startswith(br)': False,
#    'startswith(bri)': False,
#    'startswith(c)': False,
#    'startswith(ca)': False,
#    'startswith(car)': False,
#    'startswith(carl)': False,
#    'startswith(cat)': False,
#    'startswith(ce)': False,
#    'startswith(ch)': False,
#    'startswith(cha)': False,
#    'startswith(char)': False,
#    'startswith(che)': False,
#    'startswith(chr)': False,
#    'startswith(chri)': False,
#    'startswith(cl)': False,
#    'startswith(cla)': False,
#    'startswith(clar)': False,
#    'startswith(co)': False,
#    'startswith(con)': False,
#    'startswith(cor)': False,
#    'startswith(d)': True,
#    'startswith(da)': True,
#    'startswith(dan)': False,
#    'startswith(dar)': False,
#    'startswith(de)': False,
#    'startswith(del)': False,
#    'startswith(di)': False,
#    'startswith(do)': False,
#    'startswith(dor)': False,
#    'startswith(du)': False,
#    'startswith(e)': False,
#    'startswith(ed)': False,
#    'startswith(el)': False,
#    'startswith(eli)': False,
#    'startswith(em)': False,
#    'startswith(er)': False,
#    'startswith(ev)': False,
#    'startswith(f)': False,
#    'startswith(fa)': False,
#    'startswith(fe)': False,
#    'startswith(fi)': False,
#    'startswith(fl)': False,
#    'startswith(flo)': False,
#    'startswith(flor)': False,
#    'startswith(fr)': False,
#    'startswith(fra)': False,
#    'startswith(fran)': False,
#    'startswith(fre)': False,
#    'startswith(g)': False,
#    'startswith(ga)': False,
#    'startswith(gar)': False,
#    'startswith(ge)': False,
#    'startswith(geo)': False,
#    'startswith(ger)': False,
#    'startswith(gi)': False,
#    'startswith(gl)': False,
#    'startswith(go)': False,
#    'startswith(gr)': False,
#    'startswith(gu)': False,
#    'startswith(h)': False,
#    'startswith(ha)': False,
#    'startswith(har)': False,
#    'startswith(he)': False,
#    'startswith(her)': False,
#    'startswith(hi)': False,
#    'startswith(ho)': False,
#    'startswith(i)': False,
#    'startswith(in)': False,
#    'startswith(is)': False,
#    'startswith(j)': False,
#    'startswith(ja)': False,
#    'startswith(jac)': False,
#    'startswith(jan)': False,
#    'startswith(je)': False,
#    'startswith(jen)': False,
#    'startswith(jer)': False,
#    'startswith(jo)': False,
#    'startswith(ju)': False,
#    'startswith(jul)': False,
#    'startswith(k)': False,
#    'startswith(ka)': False,
#    'startswith(kar)': False,
#    'startswith(kat)': False,
#    'startswith(ke)': False,
#    'startswith(ki)': False,
#    'startswith(kr)': False,
#    'startswith(l)': False,
#    'startswith(la)': False,
#    'startswith(lau)': False,
#    'startswith(laur)': False,
#    'startswith(le)': False,
#    'startswith(leo)': False,
#    'startswith(li)': False,
#    'startswith(lin)': False,
#    'startswith(lo)': False,
#    'startswith(lor)': False,
#    'startswith(lu)': False,
#    'startswith(luc)': False,
#    'startswith(ly)': False,
#    'startswith(lyn)': False,
#    'startswith(m)': False,
#    'startswith(ma)': False,
#    'startswith(mad)': False,
#    'startswith(mar)': False,
#    'startswith(marc)': False,
#    'startswith(marg)': False,
#    'startswith(mari)': False,
#    'startswith(mat)': False,
#    'startswith(me)': False,
#    'startswith(mel)': False,
#    'startswith(mer)': False,
#    'startswith(mi)': False,
#    'startswith(mic)': False,
#    'startswith(mo)': False,
#    'startswith(mor)': False,
#    'startswith(n)': False,
#    'startswith(na)': False,
#    'startswith(nat)': False,
#    'startswith(ne)': False,
#    'startswith(ni)': False,
#    'startswith(nic)': False,
#    'startswith(no)': False,
#    'startswith(o)': False,
#    'startswith(ol)': False,
#    'startswith(or)': False,
#    'startswith(p)': False,
#    'startswith(pa)': False,
#    'startswith(pat)': False,
#    'startswith(pe)': False,
#    'startswith(ph)': False,
#    'startswith(q)': False,
#    'startswith(qu)': False,
#    'startswith(r)': False,
#    'startswith(ra)': False,
#    'startswith(ran)': False,
#    'startswith(re)': False,
#    'startswith(ri)': False,
#    'startswith(ric)': False,
#    'startswith(ro)': False,
#    'startswith(rob)': False,
#    'startswith(ros)': False,
#    'startswith(ru)': False,
#    'startswith(s)': False,
#    'startswith(sa)': False,
#    'startswith(se)': False,
#    'startswith(sh)': False,
#    'startswith(sha)': False,
#    'startswith(she)': False,
#    'startswith(si)': False,
#    'startswith(so)': False,
#    'startswith(st)': False,
#    'startswith(sta)': False,
#    'startswith(ste)': False,
#    'startswith(su)': False,
#    'startswith(t)': False,
#    'startswith(ta)': False,
#    'startswith(te)': False,
#    'startswith(ter)': False,
#    'startswith(th)': False,
#    'startswith(the)': False,
#    'startswith(ti)': False,
#    'startswith(to)': False,
#    'startswith(tr)': False,
#    'startswith(u)': False,
#    'startswith(v)': False,
#    'startswith(va)': False,
#    'startswith(val)': False,
#    'startswith(ve)': False,
#    'startswith(ver)': False,
#    'startswith(vi)': False,
#    'startswith(w)': False,
#    'startswith(wa)': False,
#    'startswith(we)': False,
#    'startswith(wi)': False,
#    'startswith(wil)': False,
#    'startswith(win)': False,
#    'startswith(y)': False,
#    'startswith(z)': False,
#    'startswith(za)': False},
#   'female'),
#  ({'endswith(a)': False,
#    'endswith(ad)': False,
#    'endswith(ah)': False,
#    'endswith(aine)': False,
#    'endswith(al)': False,
#    'endswith(am)': False,
#    'endswith(an)': False,
#    'endswith(ana)': False,
#    'endswith(and)': False,
#    'endswith(ane)': False,
#    'endswith(ann)': False,
#    'endswith(anna)': False,
#    'endswith(anne)': False,
#    'endswith(ar)': False,
#    'endswith(ara)': False,
#    'endswith(ard)': False,
#    'endswith(as)': False,
#    'endswith(ay)': False,
#    'endswith(b)': False,
#    'endswith(bel)': False,
#    'endswith(bert)': False,
#    'endswith(bie)': False,
#    'endswith(by)': False,
#    'endswith(c)': False,
#    'endswith(ca)': False,
#    'endswith(ce)': False,
#    'endswith(ch)': False,
#    'endswith(cia)': False,
#    'endswith(ck)': False,
#    'endswith(cy)': False,
#    'endswith(d)': False,
#    'endswith(da)': False,
#    'endswith(de)': False,
#    'endswith(di)': False,
#    'endswith(die)': False,
#    'endswith(do)': False,
#    'endswith(dra)': False,
#    'endswith(dy)': False,
#    'endswith(e)': True,
#    'endswith(ea)': False,
#    'endswith(ed)': False,
#    'endswith(ee)': False,
#    'endswith(een)': False,
#    'endswith(el)': False,
#    'endswith(ela)': False,
#    'endswith(elia)': False,
#    'endswith(ell)': False,
#    'endswith(ella)': False,
#    'endswith(elle)': False,
#    'endswith(en)': False,
#    'endswith(ena)': False,
#    'endswith(ene)': False,
#    'endswith(er)': False,
#    'endswith(ert)': False,
#    'endswith(es)': False,
#    'endswith(et)': False,
#    'endswith(eta)': False,
#    'endswith(etta)': False,
#    'endswith(ette)': False,
#    'endswith(ey)': False,
#    'endswith(f)': False,
#    'endswith(g)': False,
#    'endswith(ge)': False,
#    'endswith(h)': False,
#    'endswith(ha)': False,
#    'endswith(he)': False,
#    'endswith(i)': False,
#    'endswith(ia)': False,
#    'endswith(ian)': False,
#    'endswith(iana)': False,
#    'endswith(ica)': False,
#    'endswith(ice)': False,
#    'endswith(ick)': False,
#    'endswith(ida)': False,
#    'endswith(ie)': False,
#    'endswith(il)': False,
#    'endswith(in)': False,
#    'endswith(ina)': False,
#    'endswith(ine)': False,
#    'endswith(io)': False,
#    'endswith(is)': False,
#    'endswith(isa)': False,
#    'endswith(ise)': False,
#    'endswith(issa)': False,
#    'endswith(it)': False,
#    'endswith(ita)': False,
#    'endswith(k)': False,
#    'endswith(ka)': False,
#    'endswith(ke)': False,
#    'endswith(ki)': False,
#    'endswith(ky)': False,
#    'endswith(l)': False,
#    'endswith(la)': False,
#    'endswith(ld)': False,
#    'endswith(le)': False,
#    'endswith(lee)': False,
#    'endswith(leen)': False,
#    'endswith(len)': False,
#    'endswith(lene)': False,
#    'endswith(ley)': False,
#    'endswith(li)': False,
#    'endswith(lia)': False,
#    'endswith(lie)': False,
#    'endswith(lin)': False,
#    'endswith(lina)': False,
#    'endswith(line)': False,
#    'endswith(ll)': False,
#    'endswith(lla)': False,
#    'endswith(lle)': False,
#    'endswith(lli)': False,
#    'endswith(llie)': False,
#    'endswith(lly)': False,
#    'endswith(lo)': False,
#    'endswith(ly)': False,
#    'endswith(lyn)': False,
#    'endswith(m)': False,
#    'endswith(ma)': False,
#    'endswith(mie)': False,
#    'endswith(my)': False,
#    'endswith(n)': False,
#    'endswith(na)': False,
#    'endswith(nce)': False,
#    'endswith(nd)': False,
#    'endswith(nda)': False,
#    'endswith(ndra)': False,
#    'endswith(ndy)': False,
#    'endswith(ne)': True,
#    'endswith(ney)': False,
#    'endswith(ni)': False,
#    'endswith(nia)': False,
#    'endswith(nie)': False,
#    'endswith(nn)': False,
#    'endswith(nna)': False,
#    'endswith(nne)': False,
#    'endswith(nni)': False,
#    'endswith(nnie)': False,
#    'endswith(nny)': False,
#    'endswith(nt)': False,
#    'endswith(ny)': False,
#    'endswith(o)': False,
#    'endswith(on)': False,
#    'endswith(ona)': False,
#    'endswith(or)': False,
#    'endswith(ora)': False,
#    'endswith(ore)': False,
#    'endswith(p)': False,
#    'endswith(r)': False,
#    'endswith(ra)': False,
#    'endswith(rd)': False,
#    'endswith(re)': False,
#    'endswith(rey)': False,
#    'endswith(ri)': False,
#    'endswith(ria)': False,
#    'endswith(rick)': False,
#    'endswith(rie)': False,
# ...
#    'startswith(c)': False,
#    'startswith(ca)': False,
#    'startswith(car)': False,
#    'startswith(carl)': False,
#    'startswith(cat)': False,
#    'startswith(ce)': False,
#    'startswith(ch)': False,
#    'startswith(cha)': False,
#    'startswith(char)': False,
#    'startswith(che)': False,
#    'startswith(chr)': False,
#    'startswith(chri)': False,
#    'startswith(cl)': False,
#    'startswith(cla)': False,
#    'startswith(clar)': False,
#    'startswith(co)': False,
#    'startswith(con)': False,
#    'startswith(cor)': False,
#    'startswith(d)': False,
#    'startswith(da)': False,
#    'startswith(dan)': False,
#    'startswith(dar)': False,
#    'startswith(de)': False,
#    'startswith(del)': False,
#    'startswith(di)': False,
#    'startswith(do)': False,
#    'startswith(dor)': False,
#    'startswith(du)': False,
#    'startswith(e)': False,
#    'startswith(ed)': False,
#    'startswith(el)': False,
#    'startswith(eli)': False,
#    'startswith(em)': False,
#    'startswith(er)': False,
#    'startswith(ev)': False,
#    'startswith(f)': False,
#    'startswith(fa)': False,
#    'startswith(fe)': False,
#    'startswith(fi)': False,
#    'startswith(fl)': False,
#    'startswith(flo)': False,
#    'startswith(flor)': False,
#    'startswith(fr)': False,
#    'startswith(fra)': False,
#    'startswith(fran)': False,
#    'startswith(fre)': False,
#    'startswith(g)': False,
#    'startswith(ga)': False,
#    'startswith(gar)': False,
#    'startswith(ge)': False,
#    'startswith(geo)': False,
#    'startswith(ger)': False,
#    'startswith(gi)': False,
#    'startswith(gl)': False,
#    'startswith(go)': False,
#    'startswith(gr)': False,
#    'startswith(gu)': False,
#    'startswith(h)': False,
#    'startswith(ha)': False,
#    'startswith(har)': False,
#    'startswith(he)': False,
#    'startswith(her)': False,
#    'startswith(hi)': False,
#    'startswith(ho)': False,
#    'startswith(i)': False,
#    'startswith(in)': False,
#    'startswith(is)': False,
#    'startswith(j)': False,
#    'startswith(ja)': False,
#    'startswith(jac)': False,
#    'startswith(jan)': False,
#    'startswith(je)': False,
#    'startswith(jen)': False,
#    'startswith(jer)': False,
#    'startswith(jo)': False,
#    'startswith(ju)': False,
#    'startswith(jul)': False,
#    'startswith(k)': False,
#    'startswith(ka)': False,
#    'startswith(kar)': False,
#    'startswith(kat)': False,
#    'startswith(ke)': False,
#    'startswith(ki)': False,
#    'startswith(kr)': False,
#    'startswith(l)': False,
#    'startswith(la)': False,
#    'startswith(lau)': False,
#    'startswith(laur)': False,
#    'startswith(le)': False,
#    'startswith(leo)': False,
#    'startswith(li)': False,
#    'startswith(lin)': False,
#    'startswith(lo)': False,
#    'startswith(lor)': False,
#    'startswith(lu)': False,
#    'startswith(luc)': False,
#    'startswith(ly)': False,
#    'startswith(lyn)': False,
#    'startswith(m)': False,
#    'startswith(ma)': False,
#    'startswith(mad)': False,
#    'startswith(mar)': False,
#    'startswith(marc)': False,
#    'startswith(marg)': False,
#    'startswith(mari)': False,
#    'startswith(mat)': False,
#    'startswith(me)': False,
#    'startswith(mel)': False,
#    'startswith(mer)': False,
#    'startswith(mi)': False,
#    'startswith(mic)': False,
#    'startswith(mo)': False,
#    'startswith(mor)': False,
#    'startswith(n)': False,
#    'startswith(na)': False,
#    'startswith(nat)': False,
#    'startswith(ne)': False,
#    'startswith(ni)': False,
#    'startswith(nic)': False,
#    'startswith(no)': False,
#    'startswith(o)': False,
#    'startswith(ol)': False,
#    'startswith(or)': False,
#    'startswith(p)': False,
#    'startswith(pa)': False,
#    'startswith(pat)': False,
#    'startswith(pe)': False,
#    'startswith(ph)': False,
#    'startswith(q)': False,
#    'startswith(qu)': False,
#    'startswith(r)': False,
#    'startswith(ra)': False,
#    'startswith(ran)': False,
#    'startswith(re)': False,
#    'startswith(ri)': False,
#    'startswith(ric)': False,
#    'startswith(ro)': False,
#    'startswith(rob)': False,
#    'startswith(ros)': False,
#    'startswith(ru)': False,
#    'startswith(s)': True,
#    'startswith(sa)': False,
#    'startswith(se)': False,
#    'startswith(sh)': True,
#    'startswith(sha)': True,
#    'startswith(she)': False,
#    'startswith(si)': False,
#    'startswith(so)': False,
#    'startswith(st)': False,
#    'startswith(sta)': False,
#    'startswith(ste)': False,
#    'startswith(su)': False,
#    'startswith(t)': False,
#    'startswith(ta)': False,
#    'startswith(te)': False,
#    'startswith(ter)': False,
#    'startswith(th)': False,
#    'startswith(the)': False,
#    'startswith(ti)': False,
#    'startswith(to)': False,
#    'startswith(tr)': False,
#    'startswith(u)': False,
#    'startswith(v)': False,
#    'startswith(va)': False,
#    'startswith(val)': False,
#    'startswith(ve)': False,
#    'startswith(ver)': False,
#    'startswith(vi)': False,
#    'startswith(w)': False,
#    'startswith(wa)': False,
#    'startswith(we)': False,
#    'startswith(wi)': False,
#    'startswith(wil)': False,
#    'startswith(win)': False,
#    'startswith(y)': False,
#    'startswith(z)': False,
#    'startswith(za)': False},
#   'female'),
#  ({'endswith(a)': False,
#    'endswith(ad)': False,
#    'endswith(ah)': False,
#    'endswith(aine)': False,
#    'endswith(al)': False,
#    'endswith(am)': False,
#    'endswith(an)': False,
#    'endswith(ana)': False,
#    'endswith(and)': False,
#    'endswith(ane)': False,
#    'endswith(ann)': False,
#    'endswith(anna)': False,
#    'endswith(anne)': False,
#    'endswith(ar)': False,
#    'endswith(ara)': False,
#    'endswith(ard)': False,
#    'endswith(as)': False,
#    'endswith(ay)': False,
#    'endswith(b)': False,
#    'endswith(bel)': False,
#    'endswith(bert)': False,
#    'endswith(bie)': False,
#    'endswith(by)': False,
#    'endswith(c)': False,
#    'endswith(ca)': False,
#    'endswith(ce)': False,
#    'endswith(ch)': False,
#    'endswith(cia)': False,
#    'endswith(ck)': False,
#    'endswith(cy)': False,
#    'endswith(d)': False,
#    'endswith(da)': False,
#    'endswith(de)': False,
#    'endswith(di)': False,
#    'endswith(die)': False,
#    'endswith(do)': False,
#    'endswith(dra)': False,
#    'endswith(dy)': False,
#    'endswith(e)': True,
#    'endswith(ea)': False,
#    'endswith(ed)': False,
#    'endswith(ee)': False,
#    'endswith(een)': False,
#    'endswith(el)': False,
#    'endswith(ela)': False,
#    'endswith(elia)': False,
#    'endswith(ell)': False,
#    'endswith(ella)': False,
#    'endswith(elle)': False,
#    'endswith(en)': False,
#    'endswith(ena)': False,
#    'endswith(ene)': False,
#    'endswith(er)': False,
#    'endswith(ert)': False,
#    'endswith(es)': False,
#    'endswith(et)': False,
#    'endswith(eta)': False,
#    'endswith(etta)': False,
#    'endswith(ette)': False,
#    'endswith(ey)': False,
#    'endswith(f)': False,
#    'endswith(g)': False,
#    'endswith(ge)': False,
#    'endswith(h)': False,
#    'endswith(ha)': False,
#    'endswith(he)': False,
#    'endswith(i)': False,
#    'endswith(ia)': False,
#    'endswith(ian)': False,
#    'endswith(iana)': False,
#    'endswith(ica)': False,
#    'endswith(ice)': False,
#    'endswith(ick)': False,
#    'endswith(ida)': False,
#    'endswith(ie)': False,
#    'endswith(il)': False,
#    'endswith(in)': False,
#    'endswith(ina)': False,
#    'endswith(ine)': True,
#    'endswith(io)': False,
#    'endswith(is)': False,
#    'endswith(isa)': False,
#    'endswith(ise)': False,
#    'endswith(issa)': False,
#    'endswith(it)': False,
#    'endswith(ita)': False,
#    'endswith(k)': False,
#    'endswith(ka)': False,
#    'endswith(ke)': False,
#    'endswith(ki)': False,
#    'endswith(ky)': False,
#    'endswith(l)': False,
#    'endswith(la)': False,
#    'endswith(ld)': False,
#    'endswith(le)': False,
#    'endswith(lee)': False,
#    'endswith(leen)': False,
#    'endswith(len)': False,
#    'endswith(lene)': False,
#    'endswith(ley)': False,
#    'endswith(li)': False,
#    'endswith(lia)': False,
#    'endswith(lie)': False,
#    'endswith(lin)': False,
#    'endswith(lina)': False,
#    'endswith(line)': False,
#    'endswith(ll)': False,
#    'endswith(lla)': False,
#    'endswith(lle)': False,
#    'endswith(lli)': False,
#    'endswith(llie)': False,
#    'endswith(lly)': False,
#    'endswith(lo)': False,
#    'endswith(ly)': False,
#    'endswith(lyn)': False,
#    'endswith(m)': False,
#    'endswith(ma)': False,
#    'endswith(mie)': False,
#    'endswith(my)': False,
#    'endswith(n)': False,
#    'endswith(na)': False,
#    'endswith(nce)': False,
#    'endswith(nd)': False,
#    'endswith(nda)': False,
#    'endswith(ndra)': False,
#    'endswith(ndy)': False,
#    'endswith(ne)': True,
#    'endswith(ney)': False,
#    'endswith(ni)': False,
#    'endswith(nia)': False,
#    'endswith(nie)': False,
#    'endswith(nn)': False,
#    'endswith(nna)': False,
#    'endswith(nne)': False,
#    'endswith(nni)': False,
#    'endswith(nnie)': False,
#    'endswith(nny)': False,
#    'endswith(nt)': False,
#    'endswith(ny)': False,
#    'endswith(o)': False,
#    'endswith(on)': False,
#    'endswith(ona)': False,
#    'endswith(or)': False,
#    'endswith(ora)': False,
#    'endswith(ore)': False,
#    'endswith(p)': False,
#    'endswith(r)': False,
#    'endswith(ra)': False,
#    'endswith(rd)': False,
#    'endswith(re)': False,
#    'endswith(rey)': False,
#    'endswith(ri)': False,
#    'endswith(ria)': False,
#    'endswith(rick)': False,
#    'endswith(rie)': False,
#    'endswith(rina)': False,
#    'endswith(rine)': False,
#    'endswith(ris)': False,
#    'endswith(rrie)': False,
#    'endswith(rry)': False,
#    'endswith(rt)': False,
#    'endswith(ry)': False,
#    'endswith(s)': False,
#    'endswith(sa)': False,
#    'endswith(se)': False,
#    'endswith(sey)': False,
#    'endswith(sha)': False,
#    'endswith(si)': False,
#    'endswith(sie)': False,
#    'endswith(son)': False,
#    'endswith(ssa)': False,
#    'endswith(ssie)': False,
#    'endswith(sy)': False,
#    'endswith(t)': False,
#    'endswith(ta)': False,
#    'endswith(te)': False,
#    'endswith(ter)': False,
#    'endswith(th)': False,
#    'endswith(tha)': False,
#    'endswith(ti)': False,
#    'endswith(tie)': False,
#    'endswith(tin)': False,
#    'endswith(tina)': False,
#    'endswith(tine)': False,
#    'endswith(ton)': False,
#    'endswith(tt)': False,
#    'endswith(tta)': False,
#    'endswith(tte)': False,
#    'endswith(ty)': False,
#    'endswith(us)': False,
#    'endswith(va)': False,
#    'endswith(vin)': False,
#    'endswith(w)': False,
#    'endswith(y)': False,
#    'endswith(ya)': False,
#    'endswith(ye)': False,
#    'endswith(yl)': False,
#    'endswith(yn)': False,
#    'endswith(yne)': False,
#    'endswith(ynn)': False,
#    'startswith(a)': False,
#    'startswith(ab)': False,
#    'startswith(ad)': False,
#    'startswith(al)': False,
#    'startswith(ale)': False,
#    'startswith(ali)': False,
#    'startswith(all)': False,
#    'startswith(am)': False,
#    'startswith(an)': False,
#    'startswith(and)': False,
#    'startswith(ann)': False,
#    'startswith(ar)': False,
#    'startswith(au)': False,
#    'startswith(b)': False,
#    'startswith(ba)': False,
#    'startswith(bar)': False,
#    'startswith(be)': False,
#    'startswith(ben)': False,
#    'startswith(ber)': False,
#    'startswith(bl)': False,
#    'startswith(bo)': False,
#    'startswith(br)': False,
#    'startswith(bri)': False,
#    'startswith(c)': False,
#    'startswith(ca)': False,
#    'startswith(car)': False,
#    'startswith(carl)': False,
#    'startswith(cat)': False,
#    'startswith(ce)': False,
#    'startswith(ch)': False,
#    'startswith(cha)': False,
#    'startswith(char)': False,
#    'startswith(che)': False,
#    'startswith(chr)': False,
#    'startswith(chri)': False,
#    'startswith(cl)': False,
#    'startswith(cla)': False,
#    'startswith(clar)': False,
#    'startswith(co)': False,
#    'startswith(con)': False,
#    'startswith(cor)': False,
#    'startswith(d)': False,
#    'startswith(da)': False,
#    'startswith(dan)': False,
#    'startswith(dar)': False,
#    'startswith(de)': False,
#    'startswith(del)': False,
#    'startswith(di)': False,
#    'startswith(do)': False,
#    'startswith(dor)': False,
#    'startswith(du)': False,
#    'startswith(e)': False,
#    'startswith(ed)': False,
#    'startswith(el)': False,
#    'startswith(eli)': False,
#    'startswith(em)': False,
#    'startswith(er)': False,
#    'startswith(ev)': False,
#    'startswith(f)': False,
#    'startswith(fa)': False,
#    'startswith(fe)': False,
#    'startswith(fi)': False,
#    'startswith(fl)': False,
#    'startswith(flo)': False,
#    'startswith(flor)': False,
#    'startswith(fr)': False,
#    'startswith(fra)': False,
#    'startswith(fran)': False,
#    'startswith(fre)': False,
#    'startswith(g)': False,
#    'startswith(ga)': False,
#    'startswith(gar)': False,
#    'startswith(ge)': False,
#    'startswith(geo)': False,
#    'startswith(ger)': False,
#    'startswith(gi)': False,
#    'startswith(gl)': False,
#    'startswith(go)': False,
#    'startswith(gr)': False,
#    'startswith(gu)': False,
#    'startswith(h)': False,
#    'startswith(ha)': False,
#    'startswith(har)': False,
#    'startswith(he)': False,
#    'startswith(her)': False,
#    'startswith(hi)': False,
#    'startswith(ho)': False,
#    'startswith(i)': False,
#    'startswith(in)': False,
#    'startswith(is)': False,
#    'startswith(j)': True,
#    'startswith(ja)': False,
#    'startswith(jac)': False,
#    'startswith(jan)': False,
#    'startswith(je)': True,
#    'startswith(jen)': False,
#    'startswith(jer)': False,
#    'startswith(jo)': False,
#    'startswith(ju)': False,
#    'startswith(jul)': False,
#    'startswith(k)': False,
#    'startswith(ka)': False,
#    'startswith(kar)': False,
#    'startswith(kat)': False,
#    'startswith(ke)': False,
#    'startswith(ki)': False,
#    'startswith(kr)': False,
#    'startswith(l)': False,
#    'startswith(la)': False,
#    'startswith(lau)': False,
#    'startswith(laur)': False,
#    'startswith(le)': False,
#    'startswith(leo)': False,
#    'startswith(li)': False,
#    'startswith(lin)': False,
#    'startswith(lo)': False,
#    'startswith(lor)': False,
#    'startswith(lu)': False,
#    'startswith(luc)': False,
#    'startswith(ly)': False,
#    'startswith(lyn)': False,
#    'startswith(m)': False,
#    'startswith(ma)': False,
#    'startswith(mad)': False,
#    'startswith(mar)': False,
#    'startswith(marc)': False,
#    'startswith(marg)': False,
#    'startswith(mari)': False,
#    'startswith(mat)': False,
#    'startswith(me)': False,
#    'startswith(mel)': False,
#    'startswith(mer)': False,
#    'startswith(mi)': False,
#    'startswith(mic)': False,
#    'startswith(mo)': False,
#    'startswith(mor)': False,
#    'startswith(n)': False,
#    'startswith(na)': False,
#    'startswith(nat)': False,
#    'startswith(ne)': False,
#    'startswith(ni)': False,
#    'startswith(nic)': False,
#    'startswith(no)': False,
#    'startswith(o)': False,
#    'startswith(ol)': False,
#    'startswith(or)': False,
#    'startswith(p)': False,
#    'startswith(pa)': False,
#    'startswith(pat)': False,
#    'startswith(pe)': False,
#    'startswith(ph)': False,
#    'startswith(q)': False,
#    'startswith(qu)': False,
#    'startswith(r)': False,
#    'startswith(ra)': False,
#    'startswith(ran)': False,
#    'startswith(re)': False,
#    'startswith(ri)': False,
#    'startswith(ric)': False,
#    'startswith(ro)': False,
#    'startswith(rob)': False,
#    'startswith(ros)': False,
#    'startswith(ru)': False,
#    'startswith(s)': False,
#    'startswith(sa)': False,
#    'startswith(se)': False,
#    'startswith(sh)': False,
#    'startswith(sha)': False,
#    'startswith(she)': False,
#    'startswith(si)': False,
#    'startswith(so)': False,
#    'startswith(st)': False,
#    'startswith(sta)': False,
#    'startswith(ste)': False,
#    'startswith(su)': False,
#    'startswith(t)': False,
#    'startswith(ta)': False,
#    'startswith(te)': False,
#    'startswith(ter)': False,
#    'startswith(th)': False,
#    'startswith(the)': False,
#    'startswith(ti)': False,
#    'startswith(to)': False,
#    'startswith(tr)': False,
#    'startswith(u)': False,
#    'startswith(v)': False,
#    'startswith(va)': False,
#    'startswith(val)': False,
#    'startswith(ve)': False,
#    'startswith(ver)': False,
#    'startswith(vi)': False,
#    'startswith(w)': False,
#    'startswith(wa)': False,
#    'startswith(we)': False,
#    'startswith(wi)': False,
#    'startswith(wil)': False,
#    'startswith(win)': False,
#    'startswith(y)': False,
#    'startswith(z)': False,
#    'startswith(za)': False},
#   'female')]

# %%
size = int(len(featuresets) * 0.1)
train_set, test_set = featuresets[size:], featuresets[:size]

# %%
DTclassifier = nltk.DecisionTreeClassifier.train(train_set)
nltk.classify.accuracy(DTclassifier, test_set)
# Out:
# 0.7884130982367759

# %%
DTclassifier.classify(pos_features_both('Mauricio'))
# Out:
# 'male'

# %% [markdown]
# ### Model Performance

# %%
nltk.ConfusionMatrix([gender for (f,gender) in devtest_featureset], [DTclassifier.classify(pos_features_both(n)) for (n,g) in devtest_dataset])
# Out:
# <ConfusionMatrix: 406/500 correct>

# %%
DTpreds = pd.DataFrame({'name':[f for (f,gender) in test_dataset],'observed':[gender for (f,gender) in test_dataset],'predicted': [DTclassifier.classify(gender_features(n)) for (n,g) in test_dataset]})
pd.crosstab(DTpreds.observed,DTpreds.predicted)
# Out:
# predicted  female
# observed
# female        306
# male          194

# %%
#something wrong with the 'male' data, will check it out tomorrow

# %%
import seaborn as sn
import matplotlib.pyplot as plt
import numpy as np
#genderDf = pd.crosstab(DTpreds.observed,DTpreds.predicted)

#genderDf = pd.DataFrame(genderDf)
#genderArray = np.array([[genderDf.at['female','female'], genderDf.at['female','male']],
                   [genderDf.at['male','female'], genderDf.at['male','male']]])

#genderCM = pd.DataFrame(genderArray, index = ['female','male'],
                  columns = ['female','male'])
#plt.figure(figsize = (5,4))
#ax = plt.axes()
#sn.heatmap(genderCM, annot=True,cmap='YlGnBu', fmt='g', ax = ax)

#ax.set_title('Actual Vs. Predicted')
# Out:
# --------------------------------------------------------------------------
# KeyError                                 Traceback (most recent call last)
# <ipython-input-177-082782f210ae> in <module>()
#       5
#       6 genderDf = pd.DataFrame(genderDf)
# ----> 7 genderArray = np.array([[genderDf.at['female','female'], genderDf.at['female','male']],
#       8                    [genderDf.at['male','female'], genderDf.at['male','male']]])
#       9
#
# /anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1784
#    1785         key = self._convert_key(key)
# -> 1786         return self.obj.get_value(*key, takeable=self._takeable)
#    1787
#    1788     def __setitem__(self, key, value):
#
# /anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in get_value(self, index, col, takeable)
#    1915             return _maybe_box_datetimelike(series._values[index])
#    1916
# -> 1917         series = self._get_item_cache(col)
#    1918         engine = self.index._engine
#    1919
#
# /anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1532         res = cache.get(item)
#    1533         if res is None:
# -> 1534             values = self._data.get(item)
#    1535             res = self._box_item_values(item, values)
#    1536             cache[item] = res
#
# /anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /anaconda/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
# -> 2395                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2396
#    2397         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20405)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20359)()
#
# KeyError: 'male'

# %%
years = [] 
percents = [] 
from __future__ import division


for year in range(1880, 2017):
    url_base = "https://raw.githubusercontent.com/RaphaelNash/CUNY-DATA-620-WebAnalytics/master/Project3/names/yob"
    url = url_base + str(year) + ".txt"
    yob_df = pd.read_csv(url, header=None)
    yob_df["predicted_gender"] = yob_df[0].apply(lambda x:  DTclassifier.classify(gender_features(x )))
    yob_df["predicted_gender"] = ['F' if x == 'female' else 'M' for x in yob_df['predicted_gender']]
    years.append(year)
    percents.append(len( yob_df [  yob_df['predicted_gender'] == yob_df[1]])/len(yob_df))
    
year_accuracy_df = pd.Series(percents, index = years)

ax = year_accuracy_df.plot(figsize=(20,10))

vals = ax.get_yticks()
ax.set_yticklabels(['{:3.0f}%'.format(x*100) for x in vals])
ax.get_xaxis().get_major_formatter().set_useOffset(False)

ax.set_title("Prediction Acuracy with SSA Data over time")
ax.set_xlabel('Year')
ax.set_ylabel('% Accurately Predicted')
